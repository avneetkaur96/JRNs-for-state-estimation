# %%
#down pendulum EKF vs JRN comparison for 2 dimensions
import numpy as np
import tensorflow as tf
from keras.callbacks import EarlyStopping
from numpy import linalg
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import math
import matplotlib.pyplot as plt
from scipy.signal import cont2discrete, lti, dlti, dstep
import scipy.integrate
import time
from mpl_toolkits import mplot3d
import matplotlib
from keras.callbacks import EarlyStopping
from keras.models import Sequential
#from keras.layers import Dense, SimpleRNN, LSTM
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset  
import os
# Out:
# 2025-06-27 14:10:21.557538: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751047821.577856  288129 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751047821.583928  288129 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-27 14:10:21.603983: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print(tf.config.list_physical_devices())
start=time.time()

# Simulation variables
seq_length = 301 # Number of time steps in each sequence
num_records = 200 # Number of sequences to generate
dim_y = 1  # No. of observables
dim_x= 2 # Number of states
dt=0.1
end_t=seq_length*dt

# Arrays to store results
X_data_array = np.empty((num_records, seq_length, dim_x))
Y_data_array = np.empty((num_records, seq_length, dim_y))
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU')]

# %%
# Continuous-time model
def f(t,x,l,g,m,b):
    x1,x2=x
    dx_dt = [0,0]
    dx_dt[0] = x2
    dx_dt[1] = -(g*np.sin(x1))/l-b/m*x2
    return dx_dt

# Parameters
l=1
g=9.8 
m=2
b=0.9

P=0.01*np.identity(dim_x) #covariance of initial condition
mu_pn = np.zeros(dim_x) #mean of process noise
Q=0.01*np.identity(dim_x) #process noise covariance
mu_mn=np.zeros(dim_y) #mean of measurement noise
R=[0.01] #measurement noise covariance
G=np.identity(dim_x) #process noise coefficient matrix

t_span= np.arange(0,end_t,dt)
num_timesteps=np.shape(t_span)[0]

for i in range(0, num_records, 1):
    mu_x0=np.random.uniform(-2,2,size=dim_x) #mean of initial condition
    x0_old=np.random.multivariate_normal(mu_x0,P)
    sol=scipy.integrate.solve_ivp(f,(0,end_t),x0_old, method='RK45', args=(l,g,m,b),dense_output=True, t_eval=np.arange(0, end_t, dt))
    X_data_array[i,:,:]=np.transpose(sol.y)
    for j in range(1,seq_length,1):
        w=np.random.multivariate_normal(mu_pn,Q) 
        X_data_array[i,j,:]=X_data_array[i,j,:]+np.matmul(G,w)
        v=np.random.normal(mu_mn,R)   #change to multivariate if R has greater than 1 dimension
        Y_data_array[i,j,:]=np.matmul(X_data_array[i,j,:],[[1],[0]])+v

# %%
plt.plot(t_span,X_data_array[199,:,0],'b-',label='x1')
plt.plot(t_span,X_data_array[199,:,1],'r--',label='x2')
plt.ylabel('Plot')
plt.xlabel('Time')
plt.legend(loc='best')
plt.show()

# %%
plt.plot(t_span,sol.y[0,:],'b-',label='x1')
plt.plot(t_span,sol.y[1,:],'r--',label='x2')
plt.ylabel('Plot')
plt.xlabel('Time')
plt.legend(loc='best')
plt.show()

# %%
num_data_pts = seq_length*num_records
num_train_pts = np.floor(0.80*num_records).astype(int)
num_val_pts = np.floor(0.10*num_records).astype(int)
test_data_size = num_records-num_train_pts-num_val_pts

Y_train = Y_data_array[0:num_train_pts,1:,:]
X_train = X_data_array[0:num_train_pts,1:,:]
num_train_plus_val = num_train_pts+num_val_pts

Y_validate = Y_data_array[num_train_pts:num_train_plus_val,1:,:]
X_validate = X_data_array[num_train_pts:num_train_plus_val,1:,:]

Y_test = Y_data_array[num_train_plus_val:num_records,1:,:]
X_test = X_data_array[num_train_plus_val:num_records,1:,:]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
print("Device name:", torch.cuda.get_device_name(0))
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = True

# Convert data to PyTorch tensors
input_data = torch.tensor(Y_train, dtype=torch.float32)
output_data = torch.tensor(X_train, dtype=torch.float32)

# Define validation data
val_input_data = torch.tensor(Y_validate, dtype=torch.float32) 
val_output_data = torch.tensor(X_validate, dtype=torch.float32)  

test_input_data=torch.tensor(Y_test, dtype=torch.float32)
test_output_data=torch.tensor(X_test, dtype=torch.float32)

#proposed jrn implementation
start=time.time()

# Initialize variables for early stopping
best_val_loss = float('inf')  # Set initial best validation loss to infinity
patience = 50  # Number of epochs to wait for improvement
counter = 0  # Counter to track the number of epochs with no improvement

checkpoint_dir = './dp_torch_checkpoints_jrn'
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
    
# Define the model
class JRN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(JRN, self).__init__()
        self.output_size=output_size 
        self.Why = nn.Parameter(torch.empty(hidden_size, output_size))
        nn.init.xavier_uniform_(self.Why)
        self.Wyh = nn.Parameter(torch.empty(output_size, hidden_size))
        self.Wxh = nn.Parameter(torch.empty(input_size, hidden_size))
        nn.init.orthogonal_(self.Wyh)  
        nn.init.orthogonal_(self.Wxh)
        #self.bh = nn.Parameter(torch.zeros(hidden_size))
        #self.by = nn.Parameter(torch.zeros(output_size))

    def forward(self, x):
        batch_size, seq_len, _ = x.size()
        y = torch.zeros(batch_size, self.output_size, device=x.device)
        outputs = []
        for i in range(seq_len):
            h = torch.tanh(torch.matmul(x[:, i, :], self.Wxh) + torch.matmul(y, self.Wyh))
            y = torch.matmul(h, self.Why) 
            outputs.append(y.unsqueeze(1))
        return torch.cat(outputs, dim=1)

# Create DataLoader for training data
train_dataset = TensorDataset(input_data, output_data)
train_loader = DataLoader(train_dataset, batch_size=40, shuffle=True)

# Define the model, loss function, and optimizer
hidden_size = 50
model = JRN(dim_y, hidden_size, dim_x).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
best_epoch=0

# Training the model
num_epochs = 600
start_time = time.time()
for epoch in range(num_epochs):
    total_loss = 0.0
    for batch_Y, batch_X in train_loader:
        batch_Y=batch_Y.to(device)
        batch_X=batch_X.to(device)
        # Forward pass
        all_outputs = model(batch_Y)

        # Compute the loss
        loss = criterion(all_outputs, batch_X)
        total_loss += loss.item()

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Validation
    with torch.no_grad():
        val_loss = criterion(model(val_input_data.to(device)), val_output_data.to(device))

    # Print and check for early stopping
    print(f'Epoch [{epoch}], Loss: {total_loss / len(train_loader):.4f}, Val Loss: {val_loss.item():.4f}')

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
        best_epoch = epoch
        torch.save({'model_state_dict': model.state_dict()}, os.path.join(checkpoint_dir, 'ckpt.pth'))
    else:
        counter += 1
        if counter >= patience:
            print(f'Early stopping at epoch {epoch+1} as validation loss did not improve for {patience} epochs.')
            break

end_time = time.time()
print("Time taken to train RNN:", end_time - start_time)

print("Best Epoch:", best_epoch)

# Restore best model
checkpoint = torch.load(os.path.join(checkpoint_dir, 'ckpt.pth'))
model.load_state_dict(checkpoint['model_state_dict'])

# Test the model
with torch.no_grad():
    predicted_output = model(test_input_data.to(device))
    print("Error in Output:")
    print(predicted_output.to(device) - test_output_data.to(device))
# Out:
# Using device: cuda
# Device name: NVIDIA RTX 4500 Ada Generation
# Epoch [0], Loss: 0.2441, Val Loss: 0.2905
# Epoch [1], Loss: 0.2395, Val Loss: 0.2856
# Epoch [2], Loss: 0.2357, Val Loss: 0.2812
# Epoch [3], Loss: 0.2323, Val Loss: 0.2771
# Epoch [4], Loss: 0.2291, Val Loss: 0.2731
# Epoch [5], Loss: 0.2260, Val Loss: 0.2690
# Epoch [6], Loss: 0.2225, Val Loss: 0.2649
# Epoch [7], Loss: 0.2191, Val Loss: 0.2605
# Epoch [8], Loss: 0.2155, Val Loss: 0.2556
# Epoch [9], Loss: 0.2115, Val Loss: 0.2500
# Epoch [10], Loss: 0.2066, Val Loss: 0.2436
# Epoch [11], Loss: 0.2012, Val Loss: 0.2360
# Epoch [12], Loss: 0.1946, Val Loss: 0.2264
# Epoch [13], Loss: 0.1859, Val Loss: 0.2142
# Epoch [14], Loss: 0.1746, Val Loss: 0.1978
# Epoch [15], Loss: 0.1592, Val Loss: 0.1750
# Epoch [16], Loss: 0.1375, Val Loss: 0.1445
# Epoch [17], Loss: 0.1129, Val Loss: 0.1137
# Epoch [18], Loss: 0.0935, Val Loss: 0.0941
# Epoch [19], Loss: 0.0778, Val Loss: 0.0719
# Epoch [20], Loss: 0.0610, Val Loss: 0.0614
# Epoch [21], Loss: 0.0531, Val Loss: 0.0530
# Epoch [22], Loss: 0.0473, Val Loss: 0.0474
# Epoch [23], Loss: 0.0449, Val Loss: 0.0456
# Epoch [24], Loss: 0.0437, Val Loss: 0.0450
# Epoch [25], Loss: 0.0426, Val Loss: 0.0439
# Epoch [26], Loss: 0.0424, Val Loss: 0.0440
# Epoch [27], Loss: 0.0421, Val Loss: 0.0436
# Epoch [28], Loss: 0.0420, Val Loss: 0.0430
# Epoch [29], Loss: 0.0417, Val Loss: 0.0434
# Epoch [30], Loss: 0.0414, Val Loss: 0.0426
# Epoch [31], Loss: 0.0413, Val Loss: 0.0426
# Epoch [32], Loss: 0.0411, Val Loss: 0.0422
# Epoch [33], Loss: 0.0409, Val Loss: 0.0418
# Epoch [34], Loss: 0.0407, Val Loss: 0.0419
# Epoch [35], Loss: 0.0406, Val Loss: 0.0414
# Epoch [36], Loss: 0.0404, Val Loss: 0.0413
# Epoch [37], Loss: 0.0402, Val Loss: 0.0412
# Epoch [38], Loss: 0.0400, Val Loss: 0.0407
# Epoch [39], Loss: 0.0399, Val Loss: 0.0405
# Epoch [40], Loss: 0.0398, Val Loss: 0.0405
# Epoch [41], Loss: 0.0396, Val Loss: 0.0400
# Epoch [42], Loss: 0.0395, Val Loss: 0.0402
# Epoch [43], Loss: 0.0393, Val Loss: 0.0397
# Epoch [44], Loss: 0.0392, Val Loss: 0.0396
# Epoch [45], Loss: 0.0390, Val Loss: 0.0394
# Epoch [46], Loss: 0.0389, Val Loss: 0.0393
# Epoch [47], Loss: 0.0388, Val Loss: 0.0390
# Epoch [48], Loss: 0.0387, Val Loss: 0.0388
# Epoch [49], Loss: 0.0385, Val Loss: 0.0388
# Epoch [50], Loss: 0.0384, Val Loss: 0.0384
# Epoch [51], Loss: 0.0383, Val Loss: 0.0384
# Epoch [52], Loss: 0.0382, Val Loss: 0.0382
# Epoch [53], Loss: 0.0381, Val Loss: 0.0381
# Epoch [54], Loss: 0.0380, Val Loss: 0.0379
# Epoch [55], Loss: 0.0378, Val Loss: 0.0377
# Epoch [56], Loss: 0.0378, Val Loss: 0.0377
# Epoch [57], Loss: 0.0377, Val Loss: 0.0375
# Epoch [58], Loss: 0.0376, Val Loss: 0.0375
# Epoch [59], Loss: 0.0375, Val Loss: 0.0372
# Epoch [60], Loss: 0.0374, Val Loss: 0.0372
# Epoch [61], Loss: 0.0373, Val Loss: 0.0371
# Epoch [62], Loss: 0.0372, Val Loss: 0.0370
# Epoch [63], Loss: 0.0371, Val Loss: 0.0369
# Epoch [64], Loss: 0.0371, Val Loss: 0.0367
# Epoch [65], Loss: 0.0370, Val Loss: 0.0367
# Epoch [66], Loss: 0.0369, Val Loss: 0.0366
# Epoch [67], Loss: 0.0369, Val Loss: 0.0365
# Epoch [68], Loss: 0.0368, Val Loss: 0.0364
# Epoch [69], Loss: 0.0367, Val Loss: 0.0363
# Epoch [70], Loss: 0.0367, Val Loss: 0.0362
# Epoch [71], Loss: 0.0366, Val Loss: 0.0362
# Epoch [72], Loss: 0.0366, Val Loss: 0.0361
# Epoch [73], Loss: 0.0365, Val Loss: 0.0360
# Epoch [74], Loss: 0.0365, Val Loss: 0.0360
# Epoch [75], Loss: 0.0365, Val Loss: 0.0360
# Epoch [76], Loss: 0.0364, Val Loss: 0.0359
# Epoch [77], Loss: 0.0364, Val Loss: 0.0359
# Epoch [78], Loss: 0.0363, Val Loss: 0.0358
# Epoch [79], Loss: 0.0362, Val Loss: 0.0359
# Epoch [80], Loss: 0.0362, Val Loss: 0.0357
# Epoch [81], Loss: 0.0362, Val Loss: 0.0357
# Epoch [82], Loss: 0.0361, Val Loss: 0.0356
# Epoch [83], Loss: 0.0361, Val Loss: 0.0356
# Epoch [84], Loss: 0.0361, Val Loss: 0.0356
# Epoch [85], Loss: 0.0360, Val Loss: 0.0356
# Epoch [86], Loss: 0.0360, Val Loss: 0.0355
# Epoch [87], Loss: 0.0360, Val Loss: 0.0355
# Epoch [88], Loss: 0.0359, Val Loss: 0.0354
# Epoch [89], Loss: 0.0359, Val Loss: 0.0354
# Epoch [90], Loss: 0.0359, Val Loss: 0.0354
# Epoch [91], Loss: 0.0359, Val Loss: 0.0354
# Epoch [92], Loss: 0.0359, Val Loss: 0.0354
# Epoch [93], Loss: 0.0359, Val Loss: 0.0353
# Epoch [94], Loss: 0.0358, Val Loss: 0.0353
# Epoch [95], Loss: 0.0358, Val Loss: 0.0353
# Epoch [96], Loss: 0.0358, Val Loss: 0.0353
# Epoch [97], Loss: 0.0358, Val Loss: 0.0353
# Epoch [98], Loss: 0.0357, Val Loss: 0.0352
# Epoch [99], Loss: 0.0357, Val Loss: 0.0352
# Epoch [100], Loss: 0.0357, Val Loss: 0.0352
# Epoch [101], Loss: 0.0357, Val Loss: 0.0352
# Epoch [102], Loss: 0.0357, Val Loss: 0.0352
# Epoch [103], Loss: 0.0358, Val Loss: 0.0352
# Epoch [104], Loss: 0.0357, Val Loss: 0.0351
# Epoch [105], Loss: 0.0356, Val Loss: 0.0351
# Epoch [106], Loss: 0.0356, Val Loss: 0.0351
# Epoch [107], Loss: 0.0356, Val Loss: 0.0351
# Epoch [108], Loss: 0.0356, Val Loss: 0.0351
# Epoch [109], Loss: 0.0356, Val Loss: 0.0351
# Epoch [110], Loss: 0.0356, Val Loss: 0.0351
# Epoch [111], Loss: 0.0356, Val Loss: 0.0351
# Epoch [112], Loss: 0.0355, Val Loss: 0.0351
# Epoch [113], Loss: 0.0355, Val Loss: 0.0351
# Epoch [114], Loss: 0.0355, Val Loss: 0.0350
# Epoch [115], Loss: 0.0355, Val Loss: 0.0350
# Epoch [116], Loss: 0.0355, Val Loss: 0.0351
# Epoch [117], Loss: 0.0355, Val Loss: 0.0350
# Epoch [118], Loss: 0.0355, Val Loss: 0.0350
# Epoch [119], Loss: 0.0355, Val Loss: 0.0350
# Epoch [120], Loss: 0.0355, Val Loss: 0.0350
# Epoch [121], Loss: 0.0354, Val Loss: 0.0350
# Epoch [122], Loss: 0.0354, Val Loss: 0.0350
# Epoch [123], Loss: 0.0355, Val Loss: 0.0350
# Epoch [124], Loss: 0.0354, Val Loss: 0.0349
# Epoch [125], Loss: 0.0354, Val Loss: 0.0349
# Epoch [126], Loss: 0.0354, Val Loss: 0.0350
# Epoch [127], Loss: 0.0354, Val Loss: 0.0349
# Epoch [128], Loss: 0.0354, Val Loss: 0.0349
# Epoch [129], Loss: 0.0354, Val Loss: 0.0349
# Epoch [130], Loss: 0.0354, Val Loss: 0.0349
# Epoch [131], Loss: 0.0354, Val Loss: 0.0349
# Epoch [132], Loss: 0.0354, Val Loss: 0.0349
# Epoch [133], Loss: 0.0354, Val Loss: 0.0349
# Epoch [134], Loss: 0.0354, Val Loss: 0.0349
# Epoch [135], Loss: 0.0353, Val Loss: 0.0349
# Epoch [136], Loss: 0.0353, Val Loss: 0.0349
# Epoch [137], Loss: 0.0353, Val Loss: 0.0349
# Epoch [138], Loss: 0.0353, Val Loss: 0.0349
# Epoch [139], Loss: 0.0353, Val Loss: 0.0348
# Epoch [140], Loss: 0.0353, Val Loss: 0.0348
# Epoch [141], Loss: 0.0353, Val Loss: 0.0348
# Epoch [142], Loss: 0.0353, Val Loss: 0.0348
# Epoch [143], Loss: 0.0353, Val Loss: 0.0349
# Epoch [144], Loss: 0.0353, Val Loss: 0.0348
# Epoch [145], Loss: 0.0352, Val Loss: 0.0348
# Epoch [146], Loss: 0.0352, Val Loss: 0.0348
# Epoch [147], Loss: 0.0352, Val Loss: 0.0348
# Epoch [148], Loss: 0.0352, Val Loss: 0.0348
# Epoch [149], Loss: 0.0353, Val Loss: 0.0348
# Epoch [150], Loss: 0.0353, Val Loss: 0.0348
# Epoch [151], Loss: 0.0353, Val Loss: 0.0348
# Epoch [152], Loss: 0.0353, Val Loss: 0.0348
# Epoch [153], Loss: 0.0352, Val Loss: 0.0348
# Epoch [154], Loss: 0.0352, Val Loss: 0.0348
# Epoch [155], Loss: 0.0352, Val Loss: 0.0348
# Epoch [156], Loss: 0.0352, Val Loss: 0.0348
# Epoch [157], Loss: 0.0352, Val Loss: 0.0347
# Epoch [158], Loss: 0.0352, Val Loss: 0.0347
# Epoch [159], Loss: 0.0352, Val Loss: 0.0347
# Epoch [160], Loss: 0.0352, Val Loss: 0.0348
# Epoch [161], Loss: 0.0351, Val Loss: 0.0347
# Epoch [162], Loss: 0.0351, Val Loss: 0.0347
# Epoch [163], Loss: 0.0351, Val Loss: 0.0347
# Epoch [164], Loss: 0.0351, Val Loss: 0.0347
# Epoch [165], Loss: 0.0351, Val Loss: 0.0347
# Epoch [166], Loss: 0.0351, Val Loss: 0.0347
# Epoch [167], Loss: 0.0351, Val Loss: 0.0348
# Epoch [168], Loss: 0.0351, Val Loss: 0.0346
# Epoch [169], Loss: 0.0351, Val Loss: 0.0346
# Epoch [170], Loss: 0.0352, Val Loss: 0.0347
# Epoch [171], Loss: 0.0351, Val Loss: 0.0346
# Epoch [172], Loss: 0.0351, Val Loss: 0.0346
# Epoch [173], Loss: 0.0351, Val Loss: 0.0347
# Epoch [174], Loss: 0.0350, Val Loss: 0.0346
# Epoch [175], Loss: 0.0350, Val Loss: 0.0348
# Epoch [176], Loss: 0.0351, Val Loss: 0.0346
# Epoch [177], Loss: 0.0351, Val Loss: 0.0346
# Epoch [178], Loss: 0.0350, Val Loss: 0.0346
# Epoch [179], Loss: 0.0350, Val Loss: 0.0346
# Epoch [180], Loss: 0.0351, Val Loss: 0.0347
# Epoch [181], Loss: 0.0350, Val Loss: 0.0346
# Epoch [182], Loss: 0.0351, Val Loss: 0.0348
# Epoch [183], Loss: 0.0351, Val Loss: 0.0347
# Epoch [184], Loss: 0.0351, Val Loss: 0.0346
# Epoch [185], Loss: 0.0350, Val Loss: 0.0345
# Epoch [186], Loss: 0.0349, Val Loss: 0.0346
# Epoch [187], Loss: 0.0349, Val Loss: 0.0345
# Epoch [188], Loss: 0.0350, Val Loss: 0.0346
# Epoch [189], Loss: 0.0350, Val Loss: 0.0345
# Epoch [190], Loss: 0.0350, Val Loss: 0.0346
# Epoch [191], Loss: 0.0350, Val Loss: 0.0346
# Epoch [192], Loss: 0.0349, Val Loss: 0.0345
# Epoch [193], Loss: 0.0349, Val Loss: 0.0345
# Epoch [194], Loss: 0.0349, Val Loss: 0.0345
# Epoch [195], Loss: 0.0349, Val Loss: 0.0345
# Epoch [196], Loss: 0.0349, Val Loss: 0.0345
# Epoch [197], Loss: 0.0349, Val Loss: 0.0345
# Epoch [198], Loss: 0.0349, Val Loss: 0.0344
# Epoch [199], Loss: 0.0349, Val Loss: 0.0344
# Epoch [200], Loss: 0.0349, Val Loss: 0.0345
# Epoch [201], Loss: 0.0349, Val Loss: 0.0344
# Epoch [202], Loss: 0.0349, Val Loss: 0.0344
# Epoch [203], Loss: 0.0348, Val Loss: 0.0345
# Epoch [204], Loss: 0.0349, Val Loss: 0.0345
# Epoch [205], Loss: 0.0349, Val Loss: 0.0347
# Epoch [206], Loss: 0.0349, Val Loss: 0.0345
# Epoch [207], Loss: 0.0350, Val Loss: 0.0344
# Epoch [208], Loss: 0.0350, Val Loss: 0.0345
# Epoch [209], Loss: 0.0349, Val Loss: 0.0344
# Epoch [210], Loss: 0.0348, Val Loss: 0.0344
# Epoch [211], Loss: 0.0348, Val Loss: 0.0344
# Epoch [212], Loss: 0.0348, Val Loss: 0.0344
# Epoch [213], Loss: 0.0348, Val Loss: 0.0343
# Epoch [214], Loss: 0.0348, Val Loss: 0.0344
# Epoch [215], Loss: 0.0348, Val Loss: 0.0343
# Epoch [216], Loss: 0.0348, Val Loss: 0.0343
# Epoch [217], Loss: 0.0347, Val Loss: 0.0343
# Epoch [218], Loss: 0.0347, Val Loss: 0.0343
# Epoch [219], Loss: 0.0347, Val Loss: 0.0343
# Epoch [220], Loss: 0.0347, Val Loss: 0.0343
# Epoch [221], Loss: 0.0347, Val Loss: 0.0343
# Epoch [222], Loss: 0.0347, Val Loss: 0.0343
# Epoch [223], Loss: 0.0347, Val Loss: 0.0343
# Epoch [224], Loss: 0.0347, Val Loss: 0.0343
# Epoch [225], Loss: 0.0347, Val Loss: 0.0343
# Epoch [226], Loss: 0.0347, Val Loss: 0.0343
# Epoch [227], Loss: 0.0347, Val Loss: 0.0342
# Epoch [228], Loss: 0.0346, Val Loss: 0.0342
# Epoch [229], Loss: 0.0346, Val Loss: 0.0342
# Epoch [230], Loss: 0.0346, Val Loss: 0.0342
# Epoch [231], Loss: 0.0346, Val Loss: 0.0342
# Epoch [232], Loss: 0.0346, Val Loss: 0.0342
# Epoch [233], Loss: 0.0346, Val Loss: 0.0342
# Epoch [234], Loss: 0.0346, Val Loss: 0.0342
# Epoch [235], Loss: 0.0346, Val Loss: 0.0342
# Epoch [236], Loss: 0.0346, Val Loss: 0.0342
# Epoch [237], Loss: 0.0346, Val Loss: 0.0342
# Epoch [238], Loss: 0.0346, Val Loss: 0.0342
# Epoch [239], Loss: 0.0346, Val Loss: 0.0341
# Epoch [240], Loss: 0.0345, Val Loss: 0.0342
# Epoch [241], Loss: 0.0345, Val Loss: 0.0341
# Epoch [242], Loss: 0.0345, Val Loss: 0.0342
# Epoch [243], Loss: 0.0345, Val Loss: 0.0342
# Epoch [244], Loss: 0.0346, Val Loss: 0.0342
# Epoch [245], Loss: 0.0346, Val Loss: 0.0341
# Epoch [246], Loss: 0.0345, Val Loss: 0.0341
# Epoch [247], Loss: 0.0345, Val Loss: 0.0343
# Epoch [248], Loss: 0.0345, Val Loss: 0.0341
# Epoch [249], Loss: 0.0345, Val Loss: 0.0341
# Epoch [250], Loss: 0.0345, Val Loss: 0.0341
# Epoch [251], Loss: 0.0344, Val Loss: 0.0340
# Epoch [252], Loss: 0.0345, Val Loss: 0.0340
# Epoch [253], Loss: 0.0345, Val Loss: 0.0341
# Epoch [254], Loss: 0.0345, Val Loss: 0.0341
# Epoch [255], Loss: 0.0344, Val Loss: 0.0340
# Epoch [256], Loss: 0.0344, Val Loss: 0.0340
# Epoch [257], Loss: 0.0344, Val Loss: 0.0340
# Epoch [258], Loss: 0.0344, Val Loss: 0.0340
# Epoch [259], Loss: 0.0344, Val Loss: 0.0340
# Epoch [260], Loss: 0.0344, Val Loss: 0.0340
# Epoch [261], Loss: 0.0344, Val Loss: 0.0340
# Epoch [262], Loss: 0.0344, Val Loss: 0.0342
# Epoch [263], Loss: 0.0344, Val Loss: 0.0340
# Epoch [264], Loss: 0.0343, Val Loss: 0.0340
# Epoch [265], Loss: 0.0344, Val Loss: 0.0339
# Epoch [266], Loss: 0.0344, Val Loss: 0.0339
# Epoch [267], Loss: 0.0343, Val Loss: 0.0339
# Epoch [268], Loss: 0.0343, Val Loss: 0.0339
# Epoch [269], Loss: 0.0343, Val Loss: 0.0340
# Epoch [270], Loss: 0.0344, Val Loss: 0.0340
# Epoch [271], Loss: 0.0343, Val Loss: 0.0341
# Epoch [272], Loss: 0.0343, Val Loss: 0.0339
# Epoch [273], Loss: 0.0343, Val Loss: 0.0338
# Epoch [274], Loss: 0.0342, Val Loss: 0.0338
# Epoch [275], Loss: 0.0342, Val Loss: 0.0338
# Epoch [276], Loss: 0.0342, Val Loss: 0.0338
# Epoch [277], Loss: 0.0342, Val Loss: 0.0338
# Epoch [278], Loss: 0.0342, Val Loss: 0.0338
# Epoch [279], Loss: 0.0342, Val Loss: 0.0338
# Epoch [280], Loss: 0.0342, Val Loss: 0.0338
# Epoch [281], Loss: 0.0341, Val Loss: 0.0338
# Epoch [282], Loss: 0.0341, Val Loss: 0.0338
# Epoch [283], Loss: 0.0341, Val Loss: 0.0337
# Epoch [284], Loss: 0.0341, Val Loss: 0.0337
# Epoch [285], Loss: 0.0341, Val Loss: 0.0337
# Epoch [286], Loss: 0.0341, Val Loss: 0.0337
# Epoch [287], Loss: 0.0341, Val Loss: 0.0337
# Epoch [288], Loss: 0.0341, Val Loss: 0.0337
# Epoch [289], Loss: 0.0340, Val Loss: 0.0337
# Epoch [290], Loss: 0.0340, Val Loss: 0.0337
# Epoch [291], Loss: 0.0341, Val Loss: 0.0337
# Epoch [292], Loss: 0.0341, Val Loss: 0.0337
# Epoch [293], Loss: 0.0340, Val Loss: 0.0337
# Epoch [294], Loss: 0.0340, Val Loss: 0.0336
# Epoch [295], Loss: 0.0340, Val Loss: 0.0336
# Epoch [296], Loss: 0.0340, Val Loss: 0.0337
# Epoch [297], Loss: 0.0340, Val Loss: 0.0336
# Epoch [298], Loss: 0.0339, Val Loss: 0.0336
# Epoch [299], Loss: 0.0339, Val Loss: 0.0336
# Epoch [300], Loss: 0.0339, Val Loss: 0.0336
# Epoch [301], Loss: 0.0339, Val Loss: 0.0336
# Epoch [302], Loss: 0.0339, Val Loss: 0.0336
# Epoch [303], Loss: 0.0339, Val Loss: 0.0336
# Epoch [304], Loss: 0.0339, Val Loss: 0.0335
# Epoch [305], Loss: 0.0338, Val Loss: 0.0335
# Epoch [306], Loss: 0.0339, Val Loss: 0.0335
# Epoch [307], Loss: 0.0338, Val Loss: 0.0335
# Epoch [308], Loss: 0.0338, Val Loss: 0.0335
# Epoch [309], Loss: 0.0338, Val Loss: 0.0335
# Epoch [310], Loss: 0.0338, Val Loss: 0.0335
# Epoch [311], Loss: 0.0338, Val Loss: 0.0335
# Epoch [312], Loss: 0.0338, Val Loss: 0.0335
# Epoch [313], Loss: 0.0338, Val Loss: 0.0335
# Epoch [314], Loss: 0.0338, Val Loss: 0.0334
# Epoch [315], Loss: 0.0338, Val Loss: 0.0335
# Epoch [316], Loss: 0.0337, Val Loss: 0.0335
# Epoch [317], Loss: 0.0337, Val Loss: 0.0334
# Epoch [318], Loss: 0.0338, Val Loss: 0.0334
# Epoch [319], Loss: 0.0337, Val Loss: 0.0334
# Epoch [320], Loss: 0.0337, Val Loss: 0.0334
# Epoch [321], Loss: 0.0336, Val Loss: 0.0334
# Epoch [322], Loss: 0.0336, Val Loss: 0.0334
# Epoch [323], Loss: 0.0336, Val Loss: 0.0333
# Epoch [324], Loss: 0.0336, Val Loss: 0.0334
# Epoch [325], Loss: 0.0336, Val Loss: 0.0333
# Epoch [326], Loss: 0.0336, Val Loss: 0.0333
# Epoch [327], Loss: 0.0335, Val Loss: 0.0334
# Epoch [328], Loss: 0.0335, Val Loss: 0.0333
# Epoch [329], Loss: 0.0336, Val Loss: 0.0333
# Epoch [330], Loss: 0.0335, Val Loss: 0.0332
# Epoch [331], Loss: 0.0335, Val Loss: 0.0332
# Epoch [332], Loss: 0.0334, Val Loss: 0.0332
# Epoch [333], Loss: 0.0335, Val Loss: 0.0332
# Epoch [334], Loss: 0.0334, Val Loss: 0.0332
# Epoch [335], Loss: 0.0334, Val Loss: 0.0332
# Epoch [336], Loss: 0.0334, Val Loss: 0.0332
# Epoch [337], Loss: 0.0334, Val Loss: 0.0331
# Epoch [338], Loss: 0.0334, Val Loss: 0.0331
# Epoch [339], Loss: 0.0333, Val Loss: 0.0331
# Epoch [340], Loss: 0.0333, Val Loss: 0.0331
# Epoch [341], Loss: 0.0333, Val Loss: 0.0331
# Epoch [342], Loss: 0.0333, Val Loss: 0.0331
# Epoch [343], Loss: 0.0333, Val Loss: 0.0331
# Epoch [344], Loss: 0.0333, Val Loss: 0.0331
# Epoch [345], Loss: 0.0332, Val Loss: 0.0331
# Epoch [346], Loss: 0.0332, Val Loss: 0.0333
# Epoch [347], Loss: 0.0333, Val Loss: 0.0331
# Epoch [348], Loss: 0.0332, Val Loss: 0.0330
# Epoch [349], Loss: 0.0332, Val Loss: 0.0330
# Epoch [350], Loss: 0.0331, Val Loss: 0.0330
# Epoch [351], Loss: 0.0331, Val Loss: 0.0330
# Epoch [352], Loss: 0.0331, Val Loss: 0.0331
# Epoch [353], Loss: 0.0331, Val Loss: 0.0330
# Epoch [354], Loss: 0.0331, Val Loss: 0.0330
# Epoch [355], Loss: 0.0331, Val Loss: 0.0329
# Epoch [356], Loss: 0.0331, Val Loss: 0.0330
# Epoch [357], Loss: 0.0330, Val Loss: 0.0329
# Epoch [358], Loss: 0.0330, Val Loss: 0.0329
# Epoch [359], Loss: 0.0330, Val Loss: 0.0329
# Epoch [360], Loss: 0.0330, Val Loss: 0.0329
# Epoch [361], Loss: 0.0329, Val Loss: 0.0329
# Epoch [362], Loss: 0.0329, Val Loss: 0.0329
# Epoch [363], Loss: 0.0329, Val Loss: 0.0329
# Epoch [364], Loss: 0.0329, Val Loss: 0.0329
# Epoch [365], Loss: 0.0328, Val Loss: 0.0329
# Epoch [366], Loss: 0.0328, Val Loss: 0.0328
# Epoch [367], Loss: 0.0328, Val Loss: 0.0330
# Epoch [368], Loss: 0.0329, Val Loss: 0.0329
# Epoch [369], Loss: 0.0328, Val Loss: 0.0328
# Epoch [370], Loss: 0.0327, Val Loss: 0.0329
# Epoch [371], Loss: 0.0328, Val Loss: 0.0328
# Epoch [372], Loss: 0.0328, Val Loss: 0.0328
# Epoch [373], Loss: 0.0328, Val Loss: 0.0330
# Epoch [374], Loss: 0.0327, Val Loss: 0.0328
# Epoch [375], Loss: 0.0327, Val Loss: 0.0328
# Epoch [376], Loss: 0.0327, Val Loss: 0.0327
# Epoch [377], Loss: 0.0326, Val Loss: 0.0328
# Epoch [378], Loss: 0.0327, Val Loss: 0.0330
# Epoch [379], Loss: 0.0327, Val Loss: 0.0330
# Epoch [380], Loss: 0.0328, Val Loss: 0.0328
# Epoch [381], Loss: 0.0326, Val Loss: 0.0329
# Epoch [382], Loss: 0.0325, Val Loss: 0.0329
# Epoch [383], Loss: 0.0325, Val Loss: 0.0327
# Epoch [384], Loss: 0.0325, Val Loss: 0.0327
# Epoch [385], Loss: 0.0324, Val Loss: 0.0328
# Epoch [386], Loss: 0.0324, Val Loss: 0.0328
# Epoch [387], Loss: 0.0325, Val Loss: 0.0327
# Epoch [388], Loss: 0.0324, Val Loss: 0.0327
# Epoch [389], Loss: 0.0324, Val Loss: 0.0328
# Epoch [390], Loss: 0.0323, Val Loss: 0.0328
# Epoch [391], Loss: 0.0323, Val Loss: 0.0326
# Epoch [392], Loss: 0.0323, Val Loss: 0.0326
# Epoch [393], Loss: 0.0323, Val Loss: 0.0327
# Epoch [394], Loss: 0.0323, Val Loss: 0.0326
# Epoch [395], Loss: 0.0322, Val Loss: 0.0327
# Epoch [396], Loss: 0.0322, Val Loss: 0.0326
# Epoch [397], Loss: 0.0322, Val Loss: 0.0326
# Epoch [398], Loss: 0.0322, Val Loss: 0.0327
# Epoch [399], Loss: 0.0322, Val Loss: 0.0326
# Epoch [400], Loss: 0.0321, Val Loss: 0.0325
# Epoch [401], Loss: 0.0321, Val Loss: 0.0327
# Epoch [402], Loss: 0.0321, Val Loss: 0.0327
# Epoch [403], Loss: 0.0320, Val Loss: 0.0325
# Epoch [404], Loss: 0.0320, Val Loss: 0.0325
# Epoch [405], Loss: 0.0320, Val Loss: 0.0325
# Epoch [406], Loss: 0.0320, Val Loss: 0.0325
# Epoch [407], Loss: 0.0319, Val Loss: 0.0325
# Epoch [408], Loss: 0.0319, Val Loss: 0.0326
# Epoch [409], Loss: 0.0319, Val Loss: 0.0325
# Epoch [410], Loss: 0.0318, Val Loss: 0.0325
# Epoch [411], Loss: 0.0318, Val Loss: 0.0325
# Epoch [412], Loss: 0.0318, Val Loss: 0.0325
# Epoch [413], Loss: 0.0318, Val Loss: 0.0325
# Epoch [414], Loss: 0.0317, Val Loss: 0.0325
# Epoch [415], Loss: 0.0317, Val Loss: 0.0325
# Epoch [416], Loss: 0.0317, Val Loss: 0.0325
# Epoch [417], Loss: 0.0317, Val Loss: 0.0324
# Epoch [418], Loss: 0.0317, Val Loss: 0.0325
# Epoch [419], Loss: 0.0316, Val Loss: 0.0324
# Epoch [420], Loss: 0.0316, Val Loss: 0.0325
# Epoch [421], Loss: 0.0316, Val Loss: 0.0324
# Epoch [422], Loss: 0.0316, Val Loss: 0.0324
# Epoch [423], Loss: 0.0315, Val Loss: 0.0324
# Epoch [424], Loss: 0.0315, Val Loss: 0.0324
# Epoch [425], Loss: 0.0315, Val Loss: 0.0324
# Epoch [426], Loss: 0.0315, Val Loss: 0.0324
# Epoch [427], Loss: 0.0314, Val Loss: 0.0324
# Epoch [428], Loss: 0.0314, Val Loss: 0.0325
# Epoch [429], Loss: 0.0314, Val Loss: 0.0324
# Epoch [430], Loss: 0.0314, Val Loss: 0.0324
# Epoch [431], Loss: 0.0314, Val Loss: 0.0324
# Epoch [432], Loss: 0.0313, Val Loss: 0.0324
# Epoch [433], Loss: 0.0313, Val Loss: 0.0325
# Epoch [434], Loss: 0.0313, Val Loss: 0.0324
# Epoch [435], Loss: 0.0313, Val Loss: 0.0324
# Epoch [436], Loss: 0.0312, Val Loss: 0.0324
# Epoch [437], Loss: 0.0312, Val Loss: 0.0324
# Epoch [438], Loss: 0.0312, Val Loss: 0.0324
# Epoch [439], Loss: 0.0312, Val Loss: 0.0324
# Epoch [440], Loss: 0.0311, Val Loss: 0.0325
# Epoch [441], Loss: 0.0311, Val Loss: 0.0325
# Epoch [442], Loss: 0.0311, Val Loss: 0.0324
# Epoch [443], Loss: 0.0311, Val Loss: 0.0324
# Epoch [444], Loss: 0.0311, Val Loss: 0.0324
# Epoch [445], Loss: 0.0310, Val Loss: 0.0324
# Epoch [446], Loss: 0.0310, Val Loss: 0.0324
# Epoch [447], Loss: 0.0310, Val Loss: 0.0324
# Epoch [448], Loss: 0.0309, Val Loss: 0.0324
# Epoch [449], Loss: 0.0310, Val Loss: 0.0323
# Epoch [450], Loss: 0.0310, Val Loss: 0.0325
# Epoch [451], Loss: 0.0309, Val Loss: 0.0323
# Epoch [452], Loss: 0.0309, Val Loss: 0.0324
# Epoch [453], Loss: 0.0308, Val Loss: 0.0324
# Epoch [454], Loss: 0.0308, Val Loss: 0.0324
# Epoch [455], Loss: 0.0308, Val Loss: 0.0324
# Epoch [456], Loss: 0.0309, Val Loss: 0.0326
# Epoch [457], Loss: 0.0309, Val Loss: 0.0325
# Epoch [458], Loss: 0.0308, Val Loss: 0.0323
# Epoch [459], Loss: 0.0308, Val Loss: 0.0324
# Epoch [460], Loss: 0.0308, Val Loss: 0.0323
# Epoch [461], Loss: 0.0307, Val Loss: 0.0324
# Epoch [462], Loss: 0.0306, Val Loss: 0.0324
# Epoch [463], Loss: 0.0307, Val Loss: 0.0323
# Epoch [464], Loss: 0.0306, Val Loss: 0.0323
# Epoch [465], Loss: 0.0306, Val Loss: 0.0323
# Epoch [466], Loss: 0.0305, Val Loss: 0.0324
# Epoch [467], Loss: 0.0306, Val Loss: 0.0323
# Epoch [468], Loss: 0.0305, Val Loss: 0.0323
# Epoch [469], Loss: 0.0305, Val Loss: 0.0323
# Epoch [470], Loss: 0.0305, Val Loss: 0.0323
# Epoch [471], Loss: 0.0305, Val Loss: 0.0325
# Epoch [472], Loss: 0.0305, Val Loss: 0.0323
# Epoch [473], Loss: 0.0304, Val Loss: 0.0323
# Epoch [474], Loss: 0.0304, Val Loss: 0.0323
# Epoch [475], Loss: 0.0304, Val Loss: 0.0324
# Epoch [476], Loss: 0.0304, Val Loss: 0.0323
# Epoch [477], Loss: 0.0304, Val Loss: 0.0324
# Epoch [478], Loss: 0.0304, Val Loss: 0.0322
# Epoch [479], Loss: 0.0303, Val Loss: 0.0326
# Epoch [480], Loss: 0.0304, Val Loss: 0.0323
# Epoch [481], Loss: 0.0303, Val Loss: 0.0323
# Epoch [482], Loss: 0.0304, Val Loss: 0.0322
# Epoch [483], Loss: 0.0302, Val Loss: 0.0324
# Epoch [484], Loss: 0.0304, Val Loss: 0.0321
# Epoch [485], Loss: 0.0302, Val Loss: 0.0322
# Epoch [486], Loss: 0.0302, Val Loss: 0.0321
# Epoch [487], Loss: 0.0301, Val Loss: 0.0322
# Epoch [488], Loss: 0.0301, Val Loss: 0.0321
# Epoch [489], Loss: 0.0301, Val Loss: 0.0322
# Epoch [490], Loss: 0.0301, Val Loss: 0.0321
# Epoch [491], Loss: 0.0300, Val Loss: 0.0321
# Epoch [492], Loss: 0.0301, Val Loss: 0.0321
# Epoch [493], Loss: 0.0301, Val Loss: 0.0320
# Epoch [494], Loss: 0.0300, Val Loss: 0.0322
# Epoch [495], Loss: 0.0300, Val Loss: 0.0321
# Epoch [496], Loss: 0.0299, Val Loss: 0.0322
# Epoch [497], Loss: 0.0299, Val Loss: 0.0320
# Epoch [498], Loss: 0.0299, Val Loss: 0.0322
# Epoch [499], Loss: 0.0298, Val Loss: 0.0320
# Epoch [500], Loss: 0.0298, Val Loss: 0.0320
# Epoch [501], Loss: 0.0298, Val Loss: 0.0320
# Epoch [502], Loss: 0.0297, Val Loss: 0.0320
# Epoch [503], Loss: 0.0298, Val Loss: 0.0320
# Epoch [504], Loss: 0.0298, Val Loss: 0.0320
# Epoch [505], Loss: 0.0298, Val Loss: 0.0320
# Epoch [506], Loss: 0.0298, Val Loss: 0.0319
# Epoch [507], Loss: 0.0297, Val Loss: 0.0320
# Epoch [508], Loss: 0.0297, Val Loss: 0.0320
# Epoch [509], Loss: 0.0297, Val Loss: 0.0323
# Epoch [510], Loss: 0.0298, Val Loss: 0.0318
# Epoch [511], Loss: 0.0296, Val Loss: 0.0322
# Epoch [512], Loss: 0.0297, Val Loss: 0.0318
# Epoch [513], Loss: 0.0296, Val Loss: 0.0323
# Epoch [514], Loss: 0.0297, Val Loss: 0.0318
# Epoch [515], Loss: 0.0296, Val Loss: 0.0319
# Epoch [516], Loss: 0.0295, Val Loss: 0.0317
# Epoch [517], Loss: 0.0295, Val Loss: 0.0317
# Epoch [518], Loss: 0.0294, Val Loss: 0.0318
# Epoch [519], Loss: 0.0294, Val Loss: 0.0317
# Epoch [520], Loss: 0.0294, Val Loss: 0.0318
# Epoch [521], Loss: 0.0294, Val Loss: 0.0316
# Epoch [522], Loss: 0.0293, Val Loss: 0.0317
# Epoch [523], Loss: 0.0293, Val Loss: 0.0317
# Epoch [524], Loss: 0.0294, Val Loss: 0.0316
# Epoch [525], Loss: 0.0293, Val Loss: 0.0317
# Epoch [526], Loss: 0.0292, Val Loss: 0.0316
# Epoch [527], Loss: 0.0292, Val Loss: 0.0316
# Epoch [528], Loss: 0.0292, Val Loss: 0.0316
# Epoch [529], Loss: 0.0292, Val Loss: 0.0315
# Epoch [530], Loss: 0.0291, Val Loss: 0.0315
# Epoch [531], Loss: 0.0291, Val Loss: 0.0314
# Epoch [532], Loss: 0.0291, Val Loss: 0.0315
# Epoch [533], Loss: 0.0291, Val Loss: 0.0314
# Epoch [534], Loss: 0.0291, Val Loss: 0.0315
# Epoch [535], Loss: 0.0291, Val Loss: 0.0315
# Epoch [536], Loss: 0.0291, Val Loss: 0.0315
# Epoch [537], Loss: 0.0290, Val Loss: 0.0316
# Epoch [538], Loss: 0.0291, Val Loss: 0.0314
# Epoch [539], Loss: 0.0290, Val Loss: 0.0315
# Epoch [540], Loss: 0.0290, Val Loss: 0.0313
# Epoch [541], Loss: 0.0290, Val Loss: 0.0313
# Epoch [542], Loss: 0.0289, Val Loss: 0.0313
# Epoch [543], Loss: 0.0288, Val Loss: 0.0313
# Epoch [544], Loss: 0.0288, Val Loss: 0.0312
# Epoch [545], Loss: 0.0288, Val Loss: 0.0312
# Epoch [546], Loss: 0.0288, Val Loss: 0.0311
# Epoch [547], Loss: 0.0287, Val Loss: 0.0312
# Epoch [548], Loss: 0.0287, Val Loss: 0.0311
# Epoch [549], Loss: 0.0287, Val Loss: 0.0311
# Epoch [550], Loss: 0.0286, Val Loss: 0.0311
# Epoch [551], Loss: 0.0286, Val Loss: 0.0310
# Epoch [552], Loss: 0.0286, Val Loss: 0.0311
# Epoch [553], Loss: 0.0287, Val Loss: 0.0312
# Epoch [554], Loss: 0.0287, Val Loss: 0.0310
# Epoch [555], Loss: 0.0286, Val Loss: 0.0310
# Epoch [556], Loss: 0.0286, Val Loss: 0.0309
# Epoch [557], Loss: 0.0286, Val Loss: 0.0309
# Epoch [558], Loss: 0.0286, Val Loss: 0.0309
# Epoch [559], Loss: 0.0285, Val Loss: 0.0308
# Epoch [560], Loss: 0.0285, Val Loss: 0.0309
# Epoch [561], Loss: 0.0285, Val Loss: 0.0307
# Epoch [562], Loss: 0.0285, Val Loss: 0.0311
# Epoch [563], Loss: 0.0285, Val Loss: 0.0312
# Epoch [564], Loss: 0.0286, Val Loss: 0.0308
# Epoch [565], Loss: 0.0285, Val Loss: 0.0310
# Epoch [566], Loss: 0.0285, Val Loss: 0.0310
# Epoch [567], Loss: 0.0284, Val Loss: 0.0307
# Epoch [568], Loss: 0.0284, Val Loss: 0.0309
# Epoch [569], Loss: 0.0283, Val Loss: 0.0305
# Epoch [570], Loss: 0.0283, Val Loss: 0.0306
# Epoch [571], Loss: 0.0282, Val Loss: 0.0305
# Epoch [572], Loss: 0.0282, Val Loss: 0.0305
# Epoch [573], Loss: 0.0281, Val Loss: 0.0305
# Epoch [574], Loss: 0.0281, Val Loss: 0.0304
# Epoch [575], Loss: 0.0281, Val Loss: 0.0304
# Epoch [576], Loss: 0.0281, Val Loss: 0.0304
# Epoch [577], Loss: 0.0280, Val Loss: 0.0304
# Epoch [578], Loss: 0.0280, Val Loss: 0.0303
# Epoch [579], Loss: 0.0280, Val Loss: 0.0303
# Epoch [580], Loss: 0.0279, Val Loss: 0.0303
# Epoch [581], Loss: 0.0279, Val Loss: 0.0303
# Epoch [582], Loss: 0.0279, Val Loss: 0.0302
# Epoch [583], Loss: 0.0280, Val Loss: 0.0302
# Epoch [584], Loss: 0.0279, Val Loss: 0.0301
# Epoch [585], Loss: 0.0278, Val Loss: 0.0301
# Epoch [586], Loss: 0.0278, Val Loss: 0.0301
# Epoch [587], Loss: 0.0278, Val Loss: 0.0301
# Epoch [588], Loss: 0.0277, Val Loss: 0.0301
# Epoch [589], Loss: 0.0277, Val Loss: 0.0300
# Epoch [590], Loss: 0.0277, Val Loss: 0.0302
# Epoch [591], Loss: 0.0278, Val Loss: 0.0301
# Epoch [592], Loss: 0.0278, Val Loss: 0.0299
# Epoch [593], Loss: 0.0277, Val Loss: 0.0300
# Epoch [594], Loss: 0.0276, Val Loss: 0.0299
# Epoch [595], Loss: 0.0276, Val Loss: 0.0298
# Epoch [596], Loss: 0.0276, Val Loss: 0.0299
# Epoch [597], Loss: 0.0277, Val Loss: 0.0304
# Epoch [598], Loss: 0.0278, Val Loss: 0.0296
# Epoch [599], Loss: 0.0276, Val Loss: 0.0297
# Time taken to train RNN: 188.76636457443237
# Best Epoch: 598
# Error in Output:
# tensor([[[-0.2801, -0.0735],
#          [-0.1375,  0.0109],
#          [-0.0224, -0.1217],
#          ...,
#          [-0.0745, -0.0985],
#          [ 0.0747, -0.0720],
#          [ 0.0193,  0.0644]],
#
#         [[-0.5154,  1.4151],
#          [-0.0353,  1.4478],
#          [ 0.0822,  1.2582],
#          ...,
#          [ 0.0569,  0.0482],
#          [-0.0784,  0.0126],
#          [-0.0728,  0.1172]],
#
#         [[-0.2252,  1.5179],
#          [-0.0971,  2.0990],
#          [ 0.1478,  2.0692],
#          ...,
#          [-0.0880,  0.0674],
#          [ 0.1103, -0.1922],
#          [ 0.1068,  0.0325]],
#
#         ...,
#
#         [[-0.1467,  1.2515],
#          [ 0.1010,  1.2853],
#          [ 0.0883,  1.2233],
#          ...,
#          [-0.0403,  0.0984],
#          [ 0.0219, -0.0205],
#          [-0.0135,  0.1463]],
#
#         [[ 0.3549, -1.3769],
#          [ 0.0778, -1.6105],
#          [-0.0497, -1.5913],
#          ...,
#          [ 0.0479, -0.0370],
#          [-0.0302, -0.2862],
#          [-0.0183, -0.2568]],
#
#         [[-0.2027,  2.0374],
#          [-0.0305,  2.2254],
#          [ 0.1085,  1.9919],
#          ...,
#          [-0.0743, -0.0163],
#          [ 0.0615, -0.0253],
#          [ 0.0774, -0.0839]]], device='cuda:0')
# /tmp/ipykernel_288129/122517588.py:109: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(os.path.join(checkpoint_dir, 'ckpt.pth'))

# %%
# Output the final weight and bias values
print("Final Weight (Wxh):")
print(model.Wxh)
print("Final Weight (Wyh):")
print(model.Wyh)
print("Final Weight (Why):")
print(model.Why)
# Out:
# Final Weight (Wxh):
# Parameter containing:
# tensor([[ 0.2585, -0.1083,  0.1814,  0.1960,  0.1784,  0.1742,  0.2177,  0.2424,
#           0.2246,  0.1741,  0.1679,  0.0923,  0.0951,  0.1504,  0.1491, -0.2626,
#          -0.1758, -0.1275,  0.1204,  0.3295, -0.1347, -0.2708, -1.2969, -0.0062,
#          -0.0376, -0.2145, -0.0910,  0.3701,  0.1301,  0.1556,  0.2442,  0.2872,
#          -0.0344,  0.0071,  0.0085,  0.1528,  0.2031, -0.6047, -0.0816,  0.1779,
#           0.2804, -0.0978,  0.0541, -0.1330,  0.2130,  0.2111, -0.0922, -0.1880,
#          -0.1086, -0.0158]], device='cuda:0', requires_grad=True)
# Final Weight (Wyh):
# Parameter containing:
# tensor([[ 0.2340, -0.1846,  0.0994, -0.1338, -0.1437,  0.2238, -0.0601, -0.0955,
#           0.2050, -0.0552, -0.1587,  0.0982,  0.1133,  0.0066,  0.0780, -0.1957,
#          -0.0222, -0.0672,  0.0863, -0.1887,  0.0191,  0.1658,  0.5638, -0.0472,
#           0.1680,  0.2442, -0.0501, -0.1562,  0.0682,  0.1985,  0.0170, -0.0093,
#           0.2004, -0.2590, -0.1126, -0.2523,  0.0298,  0.3276,  0.1153,  0.1053,
#           0.0095, -0.1176,  0.3152,  0.1398,  0.0215,  0.1111,  0.0461, -0.0445,
#          -0.2698,  0.1537],
#         [ 0.1257, -0.1473, -0.2324,  0.0515, -0.2682,  0.1389, -0.2544,  0.3243,
#           0.0404,  0.0404, -0.3085, -0.0430, -0.0404, -0.0925, -0.1251,  0.1507,
#           0.0325,  0.0709, -0.0795,  0.0563, -0.0247, -0.0160,  0.0585,  0.1483,
#          -0.0800, -0.0205,  0.0902,  0.0470, -0.1142, -0.0564,  0.0197,  0.1405,
#          -0.0586,  0.3329, -0.1972, -0.3295,  0.0009, -0.8347,  0.1684, -0.1100,
#           0.0934,  0.0456,  0.0111,  0.2612,  0.3557, -0.1701,  0.1655,  0.0310,
#           0.0477, -0.0827]], device='cuda:0', requires_grad=True)
# Final Weight (Why):
# Parameter containing:
# tensor([[ 3.3051e-01,  9.9273e-02],
#         [-2.5837e-01, -3.0032e-01],
#         [-1.3048e-01, -3.4488e-01],
#         [ 6.0689e-02,  1.6422e-01],
#         [ 1.7837e-01, -3.9494e-01],
#         [ 3.0309e-01,  1.0940e-01],
#         [-1.2442e-02, -3.7997e-01],
#         [ 2.9686e-01, -1.8409e-01],
#         [ 1.6299e-01, -1.0642e-01],
#         [-5.8132e-02,  9.0372e-05],
#         [ 2.4630e-01, -3.2154e-01],
#         [ 6.8832e-02,  3.8669e-02],
#         [ 1.2633e-01, -3.0883e-02],
#         [ 1.6493e-01, -2.7694e-01],
#         [ 6.0794e-02, -4.0396e-01],
#         [ 7.7153e-02,  3.9937e-01],
#         [-9.7901e-02,  9.4867e-02],
#         [-3.4875e-01,  4.9564e-01],
#         [ 2.2679e-01, -4.6777e-01],
#         [-1.3075e-01,  4.1138e-01],
#         [-1.3943e-01,  6.9855e-02],
#         [-1.5884e-01, -3.1106e-01],
#         [ 4.6346e-01, -6.7825e-01],
#         [ 2.0188e-01,  4.2874e-01],
#         [-1.4843e-02, -2.7970e-01],
#         [-8.2174e-02, -2.8782e-01],
#         [-2.6359e-01, -2.2325e-02],
#         [-8.5621e-02,  3.0356e-01],
#         [ 1.2476e-01, -4.2007e-01],
#         [ 5.4670e-02, -3.0065e-01],
#         [ 4.0361e-01, -3.3240e-03],
#         [ 3.6587e-01,  2.4355e-01],
#         [ 1.4835e-01, -2.9616e-01],
#         [ 1.4985e-01, -8.1791e-02],
#         [ 4.1194e-02, -3.1875e-01],
#         [-9.2381e-02, -2.5428e-01],
#         [ 4.5081e-01,  1.5886e-02],
#         [ 1.0748e-01,  3.4789e-01],
#         [-2.4277e-02,  2.0730e-01],
#         [ 4.3788e-02, -3.5949e-01],
#         [ 3.1815e-01,  2.5569e-01],
#         [-2.5590e-01,  4.9425e-02],
#         [ 2.2203e-01, -4.7070e-01],
#         [-3.5409e-01,  1.7582e-01],
#         [ 1.7415e-01, -1.6746e-01],
#         [-3.4653e-02, -2.2819e-01],
#         [-1.3361e-01,  3.4477e-02],
#         [-3.7355e-01,  3.1376e-01],
#         [-9.9442e-03,  4.7490e-01],
#         [ 1.3194e-01, -3.5020e-01]], device='cuda:0', requires_grad=True)

# %%
print(np.shape(predicted_output))
predicted_output=predicted_output.cpu()
predicted_output=predicted_output.numpy()
all_outputs=all_outputs.cpu()
all_outputs=all_outputs.detach().numpy()
# Out:
# torch.Size([20, 300, 2])

# %%
start3=time.time()
#implementing an EKF for down pendulum

def scalar(x):
    return np.squeeze(np.asarray(x)).item()
    
def gradient_f(z):
    df=np.matrix([[0,1],[-g*np.cos(scalar(z[0]))/l, -b/m]])
    return df

def funct(w):
    func_val=np.array([w[1],-((g*np.sin(w[0]))/l)-(b/m)*w[1]])
    return func_val


X_hat_t_ekf=np.zeros((test_data_size, seq_length, dim_x))#array to store estimated state values


def prediction(X_hat_t_1,P_t_1,Q_t):
    X_hat_t_initial=np.array(X_hat_t_1.reshape(-1)).flatten()
    
    solution=scipy.integrate.solve_ivp(f,(0,2*dt),X_hat_t_initial, method='RK45', args=(l,g,m,b),dense_output=True, t_eval=np.arange(0, 2*dt, dt))
    X_hat_t_new=solution.y[:,1]
    
    Id=np.eye(dim_x)
    X_hat_t=X_hat_t_new.reshape(-1,1)
    
    F_t=Id+(1/6)*((dt*gradient_f(X_hat_t))+(2*dt*gradient_f(X_hat_t+(dt/2)*funct(X_hat_t))*(Id+(dt/2)*gradient_f(X_hat_t)))+(2*dt*gradient_f(X_hat_t+(dt/2)*funct(X_hat_t+(dt/2)*funct(X_hat_t)))*(Id+(dt/2)*gradient_f(X_hat_t+(dt/2)*funct(X_hat_t)))*(Id+(dt/2)*gradient_f(X_hat_t)))+(dt*gradient_f(X_hat_t+dt*funct(X_hat_t+(dt/2)*funct(X_hat_t+(dt/2)*funct(X_hat_t))))*(Id+dt*gradient_f(X_hat_t+(dt/2)*funct(X_hat_t+(dt/2)*funct(X_hat_t))))*(Id+(dt/2)*gradient_f(X_hat_t+(dt/2)*funct(X_hat_t)))*(Id+(dt/2)*gradient_f(X_hat_t)))) 
    P_t = F_t*P_t_1*F_t.T + Q_t
    
    return X_hat_t,P_t

def update(X_hat_t,P_t,Y_t,R_t):
    H_t=np.matrix([[1,0]])

    S = H_t*P_t*H_t.T + R_t

    K = (P_t*H_t.T) /S

    z = Y_t - (H_t*X_hat_t)         
    X_t = X_hat_t + (K*z)

    P_t = P_t - (K*H_t*P_t)

    return X_t,P_t

for seq in range(0, test_data_size, 1):
    
    P_t_minus_1=np.matrix([[0.01,0],[0,0.01]])
    Q_t=np.matrix([[0.01,0],[0,0.01]])
    R_t=np.matrix([[0.01]])
    
    #mu_x0_approx=np.random.uniform(-2,2,size=dim_x) #mean of initial condition
    #X_hat_t_ekf[seq,0,:]=np.random.multivariate_normal(mu_x0,P)
    for timestep in range(1, seq_length, 1):

        X_hat_t_step=np.transpose(np.matrix(X_hat_t_ekf[seq,timestep-1,:]))
        Y_t_step=np.matrix(Y_test[seq,timestep-1,:])

        X_hat_t_step,P_hat_t=prediction(X_hat_t_step,P_t_minus_1,Q_t)

        X_t,P_t=update(X_hat_t_step,P_hat_t,Y_t_step,R_t)

        X_hat_t_ekf[seq,timestep,:]=np.squeeze(np.asarray(X_t))

        P_t_minus_1=P_t  
        
end3=time.time()
print(end3-start3)
# Out:
# 3.800093173980713

# %%
#for plotting absolute error at each timestep averaged over test sequences
test_errors_for_ekf=np.zeros((seq_length-1,1))
for k in range(0,seq_length-1,1):
    for i in range(0,test_data_size,1):
        for j in range(0, dim_x, 1):
            test_errors_for_ekf[k]+=(X_hat_t_ekf[i,k+1,j]-X_test[i,k,j])**2
test_errors_for_ekf=test_errors_for_ekf/(dim_x*test_data_size)

# %%
#for plotting absolute error at each timestep averaged over test sequences
test_errors_for_jrn=np.zeros((seq_length-1,1))
for k in range(0,seq_length-1,1):
    for i in range(0,test_data_size,1):
        for j in range(0, dim_x, 1):
            test_errors_for_jrn[k]+=(predicted_output[i,k,j]-X_test[i,k,j])**2
test_errors_for_jrn=test_errors_for_jrn/(dim_x*test_data_size)

# %%
# Compute squared error
jrn_squared_error = (predicted_output - X_test) ** 2

# Compute mean squared error over all samples, timesteps, and dimensions
jrn_mse = np.mean(jrn_squared_error)

# Root mean squared error
jrn_rmse = np.sqrt(jrn_mse)

print(f"JRN RMSE: {jrn_rmse}")
# Out:
# JRN RMSE: 0.1700305612913123

# %%
# Extract test portion of X_hat_t_ekf
X_hat_test = X_hat_t_ekf[:, 1:, :] 

# Compute squared error
ekf_squared_error = (X_hat_test - X_test) ** 2

# Compute mean squared error across all samples, timesteps, and dimensions
ekf_mse = np.mean(ekf_squared_error)

# Root mean squared error
ekf_rmse = np.sqrt(ekf_mse)

print(f"EKF RMSE: {ekf_rmse}")
# Out:
# EKF RMSE: 0.19207615315483295

# %%
print(best_epoch)
# Out:
# 598

# %%
H = np.array([1, 0])  # measurement matrix, shape (n,)

def f(t,x):
    x1,x2=x
    dx_dt = [0,0]
    dx_dt[0] = x2
    dx_dt[1] = -(g*np.sin(x1))/l-b/m*x2
    return dx_dt
    
start4= time.time()
def generate_sigma_points(x, P, alpha=1e-3, beta=2, kappa=0):
    n = x.shape[0]
    lambda_ = alpha**2 * (n + kappa) - n
    c = n + lambda_
    Wm = np.full(2 * n + 1, 0.5 / c)
    Wc = np.full(2 * n + 1, 0.5 / c)
    Wm[0] = lambda_ / c
    Wc[0] = lambda_ / c + (1 - alpha**2 + beta)

    U = np.linalg.cholesky(c * P)
    sigma_points = np.zeros((2 * n + 1, n))
    sigma_points[0] = x
    for i in range(n):
        sigma_points[i + 1] = x + U[:, i]
        sigma_points[n + i + 1] = x - U[:, i]
    return sigma_points, Wm, Wc

def unscented_transform(sigma_points, Wm, Wc, noise_cov):
    # For state (vector) sigma points
    mean = np.sum(Wm[:, None] * sigma_points, axis=0)  # shape (n,)
    diff = sigma_points - mean
    cov = np.zeros((mean.size, mean.size))
    for i in range(len(sigma_points)):
        cov += Wc[i] * np.outer(diff[i], diff[i])
    cov += noise_cov
    return mean, cov

def unscented_transform_meas(sigma_points, Wm, Wc, noise_cov):
    # For scalar measurement sigma points
    mean = np.sum(Wm * sigma_points)  # scalar
    diff = sigma_points - mean
    cov = np.sum(Wc * diff * diff) + noise_cov  # scalar
    return mean, cov

dt = 0.1

def ukf_predict(x, P, Q):
    sigma_points, Wm, Wc = generate_sigma_points(x, P)
    
    propagated_sigma = []
    for sp in sigma_points:
        sol = scipy.integrate.solve_ivp(f, [0, dt], sp, method='RK45', t_eval=[dt])
        propagated_sigma.append(sol.y[:, -1])
    propagated_sigma = np.array(propagated_sigma)  
    
    x_pred, P_pred = unscented_transform(propagated_sigma, Wm, Wc, Q)
    return x_pred, P_pred, propagated_sigma, Wm, Wc

def ukf_update(x_pred, P_pred, propagated_sigma, Wm, Wc, y, R):
    meas_sigma = propagated_sigma @ H  
    
    y_pred, P_yy = unscented_transform_meas(meas_sigma, Wm, Wc, R)
    
    P_xy = np.zeros((x_pred.size, 1))
    for i in range(len(propagated_sigma)):
        dx = propagated_sigma[i] - x_pred   # (n,)
        dy = meas_sigma[i] - y_pred         # scalar
        P_xy += Wc[i] * dx[:, None] * dy   # (n,1)
    
    K = P_xy / P_yy                        # Kalman gain (n,1)
    
    x_new = x_pred + K.flatten() * (y - y_pred)
    P_new = P_pred - (K * P_yy) @ K.T
    return x_new, P_new

x_t = np.array([0.0, 0.0])
P_t = P            

X_hat_ukf = np.zeros((test_data_size, seq_length, dim_x))
X_hat_ukf[:,0,:] = x_t

for i in range(0, test_data_size, 1):
    for t in range(1, seq_length):
        # Prediction step
        x_pred, P_pred, propagated_sigma, Wm, Wc = ukf_predict(x_t, P_t, Q)
        y_t = Y_test[i,t-1,:]
        
        # Update step
        x_t, P_t = ukf_update(x_pred, P_pred, propagated_sigma, Wm, Wc, y_t, R)
        X_hat_ukf[i,t,:] = x_t

print("UKF estimation done.")

end4=time.time()
print("Time taken to run UKF:", end4-start4)
# Out:
# UKF estimation done.
# Time taken to run UKF: 10.404922246932983

# %%
X_hat_test_ukf = X_hat_ukf[:, 1:, :]
ukf_squared_error = (X_hat_test_ukf - X_test) ** 2
ukf_rmse = np.sqrt(np.mean(ukf_squared_error))
print(f"UKF RMSE: {ukf_rmse}")
# Out:
# UKF RMSE: 0.20243318749172542

# %%
#for plotting absolute error at each timestep averaged over test sequences
test_errors_for_ukf=np.zeros((seq_length-1,1))
for k in range(0,seq_length-1,1):
    for i in range(0,test_data_size,1):
        for j in range(0, dim_x, 1):
            test_errors_for_ukf[k]+=(X_hat_ukf[i,k+1,j]-X_test[i,k,j])**2
test_errors_for_ukf=test_errors_for_ukf/(dim_x*test_data_size)

# %%
matplotlib.rc('xtick', labelsize=15) 
matplotlib.rc('ytick', labelsize=15) 

t2=[i for i in range(0,seq_length-1, 1)] #change timesteps here if needful
f1=plt.figure()
f1.set_figwidth(10)
f1.set_figheight(5)
plt.plot(t2,test_errors_for_jrn[:,:],label="JRN error",linestyle='dashed')
plt.plot(t2,test_errors_for_ekf[:,:],label="EKF error")
plt.plot(t2,test_errors_for_ukf[:,:],label="UKF error")
#plt.title(f"x{i+1}")
plt.xlabel("Time-steps", fontsize=15)
#plt.xlim(0,100)
plt.ylabel("Error", fontsize=15)
plt.legend(fontsize=15)
plt.show()
f1.savefig("downpendulum_errors.png")
f1.savefig("downpendulum_errors.svg")

# %%
print(f"UKF RMSE: {ukf_rmse}")
print(f"EKF RMSE: {ekf_rmse}")
print(f"JRN RMSE: {jrn_rmse}")
print(f"Best Epoch: {best_epoch}")
# Out:
# UKF RMSE: 0.20243318749172542
# EKF RMSE: 0.19207615315483295
# JRN RMSE: 0.1700305612913123
# Best Epoch: 598

# %%
np.savez("downpendseq_data.npz", X_data=X_data_array[:,:,:], Y_data=Y_data_array[:,:,:])
