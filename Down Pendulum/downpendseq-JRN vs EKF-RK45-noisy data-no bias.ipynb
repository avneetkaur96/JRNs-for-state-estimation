# %%
#down pendulum EKF vs JRN comparison for 2 dimensions
import numpy as np
import tensorflow as tf
from keras.callbacks import EarlyStopping
from numpy import linalg
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import math
import matplotlib.pyplot as plt
from scipy.signal import cont2discrete, lti, dlti, dstep
import scipy.integrate
import time
from mpl_toolkits import mplot3d
import matplotlib
from keras.callbacks import EarlyStopping
from keras.models import Sequential
#from keras.layers import Dense, SimpleRNN, LSTM
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset  
import os
# Out:
# 2025-06-28 15:04:45.547468: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751137485.561414  388753 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751137485.565573  388753 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-28 15:04:45.580944: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print(tf.config.list_physical_devices())
start=time.time()

# Simulation variables
seq_length = 301 # Number of time steps in each sequence
num_records = 200 # Number of sequences to generate
dim_y = 1  # No. of observables
dim_x= 2 # Number of states
dt=0.1
end_t=seq_length*dt

# Arrays to store results
X_data_array = np.empty((num_records, seq_length, dim_x))
Y_data_array = np.empty((num_records, seq_length, dim_y))
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU')]

# %%
# Continuous-time model
def f(t,x,l,g,m,b):
    x1,x2=x
    dx_dt = [0,0]
    dx_dt[0] = x2
    dx_dt[1] = -(g*np.sin(x1))/l-b/m*x2
    return dx_dt

# Parameters
l=1
g=9.8 
m=2
b=0.9

P=0.01*np.identity(dim_x) #covariance of initial condition
mu_pn = np.zeros(dim_x) #mean of process noise
Q=0.01*np.identity(dim_x) #process noise covariance
mu_mn=np.zeros(dim_y) #mean of measurement noise
R=[0.01] #measurement noise covariance
G=np.identity(dim_x) #process noise coefficient matrix

t_span= np.arange(0,end_t,dt)
num_timesteps=np.shape(t_span)[0]

for i in range(0, num_records, 1):
    mu_x0=np.random.uniform(-1,1,size=dim_x) #mean of initial condition
    x0_old=np.random.multivariate_normal(mu_x0,P)
    sol=scipy.integrate.solve_ivp(f,(0,end_t),x0_old, method='RK45', args=(l,g,m,b),dense_output=True, t_eval=np.arange(0, end_t, dt))
    X_data_array[i,:,:]=np.transpose(sol.y)
    for j in range(1,seq_length,1):
        w=np.random.multivariate_normal(mu_pn,Q) 
        X_data_array[i,j,:]=X_data_array[i,j,:]+np.matmul(G,w)
        v=np.random.normal(mu_mn,R)   #change to multivariate if R has greater than 1 dimension
        Y_data_array[i,j,:]=np.matmul(X_data_array[i,j,:],[[1],[0]])+v

# %%
plt.plot(t_span,X_data_array[199,:,0],'b-',label='x1')
plt.plot(t_span,X_data_array[199,:,1],'r--',label='x2')
plt.ylabel('Plot')
plt.xlabel('Time')
plt.legend(loc='best')
plt.show()

# %%
plt.plot(t_span,sol.y[0,:],'b-',label='x1')
plt.plot(t_span,sol.y[1,:],'r--',label='x2')
plt.ylabel('Plot')
plt.xlabel('Time')
plt.legend(loc='best')
plt.show()

# %%
num_data_pts = seq_length*num_records
num_train_pts = np.floor(0.80*num_records).astype(int)
num_val_pts = np.floor(0.10*num_records).astype(int)
test_data_size = num_records-num_train_pts-num_val_pts

Y_train = Y_data_array[0:num_train_pts,1:,:]
X_train = X_data_array[0:num_train_pts,1:,:]
num_train_plus_val = num_train_pts+num_val_pts

Y_validate = Y_data_array[num_train_pts:num_train_plus_val,1:,:]
X_validate = X_data_array[num_train_pts:num_train_plus_val,1:,:]

Y_test = Y_data_array[num_train_plus_val:num_records,1:,:]
X_test = X_data_array[num_train_plus_val:num_records,1:,:]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
print("Device name:", torch.cuda.get_device_name(0))
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = True

# Convert data to PyTorch tensors
input_data = torch.tensor(Y_train, dtype=torch.float32)
output_data = torch.tensor(X_train, dtype=torch.float32)

# Define validation data
val_input_data = torch.tensor(Y_validate, dtype=torch.float32) 
val_output_data = torch.tensor(X_validate, dtype=torch.float32)  

test_input_data=torch.tensor(Y_test, dtype=torch.float32)
test_output_data=torch.tensor(X_test, dtype=torch.float32)

#proposed jrn implementation
start=time.time()

# Initialize variables for early stopping
best_val_loss = float('inf')  # Set initial best validation loss to infinity
patience = 25  # Number of epochs to wait for improvement
counter = 0  # Counter to track the number of epochs with no improvement

checkpoint_dir = './dp_torch_checkpoints_jrn'
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
    
# Define the model
class JRN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(JRN, self).__init__()
        self.output_size=output_size 
        self.Why = nn.Parameter(torch.empty(hidden_size, output_size))
        nn.init.xavier_uniform_(self.Why)
        self.Wyh = nn.Parameter(torch.empty(output_size, hidden_size))
        self.Wxh = nn.Parameter(torch.empty(input_size, hidden_size))
        nn.init.orthogonal_(self.Wyh)  
        nn.init.orthogonal_(self.Wxh)
        #self.bh = nn.Parameter(torch.zeros(hidden_size))
        #self.by = nn.Parameter(torch.zeros(output_size))

    def forward(self, x):
        batch_size, seq_len, _ = x.size()
        y = torch.zeros(batch_size, self.output_size, device=x.device)
        outputs = []
        for i in range(seq_len):
            h = torch.tanh(torch.matmul(x[:, i, :], self.Wxh) + torch.matmul(y, self.Wyh))
            y = torch.matmul(h, self.Why) 
            outputs.append(y.unsqueeze(1))
        return torch.cat(outputs, dim=1)

# Create DataLoader for training data
train_dataset = TensorDataset(input_data, output_data)
train_loader = DataLoader(train_dataset, batch_size=40, shuffle=True)

# Define the model, loss function, and optimizer
hidden_size = 50
model = JRN(dim_y, hidden_size, dim_x).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
best_epoch=0

# Training the model
num_epochs = 600
start_time = time.time()
for epoch in range(num_epochs):
    total_loss = 0.0
    for batch_Y, batch_X in train_loader:
        batch_Y=batch_Y.to(device)
        batch_X=batch_X.to(device)
        # Forward pass
        all_outputs = model(batch_Y)

        # Compute the loss
        loss = criterion(all_outputs, batch_X)
        total_loss += loss.item()

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Validation
    with torch.no_grad():
        val_loss = criterion(model(val_input_data.to(device)), val_output_data.to(device))

    # Print and check for early stopping
    print(f'Epoch [{epoch}], Loss: {total_loss / len(train_loader):.4f}, Val Loss: {val_loss.item():.4f}')

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
        best_epoch = epoch
        torch.save({'model_state_dict': model.state_dict()}, os.path.join(checkpoint_dir, 'ckpt.pth'))
    else:
        counter += 1
        if counter >= patience:
            print(f'Early stopping at epoch {epoch+1} as validation loss did not improve for {patience} epochs.')
            break

end_time = time.time()
print("Time taken to train RNN:", end_time - start_time)

print("Best Epoch:", best_epoch)

# Restore best model
checkpoint = torch.load(os.path.join(checkpoint_dir, 'ckpt.pth'))
model.load_state_dict(checkpoint['model_state_dict'])

# Test the model
with torch.no_grad():
    predicted_output = model(test_input_data.to(device))
    print("Error in Output:")
    print(predicted_output.to(device) - test_output_data.to(device))
# Out:
# Using device: cuda
# Device name: NVIDIA RTX 4500 Ada Generation
# Epoch [0], Loss: 0.0952, Val Loss: 0.0815
# Epoch [1], Loss: 0.0822, Val Loss: 0.0546
# Epoch [2], Loss: 0.3765, Val Loss: 0.0417
# Epoch [3], Loss: 0.0524, Val Loss: 0.0625
# Epoch [4], Loss: 0.0698, Val Loss: 0.0691
# Epoch [5], Loss: 0.0744, Val Loss: 0.0703
# Epoch [6], Loss: 0.0751, Val Loss: 0.0698
# Epoch [7], Loss: 0.0745, Val Loss: 0.0689
# Epoch [8], Loss: 0.0737, Val Loss: 0.0680
# Epoch [9], Loss: 0.0727, Val Loss: 0.0670
# Epoch [10], Loss: 0.0718, Val Loss: 0.0661
# Epoch [11], Loss: 0.0707, Val Loss: 0.0650
# Epoch [12], Loss: 0.0696, Val Loss: 0.0638
# Epoch [13], Loss: 0.0682, Val Loss: 0.0624
# Epoch [14], Loss: 0.0665, Val Loss: 0.0606
# Epoch [15], Loss: 0.0644, Val Loss: 0.0584
# Epoch [16], Loss: 0.0617, Val Loss: 0.0555
# Epoch [17], Loss: 0.0582, Val Loss: 0.0516
# Epoch [18], Loss: 0.0532, Val Loss: 0.0468
# Epoch [19], Loss: 0.0481, Val Loss: 0.0427
# Epoch [20], Loss: 0.0451, Val Loss: 0.0417
# Epoch [21], Loss: 0.0444, Val Loss: 0.0407
# Epoch [22], Loss: 0.0430, Val Loss: 0.0386
# Epoch [23], Loss: 0.0409, Val Loss: 0.0377
# Epoch [24], Loss: 0.0401, Val Loss: 0.0374
# Epoch [25], Loss: 0.0393, Val Loss: 0.0364
# Epoch [26], Loss: 0.0385, Val Loss: 0.0356
# Epoch [27], Loss: 0.0379, Val Loss: 0.0352
# Epoch [28], Loss: 0.0374, Val Loss: 0.0347
# Epoch [29], Loss: 0.0369, Val Loss: 0.0343
# Epoch [30], Loss: 0.0365, Val Loss: 0.0340
# Epoch [31], Loss: 0.0361, Val Loss: 0.0337
# Epoch [32], Loss: 0.0358, Val Loss: 0.0334
# Epoch [33], Loss: 0.0355, Val Loss: 0.0331
# Epoch [34], Loss: 0.0352, Val Loss: 0.0328
# Epoch [35], Loss: 0.0349, Val Loss: 0.0326
# Epoch [36], Loss: 0.0346, Val Loss: 0.0324
# Epoch [37], Loss: 0.0344, Val Loss: 0.0322
# Epoch [38], Loss: 0.0341, Val Loss: 0.0319
# Epoch [39], Loss: 0.0339, Val Loss: 0.0317
# Epoch [40], Loss: 0.0337, Val Loss: 0.0315
# Epoch [41], Loss: 0.0334, Val Loss: 0.0312
# Epoch [42], Loss: 0.0332, Val Loss: 0.0311
# Epoch [43], Loss: 0.0330, Val Loss: 0.0309
# Epoch [44], Loss: 0.0328, Val Loss: 0.0306
# Epoch [45], Loss: 0.0326, Val Loss: 0.0305
# Epoch [46], Loss: 0.0324, Val Loss: 0.0303
# Epoch [47], Loss: 0.0321, Val Loss: 0.0301
# Epoch [48], Loss: 0.0320, Val Loss: 0.0299
# Epoch [49], Loss: 0.0318, Val Loss: 0.0298
# Epoch [50], Loss: 0.0316, Val Loss: 0.0296
# Epoch [51], Loss: 0.0314, Val Loss: 0.0294
# Epoch [52], Loss: 0.0312, Val Loss: 0.0293
# Epoch [53], Loss: 0.0311, Val Loss: 0.0291
# Epoch [54], Loss: 0.0309, Val Loss: 0.0289
# Epoch [55], Loss: 0.0308, Val Loss: 0.0288
# Epoch [56], Loss: 0.0307, Val Loss: 0.0287
# Epoch [57], Loss: 0.0305, Val Loss: 0.0285
# Epoch [58], Loss: 0.0303, Val Loss: 0.0285
# Epoch [59], Loss: 0.0302, Val Loss: 0.0283
# Epoch [60], Loss: 0.0301, Val Loss: 0.0282
# Epoch [61], Loss: 0.0299, Val Loss: 0.0280
# Epoch [62], Loss: 0.0298, Val Loss: 0.0280
# Epoch [63], Loss: 0.0297, Val Loss: 0.0279
# Epoch [64], Loss: 0.0296, Val Loss: 0.0277
# Epoch [65], Loss: 0.0294, Val Loss: 0.0276
# Epoch [66], Loss: 0.0293, Val Loss: 0.0275
# Epoch [67], Loss: 0.0292, Val Loss: 0.0274
# Epoch [68], Loss: 0.0292, Val Loss: 0.0273
# Epoch [69], Loss: 0.0291, Val Loss: 0.0272
# Epoch [70], Loss: 0.0290, Val Loss: 0.0272
# Epoch [71], Loss: 0.0289, Val Loss: 0.0270
# Epoch [72], Loss: 0.0289, Val Loss: 0.0272
# Epoch [73], Loss: 0.0287, Val Loss: 0.0270
# Epoch [74], Loss: 0.0288, Val Loss: 0.0275
# Epoch [75], Loss: 0.0287, Val Loss: 0.0268
# Epoch [76], Loss: 0.0287, Val Loss: 0.0267
# Epoch [77], Loss: 0.0283, Val Loss: 0.0265
# Epoch [78], Loss: 0.0283, Val Loss: 0.0265
# Epoch [79], Loss: 0.0282, Val Loss: 0.0267
# Epoch [80], Loss: 0.0281, Val Loss: 0.0263
# Epoch [81], Loss: 0.0280, Val Loss: 0.0264
# Epoch [82], Loss: 0.0280, Val Loss: 0.0263
# Epoch [83], Loss: 0.0280, Val Loss: 0.0262
# Epoch [84], Loss: 0.0280, Val Loss: 0.0269
# Epoch [85], Loss: 0.0281, Val Loss: 0.0263
# Epoch [86], Loss: 0.0281, Val Loss: 0.0261
# Epoch [87], Loss: 0.0277, Val Loss: 0.0259
# Epoch [88], Loss: 0.0276, Val Loss: 0.0258
# Epoch [89], Loss: 0.0275, Val Loss: 0.0259
# Epoch [90], Loss: 0.0275, Val Loss: 0.0257
# Epoch [91], Loss: 0.0275, Val Loss: 0.0256
# Epoch [92], Loss: 0.0273, Val Loss: 0.0259
# Epoch [93], Loss: 0.0274, Val Loss: 0.0255
# Epoch [94], Loss: 0.0272, Val Loss: 0.0256
# Epoch [95], Loss: 0.0271, Val Loss: 0.0254
# Epoch [96], Loss: 0.0270, Val Loss: 0.0253
# Epoch [97], Loss: 0.0269, Val Loss: 0.0255
# Epoch [98], Loss: 0.0269, Val Loss: 0.0252
# Epoch [99], Loss: 0.0268, Val Loss: 0.0252
# Epoch [100], Loss: 0.0267, Val Loss: 0.0250
# Epoch [101], Loss: 0.0267, Val Loss: 0.0253
# Epoch [102], Loss: 0.0267, Val Loss: 0.0249
# Epoch [103], Loss: 0.0265, Val Loss: 0.0249
# Epoch [104], Loss: 0.0265, Val Loss: 0.0248
# Epoch [105], Loss: 0.0264, Val Loss: 0.0252
# Epoch [106], Loss: 0.0265, Val Loss: 0.0247
# Epoch [107], Loss: 0.0263, Val Loss: 0.0248
# Epoch [108], Loss: 0.0262, Val Loss: 0.0245
# Epoch [109], Loss: 0.0261, Val Loss: 0.0244
# Epoch [110], Loss: 0.0260, Val Loss: 0.0243
# Epoch [111], Loss: 0.0259, Val Loss: 0.0245
# Epoch [112], Loss: 0.0258, Val Loss: 0.0241
# Epoch [113], Loss: 0.0257, Val Loss: 0.0243
# Epoch [114], Loss: 0.0256, Val Loss: 0.0240
# Epoch [115], Loss: 0.0256, Val Loss: 0.0239
# Epoch [116], Loss: 0.0255, Val Loss: 0.0239
# Epoch [117], Loss: 0.0254, Val Loss: 0.0237
# Epoch [118], Loss: 0.0254, Val Loss: 0.0235
# Epoch [119], Loss: 0.0253, Val Loss: 0.0236
# Epoch [120], Loss: 0.0250, Val Loss: 0.0233
# Epoch [121], Loss: 0.0249, Val Loss: 0.0231
# Epoch [122], Loss: 0.0248, Val Loss: 0.0231
# Epoch [123], Loss: 0.0245, Val Loss: 0.0228
# Epoch [124], Loss: 0.0244, Val Loss: 0.0226
# Epoch [125], Loss: 0.0241, Val Loss: 0.0225
# Epoch [126], Loss: 0.0240, Val Loss: 0.0223
# Epoch [127], Loss: 0.0237, Val Loss: 0.0219
# Epoch [128], Loss: 0.0235, Val Loss: 0.0216
# Epoch [129], Loss: 0.0232, Val Loss: 0.0213
# Epoch [130], Loss: 0.0229, Val Loss: 0.0212
# Epoch [131], Loss: 0.0226, Val Loss: 0.0213
# Epoch [132], Loss: 0.0224, Val Loss: 0.0204
# Epoch [133], Loss: 0.0221, Val Loss: 0.0202
# Epoch [134], Loss: 0.0218, Val Loss: 0.0199
# Epoch [135], Loss: 0.0217, Val Loss: 0.0199
# Epoch [136], Loss: 0.0215, Val Loss: 0.0196
# Epoch [137], Loss: 0.0213, Val Loss: 0.0198
# Epoch [138], Loss: 0.0211, Val Loss: 0.0194
# Epoch [139], Loss: 0.0210, Val Loss: 0.0192
# Epoch [140], Loss: 0.0209, Val Loss: 0.0193
# Epoch [141], Loss: 0.0210, Val Loss: 0.0192
# Epoch [142], Loss: 0.0209, Val Loss: 0.0190
# Epoch [143], Loss: 0.0206, Val Loss: 0.0193
# Epoch [144], Loss: 0.0207, Val Loss: 0.0190
# Epoch [145], Loss: 0.0205, Val Loss: 0.0187
# Epoch [146], Loss: 0.0204, Val Loss: 0.0187
# Epoch [147], Loss: 0.0204, Val Loss: 0.0186
# Epoch [148], Loss: 0.0203, Val Loss: 0.0191
# Epoch [149], Loss: 0.0205, Val Loss: 0.0190
# Epoch [150], Loss: 0.0203, Val Loss: 0.0184
# Epoch [151], Loss: 0.0200, Val Loss: 0.0184
# Epoch [152], Loss: 0.0200, Val Loss: 0.0183
# Epoch [153], Loss: 0.0199, Val Loss: 0.0183
# Epoch [154], Loss: 0.0199, Val Loss: 0.0181
# Epoch [155], Loss: 0.0198, Val Loss: 0.0181
# Epoch [156], Loss: 0.0198, Val Loss: 0.0180
# Epoch [157], Loss: 0.0197, Val Loss: 0.0180
# Epoch [158], Loss: 0.0196, Val Loss: 0.0180
# Epoch [159], Loss: 0.0195, Val Loss: 0.0179
# Epoch [160], Loss: 0.0195, Val Loss: 0.0178
# Epoch [161], Loss: 0.0194, Val Loss: 0.0177
# Epoch [162], Loss: 0.0194, Val Loss: 0.0177
# Epoch [163], Loss: 0.0193, Val Loss: 0.0177
# Epoch [164], Loss: 0.0192, Val Loss: 0.0176
# Epoch [165], Loss: 0.0192, Val Loss: 0.0175
# Epoch [166], Loss: 0.0192, Val Loss: 0.0175
# Epoch [167], Loss: 0.0191, Val Loss: 0.0174
# Epoch [168], Loss: 0.0190, Val Loss: 0.0173
# Epoch [169], Loss: 0.0190, Val Loss: 0.0173
# Epoch [170], Loss: 0.0192, Val Loss: 0.0173
# Epoch [171], Loss: 0.0191, Val Loss: 0.0173
# Epoch [172], Loss: 0.0190, Val Loss: 0.0174
# Epoch [173], Loss: 0.0189, Val Loss: 0.0171
# Epoch [174], Loss: 0.0187, Val Loss: 0.0173
# Epoch [175], Loss: 0.0187, Val Loss: 0.0171
# Epoch [176], Loss: 0.0187, Val Loss: 0.0171
# Epoch [177], Loss: 0.0188, Val Loss: 0.0169
# Epoch [178], Loss: 0.0187, Val Loss: 0.0171
# Epoch [179], Loss: 0.0188, Val Loss: 0.0169
# Epoch [180], Loss: 0.0185, Val Loss: 0.0168
# Epoch [181], Loss: 0.0184, Val Loss: 0.0167
# Epoch [182], Loss: 0.0185, Val Loss: 0.0167
# Epoch [183], Loss: 0.0184, Val Loss: 0.0167
# Epoch [184], Loss: 0.0183, Val Loss: 0.0167
# Epoch [185], Loss: 0.0183, Val Loss: 0.0166
# Epoch [186], Loss: 0.0184, Val Loss: 0.0167
# Epoch [187], Loss: 0.0185, Val Loss: 0.0166
# Epoch [188], Loss: 0.0184, Val Loss: 0.0166
# Epoch [189], Loss: 0.0182, Val Loss: 0.0165
# Epoch [190], Loss: 0.0182, Val Loss: 0.0165
# Epoch [191], Loss: 0.0181, Val Loss: 0.0165
# Epoch [192], Loss: 0.0183, Val Loss: 0.0165
# Epoch [193], Loss: 0.0185, Val Loss: 0.0164
# Epoch [194], Loss: 0.0182, Val Loss: 0.0166
# Epoch [195], Loss: 0.0181, Val Loss: 0.0164
# Epoch [196], Loss: 0.0181, Val Loss: 0.0164
# Epoch [197], Loss: 0.0181, Val Loss: 0.0163
# Epoch [198], Loss: 0.0180, Val Loss: 0.0162
# Epoch [199], Loss: 0.0180, Val Loss: 0.0163
# Epoch [200], Loss: 0.0181, Val Loss: 0.0164
# Epoch [201], Loss: 0.0181, Val Loss: 0.0162
# Epoch [202], Loss: 0.0179, Val Loss: 0.0166
# Epoch [203], Loss: 0.0180, Val Loss: 0.0167
# Epoch [204], Loss: 0.0181, Val Loss: 0.0164
# Epoch [205], Loss: 0.0180, Val Loss: 0.0164
# Epoch [206], Loss: 0.0179, Val Loss: 0.0163
# Epoch [207], Loss: 0.0179, Val Loss: 0.0163
# Epoch [208], Loss: 0.0179, Val Loss: 0.0163
# Epoch [209], Loss: 0.0178, Val Loss: 0.0161
# Epoch [210], Loss: 0.0177, Val Loss: 0.0160
# Epoch [211], Loss: 0.0177, Val Loss: 0.0160
# Epoch [212], Loss: 0.0177, Val Loss: 0.0160
# Epoch [213], Loss: 0.0178, Val Loss: 0.0160
# Epoch [214], Loss: 0.0178, Val Loss: 0.0160
# Epoch [215], Loss: 0.0177, Val Loss: 0.0160
# Epoch [216], Loss: 0.0178, Val Loss: 0.0162
# Epoch [217], Loss: 0.0178, Val Loss: 0.0162
# Epoch [218], Loss: 0.0177, Val Loss: 0.0161
# Epoch [219], Loss: 0.0177, Val Loss: 0.0159
# Epoch [220], Loss: 0.0177, Val Loss: 0.0160
# Epoch [221], Loss: 0.0177, Val Loss: 0.0159
# Epoch [222], Loss: 0.0176, Val Loss: 0.0159
# Epoch [223], Loss: 0.0176, Val Loss: 0.0159
# Epoch [224], Loss: 0.0176, Val Loss: 0.0159
# Epoch [225], Loss: 0.0175, Val Loss: 0.0159
# Epoch [226], Loss: 0.0176, Val Loss: 0.0161
# Epoch [227], Loss: 0.0177, Val Loss: 0.0159
# Epoch [228], Loss: 0.0177, Val Loss: 0.0160
# Epoch [229], Loss: 0.0177, Val Loss: 0.0161
# Epoch [230], Loss: 0.0177, Val Loss: 0.0163
# Epoch [231], Loss: 0.0177, Val Loss: 0.0161
# Epoch [232], Loss: 0.0176, Val Loss: 0.0160
# Epoch [233], Loss: 0.0176, Val Loss: 0.0161
# Epoch [234], Loss: 0.0177, Val Loss: 0.0159
# Epoch [235], Loss: 0.0176, Val Loss: 0.0160
# Epoch [236], Loss: 0.0176, Val Loss: 0.0161
# Epoch [237], Loss: 0.0178, Val Loss: 0.0164
# Epoch [238], Loss: 0.0178, Val Loss: 0.0159
# Epoch [239], Loss: 0.0175, Val Loss: 0.0159
# Epoch [240], Loss: 0.0175, Val Loss: 0.0157
# Epoch [241], Loss: 0.0174, Val Loss: 0.0158
# Epoch [242], Loss: 0.0175, Val Loss: 0.0157
# Epoch [243], Loss: 0.0177, Val Loss: 0.0166
# Epoch [244], Loss: 0.0179, Val Loss: 0.0169
# Epoch [245], Loss: 0.0180, Val Loss: 0.0162
# Epoch [246], Loss: 0.0179, Val Loss: 0.0159
# Epoch [247], Loss: 0.0179, Val Loss: 0.0160
# Epoch [248], Loss: 0.0177, Val Loss: 0.0159
# Epoch [249], Loss: 0.0175, Val Loss: 0.0163
# Epoch [250], Loss: 0.0177, Val Loss: 0.0163
# Epoch [251], Loss: 0.0178, Val Loss: 0.0163
# Epoch [252], Loss: 0.0180, Val Loss: 0.0168
# Epoch [253], Loss: 0.0183, Val Loss: 0.0162
# Epoch [254], Loss: 0.0180, Val Loss: 0.0163
# Epoch [255], Loss: 0.0178, Val Loss: 0.0158
# Epoch [256], Loss: 0.0176, Val Loss: 0.0159
# Epoch [257], Loss: 0.0175, Val Loss: 0.0159
# Epoch [258], Loss: 0.0175, Val Loss: 0.0157
# Epoch [259], Loss: 0.0174, Val Loss: 0.0158
# Epoch [260], Loss: 0.0175, Val Loss: 0.0158
# Epoch [261], Loss: 0.0174, Val Loss: 0.0156
# Epoch [262], Loss: 0.0174, Val Loss: 0.0158
# Epoch [263], Loss: 0.0176, Val Loss: 0.0157
# Epoch [264], Loss: 0.0176, Val Loss: 0.0161
# Epoch [265], Loss: 0.0175, Val Loss: 0.0161
# Epoch [266], Loss: 0.0175, Val Loss: 0.0159
# Epoch [267], Loss: 0.0175, Val Loss: 0.0159
# Epoch [268], Loss: 0.0176, Val Loss: 0.0159
# Epoch [269], Loss: 0.0175, Val Loss: 0.0159
# Epoch [270], Loss: 0.0175, Val Loss: 0.0158
# Epoch [271], Loss: 0.0174, Val Loss: 0.0163
# Epoch [272], Loss: 0.0177, Val Loss: 0.0165
# Epoch [273], Loss: 0.0179, Val Loss: 0.0162
# Epoch [274], Loss: 0.0177, Val Loss: 0.0161
# Epoch [275], Loss: 0.0176, Val Loss: 0.0161
# Epoch [276], Loss: 0.0176, Val Loss: 0.0157
# Epoch [277], Loss: 0.0176, Val Loss: 0.0158
# Epoch [278], Loss: 0.0173, Val Loss: 0.0157
# Epoch [279], Loss: 0.0173, Val Loss: 0.0158
# Epoch [280], Loss: 0.0174, Val Loss: 0.0158
# Epoch [281], Loss: 0.0174, Val Loss: 0.0158
# Epoch [282], Loss: 0.0174, Val Loss: 0.0157
# Epoch [283], Loss: 0.0174, Val Loss: 0.0157
# Epoch [284], Loss: 0.0174, Val Loss: 0.0156
# Epoch [285], Loss: 0.0173, Val Loss: 0.0155
# Epoch [286], Loss: 0.0173, Val Loss: 0.0157
# Epoch [287], Loss: 0.0175, Val Loss: 0.0160
# Epoch [288], Loss: 0.0174, Val Loss: 0.0157
# Epoch [289], Loss: 0.0173, Val Loss: 0.0156
# Epoch [290], Loss: 0.0172, Val Loss: 0.0156
# Epoch [291], Loss: 0.0173, Val Loss: 0.0157
# Epoch [292], Loss: 0.0174, Val Loss: 0.0159
# Epoch [293], Loss: 0.0177, Val Loss: 0.0158
# Epoch [294], Loss: 0.0175, Val Loss: 0.0158
# Epoch [295], Loss: 0.0175, Val Loss: 0.0156
# Epoch [296], Loss: 0.0174, Val Loss: 0.0155
# Epoch [297], Loss: 0.0174, Val Loss: 0.0155
# Epoch [298], Loss: 0.0174, Val Loss: 0.0158
# Epoch [299], Loss: 0.0174, Val Loss: 0.0157
# Epoch [300], Loss: 0.0173, Val Loss: 0.0158
# Epoch [301], Loss: 0.0174, Val Loss: 0.0156
# Epoch [302], Loss: 0.0175, Val Loss: 0.0156
# Epoch [303], Loss: 0.0175, Val Loss: 0.0156
# Epoch [304], Loss: 0.0173, Val Loss: 0.0157
# Epoch [305], Loss: 0.0173, Val Loss: 0.0158
# Epoch [306], Loss: 0.0173, Val Loss: 0.0155
# Epoch [307], Loss: 0.0173, Val Loss: 0.0155
# Epoch [308], Loss: 0.0173, Val Loss: 0.0157
# Epoch [309], Loss: 0.0173, Val Loss: 0.0156
# Epoch [310], Loss: 0.0174, Val Loss: 0.0155
# Epoch [311], Loss: 0.0172, Val Loss: 0.0155
# Epoch [312], Loss: 0.0172, Val Loss: 0.0155
# Epoch [313], Loss: 0.0173, Val Loss: 0.0156
# Epoch [314], Loss: 0.0175, Val Loss: 0.0156
# Epoch [315], Loss: 0.0174, Val Loss: 0.0156
# Epoch [316], Loss: 0.0174, Val Loss: 0.0156
# Epoch [317], Loss: 0.0174, Val Loss: 0.0157
# Epoch [318], Loss: 0.0173, Val Loss: 0.0157
# Epoch [319], Loss: 0.0173, Val Loss: 0.0155
# Epoch [320], Loss: 0.0173, Val Loss: 0.0156
# Epoch [321], Loss: 0.0174, Val Loss: 0.0162
# Epoch [322], Loss: 0.0175, Val Loss: 0.0155
# Epoch [323], Loss: 0.0173, Val Loss: 0.0155
# Epoch [324], Loss: 0.0172, Val Loss: 0.0156
# Epoch [325], Loss: 0.0172, Val Loss: 0.0155
# Epoch [326], Loss: 0.0174, Val Loss: 0.0155
# Epoch [327], Loss: 0.0173, Val Loss: 0.0158
# Epoch [328], Loss: 0.0174, Val Loss: 0.0156
# Epoch [329], Loss: 0.0175, Val Loss: 0.0155
# Epoch [330], Loss: 0.0175, Val Loss: 0.0156
# Epoch [331], Loss: 0.0176, Val Loss: 0.0158
# Epoch [332], Loss: 0.0177, Val Loss: 0.0157
# Epoch [333], Loss: 0.0178, Val Loss: 0.0158
# Epoch [334], Loss: 0.0178, Val Loss: 0.0157
# Epoch [335], Loss: 0.0179, Val Loss: 0.0156
# Epoch [336], Loss: 0.0178, Val Loss: 0.0158
# Epoch [337], Loss: 0.0175, Val Loss: 0.0160
# Early stopping at epoch 338 as validation loss did not improve for 25 epochs.
# Time taken to train RNN: 101.61306238174438
# Best Epoch: 312
# Error in Output:
# tensor([[[ 1.9228e-01, -6.4582e-01],
#          [-1.6436e-01, -4.6200e-01],
#          [-1.8231e-01, -5.2053e-01],
#          ...,
#          [ 5.3256e-02, -1.5845e-01],
#          [ 2.3729e-02,  3.8259e-02],
#          [-2.1747e-02, -1.7740e-01]],
#
#         [[-1.7319e-01,  8.2245e-01],
#          [ 1.4930e-02,  6.4357e-01],
#          [ 1.0459e-01,  6.5683e-01],
#          ...,
#          [-3.5453e-02, -5.6061e-02],
#          [-9.3936e-02, -2.1675e-01],
#          [-5.3782e-02,  1.6726e-02]],
#
#         [[ 2.2954e-01,  3.0483e-01],
#          [ 1.9599e-01,  4.3386e-01],
#          [ 9.9032e-02,  1.1714e-02],
#          ...,
#          [ 1.7729e-01, -7.3929e-02],
#          [-1.2612e-01, -9.1575e-03],
#          [ 4.2109e-02, -8.2787e-02]],
#
#         ...,
#
#         [[ 1.1135e-01, -1.1827e+00],
#          [ 1.6574e-01, -1.5737e+00],
#          [ 1.0294e-01, -1.3924e+00],
#          ...,
#          [ 1.4619e-01,  1.4516e-03],
#          [ 4.8477e-02,  3.7096e-02],
#          [-6.3364e-02,  2.0364e-01]],
#
#         [[ 2.2213e-01, -7.4257e-01],
#          [ 5.6697e-02, -7.5866e-01],
#          [-1.8642e-02, -8.6944e-01],
#          ...,
#          [ 6.2287e-02,  2.2226e-01],
#          [-8.6320e-02, -4.0828e-02],
#          [-3.7288e-02,  1.6866e-01]],
#
#         [[-2.3386e-01, -3.8068e-01],
#          [-2.0153e-01, -2.9475e-02],
#          [-1.5214e-01,  3.4856e-02],
#          ...,
#          [-6.9902e-02, -3.5025e-03],
#          [ 9.8194e-02, -4.2275e-02],
#          [-9.8478e-02, -1.9755e-01]]], device='cuda:0')
# /tmp/ipykernel_388753/1296830535.py:109: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(os.path.join(checkpoint_dir, 'ckpt.pth'))

# %%
# Output the final weight and bias values
print("Final Weight (Wxh):")
print(model.Wxh)
print("Final Weight (Wyh):")
print(model.Wyh)
print("Final Weight (Why):")
print(model.Why)
# Out:
# Final Weight (Wxh):
# Parameter containing:
# tensor([[-0.1140,  0.0439, -0.3238,  0.2700,  0.0452, -0.4382,  0.2214, -0.2433,
#          -0.1157, -0.2126,  0.0531,  0.1103, -0.1372,  0.1931, -0.1770,  0.2604,
#           0.3106, -0.1300, -0.2426,  0.6030,  0.2640,  0.0964,  0.2053, -0.2922,
#           0.1671, -0.2622, -0.2435,  0.2114,  0.2597,  0.2373, -0.3134,  2.1553,
#           0.2730, -0.0258, -0.2683, -0.2195, -0.1279,  0.2932,  0.1970, -0.1146,
#           0.1975,  0.1522, -0.1705,  0.1871,  0.2056, -0.0577,  0.2288,  0.0815,
#           0.0461, -0.1441]], device='cuda:0', requires_grad=True)
# Final Weight (Wyh):
# Parameter containing:
# tensor([[ 0.0339, -0.3451, -0.1212,  0.0220, -0.2942, -0.1812, -0.1005,  0.2557,
#           0.1621, -0.0168,  0.1531, -0.0040,  0.0866,  0.0298, -0.0702, -0.0009,
#          -0.4154, -0.2520,  0.0855,  0.4797,  0.1072,  0.2040,  0.2764, -0.0112,
#           0.1596,  0.0597,  0.0607, -0.0659, -0.1365,  0.1199,  0.0903, -0.6860,
#           0.2007,  0.0089, -0.2271,  0.0666, -0.0322,  0.1811,  0.1034,  0.3887,
#          -0.1970,  0.0553,  0.0251,  0.0012,  0.1087, -0.1363,  0.0800,  0.0625,
#          -0.1200, -0.1450],
#         [-0.2406,  0.0555,  0.2076, -0.3265,  0.1260, -0.2892,  0.1068,  0.0882,
#           0.2827,  0.1325, -0.1515, -0.0595,  0.2432,  0.0954, -0.0152, -0.2474,
#           0.1093,  0.3327,  0.2901,  0.1741,  0.0231, -0.0845, -0.1553,  0.0597,
#           0.1565,  0.0622,  0.0733, -0.0768,  0.0981, -0.0422, -0.0346, -0.1281,
#          -0.0974,  0.0390,  0.0477,  0.1250,  0.1002, -0.0448, -0.2588, -0.0555,
#          -0.1266,  0.2614,  0.1439, -0.0517, -0.0922, -0.0893, -0.1155,  0.0933,
#           0.0698, -0.0533]], device='cuda:0', requires_grad=True)
# Final Weight (Why):
# Parameter containing:
# tensor([[-0.2607, -0.1797],
#         [ 0.0535,  0.1667],
#         [ 0.1623,  0.0452],
#         [ 0.0647, -0.1489],
#         [-0.0087,  0.2329],
#         [-0.0254,  0.1683],
#         [ 0.3314,  0.3180],
#         [-0.0280, -0.0388],
#         [ 0.0504,  0.1590],
#         [-0.1692,  0.0512],
#         [-0.0499, -0.2180],
#         [ 0.0518, -0.1771],
#         [-0.1985,  0.2781],
#         [ 0.2442,  0.1106],
#         [-0.0769,  0.0066],
#         [ 0.0396, -0.1901],
#         [ 0.2852,  0.1101],
#         [ 0.1771,  0.2348],
#         [-0.0427,  0.3998],
#         [ 0.3944, -0.0118],
#         [ 0.5140, -0.0575],
#         [ 0.0127, -0.1184],
#         [ 0.1727, -0.2099],
#         [-0.3124, -0.1508],
#         [-0.0695, -0.2087],
#         [-0.2225,  0.0460],
#         [-0.2878,  0.1746],
#         [ 0.2209, -0.2320],
#         [ 0.3645,  0.2839],
#         [ 0.1750, -0.1137],
#         [-0.2313, -0.1732],
#         [-0.8391,  0.4567],
#         [ 0.2105, -0.2209],
#         [ 0.0217, -0.0279],
#         [-0.4355,  0.3213],
#         [-0.2436,  0.3613],
#         [-0.1415, -0.2574],
#         [ 0.4312, -0.1981],
#         [-0.0812, -0.2951],
#         [ 0.1988, -0.0357],
#         [ 0.2711, -0.8091],
#         [ 0.2437,  0.2863],
#         [-0.2435,  0.1952],
#         [ 0.2801, -0.2416],
#         [ 0.2897, -0.2687],
#         [-0.0341,  0.0760],
#         [ 0.3755, -0.1640],
#         [ 0.0397, -0.2510],
#         [ 0.1288,  0.3307],
#         [-0.0946,  0.1220]], device='cuda:0', requires_grad=True)

# %%
print(np.shape(predicted_output))
predicted_output=predicted_output.cpu()
predicted_output=predicted_output.numpy()
all_outputs=all_outputs.cpu()
all_outputs=all_outputs.detach().numpy()
# Out:
# torch.Size([20, 300, 2])

# %%
start3=time.time()
#implementing an EKF for down pendulum

def scalar(x):
    return np.squeeze(np.asarray(x)).item()
    
def gradient_f(z):
    df=np.matrix([[0,1],[-g*np.cos(scalar(z[0]))/l, -b/m]])
    return df

def funct(w):
    func_val=np.array([w[1],-((g*np.sin(w[0]))/l)-(b/m)*w[1]])
    return func_val


X_hat_t_ekf=np.zeros((test_data_size, seq_length, dim_x))#array to store estimated state values


def prediction(X_hat_t_1,P_t_1,Q_t):
    X_hat_t_initial=np.array(X_hat_t_1.reshape(-1)).flatten()
    
    solution=scipy.integrate.solve_ivp(f,(0,2*dt),X_hat_t_initial, method='RK45', args=(l,g,m,b),dense_output=True, t_eval=np.arange(0, 2*dt, dt))
    X_hat_t_new=solution.y[:,1]
    
    Id=np.eye(dim_x)
    X_hat_t=X_hat_t_new.reshape(-1,1)
    
    F_t=Id+(1/6)*((dt*gradient_f(X_hat_t))+(2*dt*gradient_f(X_hat_t+(dt/2)*funct(X_hat_t))*(Id+(dt/2)*gradient_f(X_hat_t)))+(2*dt*gradient_f(X_hat_t+(dt/2)*funct(X_hat_t+(dt/2)*funct(X_hat_t)))*(Id+(dt/2)*gradient_f(X_hat_t+(dt/2)*funct(X_hat_t)))*(Id+(dt/2)*gradient_f(X_hat_t)))+(dt*gradient_f(X_hat_t+dt*funct(X_hat_t+(dt/2)*funct(X_hat_t+(dt/2)*funct(X_hat_t))))*(Id+dt*gradient_f(X_hat_t+(dt/2)*funct(X_hat_t+(dt/2)*funct(X_hat_t))))*(Id+(dt/2)*gradient_f(X_hat_t+(dt/2)*funct(X_hat_t)))*(Id+(dt/2)*gradient_f(X_hat_t)))) 
    P_t = F_t*P_t_1*F_t.T + Q_t
    
    return X_hat_t,P_t

def update(X_hat_t,P_t,Y_t,R_t):
    H_t=np.matrix([[1,0]])

    S = H_t*P_t*H_t.T + R_t

    K = (P_t*H_t.T) /S

    z = Y_t - (H_t*X_hat_t)         
    X_t = X_hat_t + (K*z)

    P_t = P_t - (K*H_t*P_t)

    return X_t,P_t

for seq in range(0, test_data_size, 1):
    
    P_t_minus_1=np.matrix([[0.01,0],[0,0.01]])
    Q_t=np.matrix([[0.01,0],[0,0.01]])
    R_t=np.matrix([[0.01]])
    
    #mu_x0_approx=np.random.uniform(-2,2,size=dim_x) #mean of initial condition
    #X_hat_t_ekf[seq,0,:]=np.random.multivariate_normal(mu_x0,P)
    for timestep in range(1, seq_length, 1):

        X_hat_t_step=np.transpose(np.matrix(X_hat_t_ekf[seq,timestep-1,:]))
        Y_t_step=np.matrix(Y_test[seq,timestep-1,:])

        X_hat_t_step,P_hat_t=prediction(X_hat_t_step,P_t_minus_1,Q_t)

        X_t,P_t=update(X_hat_t_step,P_hat_t,Y_t_step,R_t)

        X_hat_t_ekf[seq,timestep,:]=np.squeeze(np.asarray(X_t))

        P_t_minus_1=P_t  
        
end3=time.time()
print(end3-start3)
# Out:
# 3.7070658206939697

# %%
#for plotting absolute error at each timestep averaged over test sequences
test_errors_for_ekf=np.zeros((seq_length-1,1))
for k in range(0,seq_length-1,1):
    for i in range(0,test_data_size,1):
        for j in range(0, dim_x, 1):
            test_errors_for_ekf[k]+=(X_hat_t_ekf[i,k+1,j]-X_test[i,k,j])**2
test_errors_for_ekf=test_errors_for_ekf/(dim_x*test_data_size)

# %%
#for plotting absolute error at each timestep averaged over test sequences
test_errors_for_jrn=np.zeros((seq_length-1,1))
for k in range(0,seq_length-1,1):
    for i in range(0,test_data_size,1):
        for j in range(0, dim_x, 1):
            test_errors_for_jrn[k]+=(predicted_output[i,k,j]-X_test[i,k,j])**2
test_errors_for_jrn=test_errors_for_jrn/(dim_x*test_data_size)

# %%
# Compute squared error
jrn_squared_error = (predicted_output - X_test) ** 2

# Compute mean squared error over all samples, timesteps, and dimensions
jrn_mse = np.mean(jrn_squared_error)

# Root mean squared error
jrn_rmse = np.sqrt(jrn_mse)

print(f"JRN RMSE: {jrn_rmse}")
# Out:
# JRN RMSE: 0.12987056012077

# %%
# Extract test portion of X_hat_t_ekf
X_hat_test = X_hat_t_ekf[:, 1:, :] 

# Compute squared error
ekf_squared_error = (X_hat_test - X_test) ** 2

# Compute mean squared error across all samples, timesteps, and dimensions
ekf_mse = np.mean(ekf_squared_error)

# Root mean squared error
ekf_rmse = np.sqrt(ekf_mse)

print(f"EKF RMSE: {ekf_rmse}")
# Out:
# EKF RMSE: 0.1594046986139295

# %%
print(best_epoch)
# Out:
# 312

# %%
H = np.array([1, 0])  # measurement matrix, shape (n,)

def f(t,x):
    x1,x2=x
    dx_dt = [0,0]
    dx_dt[0] = x2
    dx_dt[1] = -(g*np.sin(x1))/l-b/m*x2
    return dx_dt
    
start4= time.time()
def generate_sigma_points(x, P, alpha=1e-3, beta=2, kappa=0):
    n = x.shape[0]
    lambda_ = alpha**2 * (n + kappa) - n
    c = n + lambda_
    Wm = np.full(2 * n + 1, 0.5 / c)
    Wc = np.full(2 * n + 1, 0.5 / c)
    Wm[0] = lambda_ / c
    Wc[0] = lambda_ / c + (1 - alpha**2 + beta)

    U = np.linalg.cholesky(c * P)
    sigma_points = np.zeros((2 * n + 1, n))
    sigma_points[0] = x
    for i in range(n):
        sigma_points[i + 1] = x + U[:, i]
        sigma_points[n + i + 1] = x - U[:, i]
    return sigma_points, Wm, Wc

def unscented_transform(sigma_points, Wm, Wc, noise_cov):
    # For state (vector) sigma points
    mean = np.sum(Wm[:, None] * sigma_points, axis=0)  # shape (n,)
    diff = sigma_points - mean
    cov = np.zeros((mean.size, mean.size))
    for i in range(len(sigma_points)):
        cov += Wc[i] * np.outer(diff[i], diff[i])
    cov += noise_cov
    return mean, cov

def unscented_transform_meas(sigma_points, Wm, Wc, noise_cov):
    # For scalar measurement sigma points
    mean = np.sum(Wm * sigma_points)  # scalar
    diff = sigma_points - mean
    cov = np.sum(Wc * diff * diff) + noise_cov  # scalar
    return mean, cov

dt = 0.1

def ukf_predict(x, P, Q):
    sigma_points, Wm, Wc = generate_sigma_points(x, P)
    
    propagated_sigma = []
    for sp in sigma_points:
        sol = scipy.integrate.solve_ivp(f, [0, dt], sp, method='RK45', t_eval=[dt])
        propagated_sigma.append(sol.y[:, -1])
    propagated_sigma = np.array(propagated_sigma)  
    
    x_pred, P_pred = unscented_transform(propagated_sigma, Wm, Wc, Q)
    return x_pred, P_pred, propagated_sigma, Wm, Wc

def ukf_update(x_pred, P_pred, propagated_sigma, Wm, Wc, y, R):
    meas_sigma = propagated_sigma @ H  
    
    y_pred, P_yy = unscented_transform_meas(meas_sigma, Wm, Wc, R)
    
    P_xy = np.zeros((x_pred.size, 1))
    for i in range(len(propagated_sigma)):
        dx = propagated_sigma[i] - x_pred   # (n,)
        dy = meas_sigma[i] - y_pred         # scalar
        P_xy += Wc[i] * dx[:, None] * dy   # (n,1)
    
    K = P_xy / P_yy                        # Kalman gain (n,1)
    
    x_new = x_pred + K.flatten() * (y - y_pred)
    P_new = P_pred - (K * P_yy) @ K.T
    return x_new, P_new

x_t = np.array([0.0, 0.0])
P_t = P            

X_hat_ukf = np.zeros((test_data_size, seq_length, dim_x))
X_hat_ukf[:,0,:] = x_t

for i in range(0, test_data_size, 1):
    for t in range(1, seq_length):
        # Prediction step
        x_pred, P_pred, propagated_sigma, Wm, Wc = ukf_predict(x_t, P_t, Q)
        y_t = Y_test[i,t-1,:]
        
        # Update step
        x_t, P_t = ukf_update(x_pred, P_pred, propagated_sigma, Wm, Wc, y_t, R)
        X_hat_ukf[i,t,:] = x_t

print("UKF estimation done.")

end4=time.time()
print("Time taken to run UKF:", end4-start4)
# Out:
# UKF estimation done.
# Time taken to run UKF: 7.56902551651001

# %%
X_hat_test_ukf = X_hat_ukf[:, 1:, :]
ukf_squared_error = (X_hat_test_ukf - X_test) ** 2
ukf_rmse = np.sqrt(np.mean(ukf_squared_error))
print(f"UKF RMSE: {ukf_rmse}")
# Out:
# UKF RMSE: 0.1693309392522343

# %%
#for plotting absolute error at each timestep averaged over test sequences
test_errors_for_ukf=np.zeros((seq_length-1,1))
for k in range(0,seq_length-1,1):
    for i in range(0,test_data_size,1):
        for j in range(0, dim_x, 1):
            test_errors_for_ukf[k]+=(X_hat_ukf[i,k+1,j]-X_test[i,k,j])**2
test_errors_for_ukf=test_errors_for_ukf/(dim_x*test_data_size)

# %%
matplotlib.rc('xtick', labelsize=15) 
matplotlib.rc('ytick', labelsize=15) 

t2=[i for i in range(0,seq_length-1, 1)] #change timesteps here if needful
f1=plt.figure()
f1.set_figwidth(10)
f1.set_figheight(5)
plt.plot(t2,test_errors_for_jrn[:,:],label="JRN error",linestyle='dashed')
plt.plot(t2,test_errors_for_ekf[:,:],label="EKF error")
plt.plot(t2,test_errors_for_ukf[:,:],label="UKF error")
#plt.title(f"x{i+1}")
plt.xlabel("Time-steps", fontsize=15)
#plt.xlim(0,100)
plt.ylabel("Error", fontsize=15)
plt.legend(fontsize=15)
plt.show()
f1.savefig("downpendulum_errors.png")
f1.savefig("downpendulum_errors.svg")

# %%
print(f"UKF RMSE: {ukf_rmse}")
print(f"EKF RMSE: {ekf_rmse}")
print(f"JRN RMSE: {jrn_rmse}")
print(f"Best Epoch: {best_epoch}")
# Out:
# UKF RMSE: 0.1693309392522343
# EKF RMSE: 0.1594046986139295
# JRN RMSE: 0.12987056012077
# Best Epoch: 312

# %%
np.savez("downpendseq_data.npz", X_data=X_data_array[:,:,:], Y_data=Y_data_array[:,:,:])
