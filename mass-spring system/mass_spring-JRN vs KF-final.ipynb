# %%
#mass spring system KF vs RNN comparison
import numpy as np
import tensorflow as tf
from keras.callbacks import EarlyStopping
from numpy import linalg
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import math
import matplotlib.pyplot as plt
from scipy.signal import cont2discrete, lti, dlti, dstep
import scipy.integrate
import time
from mpl_toolkits import mplot3d
import matplotlib
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, LSTM
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset 
import os
# Out:
# 2025-06-27 21:48:51.819377: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751075331.839045  319954 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751075331.845135  319954 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-27 21:48:51.865168: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print(tf.config.list_physical_devices())
start=time.time()

# Simulation variables
seq_length = 301 # Number of time steps in each sequence
num_records = 100 # Number of sequences to generate
dim_y =1 # Degrees of freedom (number of connected masses) # No. of measured states
dim_x= 2*dim_y # Number of states

# Arrays to store results
X_data_array = np.empty((num_records, seq_length, dim_x))
Y_data_array = np.zeros((num_records, seq_length, dim_y))
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU')]

# %%
# Continuous-time model
# Parameters 

# Masses (kg)
m = np.ones(dim_y)
m = 10*m

# Spring constants (N/m)
k = np.ones(dim_y)
k = 800*k

# Damping factors (Ns/m)
d = np.ones(dim_y)
d = 6*d

# State-space
A_c = np.zeros((dim_x,dim_x))

offset = 0
for i in range(dim_x):
    if i % 2 == 0:
        A_c[i,i+1] = 1

    if i % 2 == 1:
        if i != dim_x-1:
            A_c[i,i-1] = -(k[i-1-offset]+k[i-offset])/m[i-1-offset]
            A_c[i,i] = -(d[i-1-offset]+d[i-offset])/m[i-1-offset]
            A_c[i,i+1] = k[i-offset]/m[i-1-offset]
            A_c[i,i+2] = d[i-offset]/m[i-1-offset]
        else:
            A_c[i,i-1] = -k[i-dim_y]/m[i-dim_y]
            A_c[i,i] = -d[i-dim_y]/m[i-dim_y]

        if i != 1:
            A_c[i,i-3] = k[i-1-offset]/m[i-1-offset]
            A_c[i,i-2] = d[i-1-offset]/m[i-1-offset]
        
        offset += 1

B_c = np.zeros((dim_x,dim_y))

H_c = np.zeros((dim_y,dim_x))
offset = 0
for i in range(dim_y):
    H_c[i,i+offset] = 1

    offset += 1

D_c = np.array([[0.]])

# %%
# Discretize LTI system using zero-order hold method
dt = 0.1 # Sampling time (seconds)
d_system = cont2discrete((A_c, B_c, H_c, D_c),dt)
A = d_system[0] # Process matrix
H = d_system[2] # Measurement matrix`
print(np.linalg.eig(A))
print(A)

def is_schur(matrix):
    # Check eigenvalues
    eigenvalues, _ = np.linalg.eig(matrix)
    if np.all(np.abs(eigenvalues) < 1):
        print(np.abs(eigenvalues))
        return True
    else:
        return False
    
if is_schur(A):
    print("The matrix is Schur.")
else:
    print("The matrix is not Schur.")
# Out:
# EigResult(eigenvalues=array([0.60784633+0.75649677j, 0.60784633-0.75649677j]), eigenvectors=array([[-0.00372678-0.11104859j, -0.00372678+0.11104859j],
#        [ 0.99380799+0.j        ,  0.99380799-0.j        ]]))
# [[ 0.63323429  0.08462653]
#  [-6.77012211  0.58245838]]
# [0.97044553 0.97044553]
# The matrix is Schur.

# %%
# Noise parameters
mu_pn = np.zeros(dim_x) #mean of process noise
sigma_p = 0.01 # Standard deviation of process noise
sigma_p_diag = (sigma_p**2)*np.ones(dim_x)
Q = np.diag(sigma_p_diag)

mu_mn=np.zeros(dim_y) #mean of measurement noise
sigma_m = 0.01 # Standard deviation of measurement noise
sigma_m_diag = (sigma_m**2)*np.ones(dim_y)
R = np.diag(sigma_m_diag)

sigma_x = 0.01 # Standard deviation of initial state
sigma_x_diag = (sigma_p**2)*np.ones(dim_x)
P = np.diag(sigma_x_diag)

# %%
# Simulation
for s in range(num_records):
    mu_x0 = np.random.uniform(-1,1,size=dim_x) # Initial true state
    x=np.random.multivariate_normal(mu_x0,P)
    # Store initial values
    X_data_array[s,0,:] = np.squeeze(np.asarray(x))
    
    for t in range(1,seq_length):
        w = np.random.multivariate_normal(mu_pn,Q)         
        v = np.random.multivariate_normal(mu_mn,R)

        x = A.dot(X_data_array[s,t-1,:]) + w #state at time t
        y = H.dot(x.reshape(-1,1)) + v # Measurement at time t
         
        X_data_array[s,t,:] = x.T # Store true state at time t
        Y_data_array[s,t,:] = y.T # Store measurement at time t

# %%
end_t=seq_length*dt
t_span=np.arange(0,end_t,dt)
plt.plot(t_span,X_data_array[0,:,0],'b-',label='x1')
plt.plot(t_span,X_data_array[0,:,1],'r--',label='x2')
plt.ylabel('Plot')
plt.xlabel('Time')
plt.legend(loc='best')
plt.show()

# %%
num_data_pts=seq_length*num_records
print(num_data_pts)
# Out:
# 30100

# %%
num_train_pts=np.floor(0.80*num_records).astype(int)
num_val_pts=np.floor(0.10*num_records).astype(int)
test_data_size=num_records-num_train_pts-num_val_pts

Y_train=Y_data_array[0:num_train_pts,1:,:]
X_train=X_data_array[0:num_train_pts,1:,:]
num_train_plus_val=num_train_pts+num_val_pts

Y_validate=Y_data_array[num_train_pts:num_train_plus_val,1:,:]
X_validate=X_data_array[num_train_pts:num_train_plus_val,1:,:]

Y_test=Y_data_array[num_train_plus_val:num_records,1:,:]
X_test=X_data_array[num_train_plus_val:num_records,1:,:]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
print("Device name:", torch.cuda.get_device_name(0))
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = True

#proposed rnn implementation
start=time.time()
# Convert data to PyTorch tensors
input_data = torch.tensor(Y_train, dtype=torch.float32)
output_data = torch.tensor(X_train, dtype=torch.float32)

# Define validation data
val_input_data = torch.tensor(Y_validate, dtype=torch.float32)
val_output_data = torch.tensor(X_validate, dtype=torch.float32) 

test_input_data=torch.tensor(Y_test, dtype=torch.float32)
test_output_data=torch.tensor(X_test, dtype=torch.float32)

# Initialize variables for early stopping
best_val_loss = float('inf')  # Set initial best validation loss to infinity
patience = 10  # Number of epochs to wait for improvement
counter = 0  # Counter to track the number of epochs with no improvement
best_epoch = 0 

checkpoint_dir = './ms_torch_checkpoints_jrn'
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
    
# Define the model
class JRN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(JRN, self).__init__()
        self.output_size=output_size 
        self.Why = nn.Parameter(torch.empty(hidden_size, output_size))
        nn.init.xavier_uniform_(self.Why)
        self.Wyh = nn.Parameter(torch.empty(output_size, hidden_size))
        self.Wxh = nn.Parameter(torch.empty(input_size, hidden_size))
        nn.init.orthogonal_(self.Wyh)  
        nn.init.orthogonal_(self.Wxh)
        #self.bh = nn.Parameter(torch.zeros(hidden_size))
        #self.by = nn.Parameter(torch.zeros(output_size))

    def forward(self, x):
        batch_size, seq_len, _ = x.size()
        y = torch.zeros(batch_size, self.output_size, device=x.device)
        outputs = []
        for i in range(seq_len):
            h = torch.matmul(x[:, i, :], self.Wxh) + torch.matmul(y, self.Wyh)
            y = torch.matmul(h, self.Why) 
            outputs.append(y.unsqueeze(1))
        return torch.cat(outputs, dim=1)

# Create DataLoader for training data
train_dataset = TensorDataset(input_data, output_data)
train_loader = DataLoader(train_dataset, batch_size=40, shuffle=True)

# Define the model, loss function, and optimizer
hidden_size = 50
model = JRN(dim_y, hidden_size, dim_x).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=5*1e-3)

# Training the model
num_epochs = 800
start_time = time.time()
for epoch in range(num_epochs):
    total_loss = 0.0
    for batch_Y, batch_X in train_loader:
        batch_Y = batch_Y.to(device)
        batch_X = batch_X.to(device)
        # Forward pass
        all_outputs = model(batch_Y)

        # Compute the loss
        loss = criterion(all_outputs, batch_X)
        total_loss += loss.item()

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Validation
    with torch.no_grad():
        val_loss = criterion(model(val_input_data.to(device)), val_output_data.to(device))

    # Print and check for early stopping
    print(f'Epoch [{epoch}], Loss: {total_loss / len(train_loader):.4f}, Val Loss: {val_loss.item():.4f}')

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
        best_epoch = epoch
        torch.save({'model_state_dict': model.state_dict()}, os.path.join(checkpoint_dir, 'ckpt.pth'))
    else:
        counter += 1
        if counter >= patience:
            print(f'Early stopping at epoch {epoch+1} as validation loss did not improve for {patience} epochs.')
            break

end_time = time.time()
print("Time taken to train JRN:", end_time - start_time)

print("Best Epoch:", best_epoch)

# Restore best model
checkpoint = torch.load(os.path.join(checkpoint_dir, 'ckpt.pth'))
model.load_state_dict(checkpoint['model_state_dict'])

# Test the model
with torch.no_grad():
    predicted_output = model(test_input_data.to(device))
    print("Error in Output:")
    print(predicted_output.to(device) - test_output_data.to(device))
# Out:
# Using device: cuda
# Device name: NVIDIA RTX 4500 Ada Generation
# Epoch [0], Loss: 0.4336, Val Loss: 0.4507
# Epoch [1], Loss: 0.4301, Val Loss: 0.4448
# Epoch [2], Loss: 0.4234, Val Loss: 0.4341
# Epoch [3], Loss: 0.4114, Val Loss: 0.4165
# Epoch [4], Loss: 0.3926, Val Loss: 0.3904
# Epoch [5], Loss: 0.3653, Val Loss: 0.3567
# Epoch [6], Loss: 0.3329, Val Loss: 0.3229
# Epoch [7], Loss: 0.3021, Val Loss: 0.2968
# Epoch [8], Loss: 0.2773, Val Loss: 0.2668
# Epoch [9], Loss: 0.2439, Val Loss: 0.2130
# Epoch [10], Loss: 0.1865, Val Loss: 0.1485
# Epoch [11], Loss: 0.1505, Val Loss: 0.1654
# Epoch [12], Loss: 0.1421, Val Loss: 0.1294
# Epoch [13], Loss: 0.1195, Val Loss: 0.1271
# Epoch [14], Loss: 0.1194, Val Loss: 0.1268
# Epoch [15], Loss: 0.1174, Val Loss: 0.1184
# Epoch [16], Loss: 0.1069, Val Loss: 0.1006
# Epoch [17], Loss: 0.0890, Val Loss: 0.0888
# Epoch [18], Loss: 0.0820, Val Loss: 0.0931
# Epoch [19], Loss: 0.0833, Val Loss: 0.0826
# Epoch [20], Loss: 0.0727, Val Loss: 0.0771
# Epoch [21], Loss: 0.0701, Val Loss: 0.0779
# Epoch [22], Loss: 0.0693, Val Loss: 0.0725
# Epoch [23], Loss: 0.0640, Val Loss: 0.0697
# Epoch [24], Loss: 0.0627, Val Loss: 0.0698
# Epoch [25], Loss: 0.0612, Val Loss: 0.0657
# Epoch [26], Loss: 0.0579, Val Loss: 0.0666
# Epoch [27], Loss: 0.0586, Val Loss: 0.0660
# Epoch [28], Loss: 0.0571, Val Loss: 0.0641
# Epoch [29], Loss: 0.0564, Val Loss: 0.0641
# Epoch [30], Loss: 0.0558, Val Loss: 0.0627
# Epoch [31], Loss: 0.0549, Val Loss: 0.0634
# Epoch [32], Loss: 0.0551, Val Loss: 0.0623
# Epoch [33], Loss: 0.0542, Val Loss: 0.0620
# Epoch [34], Loss: 0.0541, Val Loss: 0.0615
# Epoch [35], Loss: 0.0535, Val Loss: 0.0615
# Epoch [36], Loss: 0.0534, Val Loss: 0.0613
# Epoch [37], Loss: 0.0530, Val Loss: 0.0606
# Epoch [38], Loss: 0.0527, Val Loss: 0.0603
# Epoch [39], Loss: 0.0524, Val Loss: 0.0600
# Epoch [40], Loss: 0.0522, Val Loss: 0.0598
# Epoch [41], Loss: 0.0519, Val Loss: 0.0594
# Epoch [42], Loss: 0.0517, Val Loss: 0.0591
# Epoch [43], Loss: 0.0515, Val Loss: 0.0589
# Epoch [44], Loss: 0.0513, Val Loss: 0.0587
# Epoch [45], Loss: 0.0511, Val Loss: 0.0584
# Epoch [46], Loss: 0.0509, Val Loss: 0.0582
# Epoch [47], Loss: 0.0507, Val Loss: 0.0580
# Epoch [48], Loss: 0.0505, Val Loss: 0.0578
# Epoch [49], Loss: 0.0504, Val Loss: 0.0577
# Epoch [50], Loss: 0.0503, Val Loss: 0.0575
# Epoch [51], Loss: 0.0501, Val Loss: 0.0574
# Epoch [52], Loss: 0.0500, Val Loss: 0.0572
# Epoch [53], Loss: 0.0498, Val Loss: 0.0570
# Epoch [54], Loss: 0.0497, Val Loss: 0.0569
# Epoch [55], Loss: 0.0496, Val Loss: 0.0568
# Epoch [56], Loss: 0.0495, Val Loss: 0.0567
# Epoch [57], Loss: 0.0494, Val Loss: 0.0566
# Epoch [58], Loss: 0.0492, Val Loss: 0.0564
# Epoch [59], Loss: 0.0491, Val Loss: 0.0563
# Epoch [60], Loss: 0.0490, Val Loss: 0.0562
# Epoch [61], Loss: 0.0489, Val Loss: 0.0561
# Epoch [62], Loss: 0.0488, Val Loss: 0.0560
# Epoch [63], Loss: 0.0488, Val Loss: 0.0559
# Epoch [64], Loss: 0.0487, Val Loss: 0.0558
# Epoch [65], Loss: 0.0486, Val Loss: 0.0557
# Epoch [66], Loss: 0.0485, Val Loss: 0.0557
# Epoch [67], Loss: 0.0484, Val Loss: 0.0556
# Epoch [68], Loss: 0.0483, Val Loss: 0.0555
# Epoch [69], Loss: 0.0482, Val Loss: 0.0554
# Epoch [70], Loss: 0.0482, Val Loss: 0.0553
# Epoch [71], Loss: 0.0481, Val Loss: 0.0552
# Epoch [72], Loss: 0.0480, Val Loss: 0.0551
# Epoch [73], Loss: 0.0480, Val Loss: 0.0551
# Epoch [74], Loss: 0.0479, Val Loss: 0.0550
# Epoch [75], Loss: 0.0478, Val Loss: 0.0549
# Epoch [76], Loss: 0.0478, Val Loss: 0.0548
# Epoch [77], Loss: 0.0477, Val Loss: 0.0548
# Epoch [78], Loss: 0.0476, Val Loss: 0.0547
# Epoch [79], Loss: 0.0476, Val Loss: 0.0546
# Epoch [80], Loss: 0.0475, Val Loss: 0.0546
# Epoch [81], Loss: 0.0474, Val Loss: 0.0545
# Epoch [82], Loss: 0.0474, Val Loss: 0.0544
# Epoch [83], Loss: 0.0473, Val Loss: 0.0544
# Epoch [84], Loss: 0.0473, Val Loss: 0.0543
# Epoch [85], Loss: 0.0472, Val Loss: 0.0542
# Epoch [86], Loss: 0.0471, Val Loss: 0.0542
# Epoch [87], Loss: 0.0471, Val Loss: 0.0541
# Epoch [88], Loss: 0.0470, Val Loss: 0.0540
# Epoch [89], Loss: 0.0470, Val Loss: 0.0540
# Epoch [90], Loss: 0.0469, Val Loss: 0.0539
# Epoch [91], Loss: 0.0469, Val Loss: 0.0539
# Epoch [92], Loss: 0.0468, Val Loss: 0.0538
# Epoch [93], Loss: 0.0468, Val Loss: 0.0537
# Epoch [94], Loss: 0.0467, Val Loss: 0.0537
# Epoch [95], Loss: 0.0467, Val Loss: 0.0536
# Epoch [96], Loss: 0.0466, Val Loss: 0.0536
# Epoch [97], Loss: 0.0466, Val Loss: 0.0535
# Epoch [98], Loss: 0.0465, Val Loss: 0.0535
# Epoch [99], Loss: 0.0465, Val Loss: 0.0534
# Epoch [100], Loss: 0.0465, Val Loss: 0.0534
# Epoch [101], Loss: 0.0464, Val Loss: 0.0533
# Epoch [102], Loss: 0.0464, Val Loss: 0.0533
# Epoch [103], Loss: 0.0463, Val Loss: 0.0532
# Epoch [104], Loss: 0.0463, Val Loss: 0.0532
# Epoch [105], Loss: 0.0462, Val Loss: 0.0531
# Epoch [106], Loss: 0.0462, Val Loss: 0.0531
# Epoch [107], Loss: 0.0462, Val Loss: 0.0530
# Epoch [108], Loss: 0.0461, Val Loss: 0.0530
# Epoch [109], Loss: 0.0461, Val Loss: 0.0529
# Epoch [110], Loss: 0.0460, Val Loss: 0.0529
# Epoch [111], Loss: 0.0460, Val Loss: 0.0528
# Epoch [112], Loss: 0.0460, Val Loss: 0.0528
# Epoch [113], Loss: 0.0459, Val Loss: 0.0527
# Epoch [114], Loss: 0.0459, Val Loss: 0.0527
# Epoch [115], Loss: 0.0458, Val Loss: 0.0526
# Epoch [116], Loss: 0.0458, Val Loss: 0.0526
# Epoch [117], Loss: 0.0458, Val Loss: 0.0526
# Epoch [118], Loss: 0.0457, Val Loss: 0.0525
# Epoch [119], Loss: 0.0457, Val Loss: 0.0525
# Epoch [120], Loss: 0.0457, Val Loss: 0.0524
# Epoch [121], Loss: 0.0456, Val Loss: 0.0524
# Epoch [122], Loss: 0.0456, Val Loss: 0.0523
# Epoch [123], Loss: 0.0456, Val Loss: 0.0523
# Epoch [124], Loss: 0.0455, Val Loss: 0.0523
# Epoch [125], Loss: 0.0455, Val Loss: 0.0522
# Epoch [126], Loss: 0.0455, Val Loss: 0.0522
# Epoch [127], Loss: 0.0454, Val Loss: 0.0521
# Epoch [128], Loss: 0.0454, Val Loss: 0.0521
# Epoch [129], Loss: 0.0454, Val Loss: 0.0521
# Epoch [130], Loss: 0.0453, Val Loss: 0.0520
# Epoch [131], Loss: 0.0453, Val Loss: 0.0520
# Epoch [132], Loss: 0.0453, Val Loss: 0.0520
# Epoch [133], Loss: 0.0453, Val Loss: 0.0520
# Epoch [134], Loss: 0.0452, Val Loss: 0.0519
# Epoch [135], Loss: 0.0452, Val Loss: 0.0519
# Epoch [136], Loss: 0.0452, Val Loss: 0.0518
# Epoch [137], Loss: 0.0451, Val Loss: 0.0518
# Epoch [138], Loss: 0.0451, Val Loss: 0.0518
# Epoch [139], Loss: 0.0451, Val Loss: 0.0517
# Epoch [140], Loss: 0.0451, Val Loss: 0.0517
# Epoch [141], Loss: 0.0450, Val Loss: 0.0517
# Epoch [142], Loss: 0.0450, Val Loss: 0.0516
# Epoch [143], Loss: 0.0450, Val Loss: 0.0516
# Epoch [144], Loss: 0.0450, Val Loss: 0.0516
# Epoch [145], Loss: 0.0450, Val Loss: 0.0516
# Epoch [146], Loss: 0.0449, Val Loss: 0.0516
# Epoch [147], Loss: 0.0449, Val Loss: 0.0515
# Epoch [148], Loss: 0.0449, Val Loss: 0.0515
# Epoch [149], Loss: 0.0449, Val Loss: 0.0514
# Epoch [150], Loss: 0.0448, Val Loss: 0.0514
# Epoch [151], Loss: 0.0448, Val Loss: 0.0514
# Epoch [152], Loss: 0.0448, Val Loss: 0.0514
# Epoch [153], Loss: 0.0448, Val Loss: 0.0513
# Epoch [154], Loss: 0.0447, Val Loss: 0.0513
# Epoch [155], Loss: 0.0447, Val Loss: 0.0513
# Epoch [156], Loss: 0.0447, Val Loss: 0.0513
# Epoch [157], Loss: 0.0447, Val Loss: 0.0512
# Epoch [158], Loss: 0.0447, Val Loss: 0.0512
# Epoch [159], Loss: 0.0446, Val Loss: 0.0512
# Epoch [160], Loss: 0.0446, Val Loss: 0.0511
# Epoch [161], Loss: 0.0446, Val Loss: 0.0511
# Epoch [162], Loss: 0.0446, Val Loss: 0.0511
# Epoch [163], Loss: 0.0446, Val Loss: 0.0511
# Epoch [164], Loss: 0.0446, Val Loss: 0.0511
# Epoch [165], Loss: 0.0446, Val Loss: 0.0510
# Epoch [166], Loss: 0.0445, Val Loss: 0.0510
# Epoch [167], Loss: 0.0445, Val Loss: 0.0510
# Epoch [168], Loss: 0.0445, Val Loss: 0.0511
# Epoch [169], Loss: 0.0445, Val Loss: 0.0510
# Epoch [170], Loss: 0.0445, Val Loss: 0.0509
# Epoch [171], Loss: 0.0445, Val Loss: 0.0509
# Epoch [172], Loss: 0.0445, Val Loss: 0.0509
# Epoch [173], Loss: 0.0445, Val Loss: 0.0512
# Epoch [174], Loss: 0.0446, Val Loss: 0.0511
# Epoch [175], Loss: 0.0445, Val Loss: 0.0510
# Epoch [176], Loss: 0.0445, Val Loss: 0.0508
# Epoch [177], Loss: 0.0444, Val Loss: 0.0508
# Epoch [178], Loss: 0.0444, Val Loss: 0.0510
# Epoch [179], Loss: 0.0444, Val Loss: 0.0510
# Epoch [180], Loss: 0.0445, Val Loss: 0.0508
# Epoch [181], Loss: 0.0445, Val Loss: 0.0507
# Epoch [182], Loss: 0.0444, Val Loss: 0.0508
# Epoch [183], Loss: 0.0443, Val Loss: 0.0508
# Epoch [184], Loss: 0.0443, Val Loss: 0.0508
# Epoch [185], Loss: 0.0444, Val Loss: 0.0506
# Epoch [186], Loss: 0.0443, Val Loss: 0.0508
# Epoch [187], Loss: 0.0443, Val Loss: 0.0509
# Epoch [188], Loss: 0.0444, Val Loss: 0.0506
# Epoch [189], Loss: 0.0444, Val Loss: 0.0508
# Epoch [190], Loss: 0.0443, Val Loss: 0.0508
# Epoch [191], Loss: 0.0444, Val Loss: 0.0506
# Epoch [192], Loss: 0.0443, Val Loss: 0.0506
# Epoch [193], Loss: 0.0442, Val Loss: 0.0506
# Epoch [194], Loss: 0.0443, Val Loss: 0.0505
# Epoch [195], Loss: 0.0443, Val Loss: 0.0507
# Epoch [196], Loss: 0.0442, Val Loss: 0.0506
# Epoch [197], Loss: 0.0442, Val Loss: 0.0505
# Epoch [198], Loss: 0.0442, Val Loss: 0.0506
# Epoch [199], Loss: 0.0442, Val Loss: 0.0507
# Epoch [200], Loss: 0.0443, Val Loss: 0.0504
# Epoch [201], Loss: 0.0443, Val Loss: 0.0505
# Epoch [202], Loss: 0.0441, Val Loss: 0.0506
# Epoch [203], Loss: 0.0442, Val Loss: 0.0504
# Epoch [204], Loss: 0.0441, Val Loss: 0.0504
# Epoch [205], Loss: 0.0441, Val Loss: 0.0505
# Epoch [206], Loss: 0.0441, Val Loss: 0.0505
# Epoch [207], Loss: 0.0441, Val Loss: 0.0504
# Epoch [208], Loss: 0.0441, Val Loss: 0.0505
# Epoch [209], Loss: 0.0441, Val Loss: 0.0504
# Epoch [210], Loss: 0.0441, Val Loss: 0.0504
# Epoch [211], Loss: 0.0440, Val Loss: 0.0503
# Epoch [212], Loss: 0.0440, Val Loss: 0.0504
# Epoch [213], Loss: 0.0440, Val Loss: 0.0505
# Epoch [214], Loss: 0.0442, Val Loss: 0.0503
# Epoch [215], Loss: 0.0442, Val Loss: 0.0510
# Epoch [216], Loss: 0.0444, Val Loss: 0.0508
# Epoch [217], Loss: 0.0448, Val Loss: 0.0503
# Epoch [218], Loss: 0.0448, Val Loss: 0.0544
# Epoch [219], Loss: 0.0461, Val Loss: 0.0534
# Epoch [220], Loss: 0.0462, Val Loss: 0.0505
# Epoch [221], Loss: 0.0456, Val Loss: 0.0535
# Epoch [222], Loss: 0.0457, Val Loss: 0.0535
# Epoch [223], Loss: 0.0459, Val Loss: 0.0519
# Epoch [224], Loss: 0.0454, Val Loss: 0.0504
# Epoch [225], Loss: 0.0447, Val Loss: 0.0502
# Epoch [226], Loss: 0.0445, Val Loss: 0.0506
# Epoch [227], Loss: 0.0444, Val Loss: 0.0510
# Epoch [228], Loss: 0.0444, Val Loss: 0.0516
# Epoch [229], Loss: 0.0446, Val Loss: 0.0517
# Epoch [230], Loss: 0.0446, Val Loss: 0.0511
# Epoch [231], Loss: 0.0444, Val Loss: 0.0506
# Epoch [232], Loss: 0.0443, Val Loss: 0.0502
# Epoch [233], Loss: 0.0441, Val Loss: 0.0501
# Epoch [234], Loss: 0.0440, Val Loss: 0.0502
# Epoch [235], Loss: 0.0440, Val Loss: 0.0503
# Epoch [236], Loss: 0.0440, Val Loss: 0.0504
# Epoch [237], Loss: 0.0440, Val Loss: 0.0502
# Epoch [238], Loss: 0.0440, Val Loss: 0.0501
# Epoch [239], Loss: 0.0440, Val Loss: 0.0501
# Epoch [240], Loss: 0.0439, Val Loss: 0.0501
# Epoch [241], Loss: 0.0439, Val Loss: 0.0501
# Epoch [242], Loss: 0.0439, Val Loss: 0.0502
# Epoch [243], Loss: 0.0439, Val Loss: 0.0503
# Epoch [244], Loss: 0.0440, Val Loss: 0.0502
# Epoch [245], Loss: 0.0440, Val Loss: 0.0501
# Epoch [246], Loss: 0.0439, Val Loss: 0.0501
# Epoch [247], Loss: 0.0439, Val Loss: 0.0502
# Epoch [248], Loss: 0.0439, Val Loss: 0.0502
# Epoch [249], Loss: 0.0439, Val Loss: 0.0501
# Epoch [250], Loss: 0.0439, Val Loss: 0.0500
# Epoch [251], Loss: 0.0438, Val Loss: 0.0501
# Epoch [252], Loss: 0.0438, Val Loss: 0.0500
# Epoch [253], Loss: 0.0438, Val Loss: 0.0501
# Epoch [254], Loss: 0.0438, Val Loss: 0.0500
# Epoch [255], Loss: 0.0438, Val Loss: 0.0500
# Epoch [256], Loss: 0.0438, Val Loss: 0.0500
# Epoch [257], Loss: 0.0438, Val Loss: 0.0500
# Epoch [258], Loss: 0.0438, Val Loss: 0.0500
# Epoch [259], Loss: 0.0438, Val Loss: 0.0500
# Epoch [260], Loss: 0.0438, Val Loss: 0.0500
# Epoch [261], Loss: 0.0438, Val Loss: 0.0500
# Epoch [262], Loss: 0.0438, Val Loss: 0.0501
# Epoch [263], Loss: 0.0439, Val Loss: 0.0501
# Epoch [264], Loss: 0.0439, Val Loss: 0.0500
# Epoch [265], Loss: 0.0438, Val Loss: 0.0500
# Epoch [266], Loss: 0.0438, Val Loss: 0.0501
# Epoch [267], Loss: 0.0438, Val Loss: 0.0500
# Epoch [268], Loss: 0.0438, Val Loss: 0.0500
# Epoch [269], Loss: 0.0438, Val Loss: 0.0501
# Epoch [270], Loss: 0.0438, Val Loss: 0.0500
# Epoch [271], Loss: 0.0438, Val Loss: 0.0500
# Epoch [272], Loss: 0.0438, Val Loss: 0.0500
# Epoch [273], Loss: 0.0437, Val Loss: 0.0500
# Epoch [274], Loss: 0.0437, Val Loss: 0.0499
# Epoch [275], Loss: 0.0437, Val Loss: 0.0499
# Epoch [276], Loss: 0.0437, Val Loss: 0.0499
# Epoch [277], Loss: 0.0437, Val Loss: 0.0499
# Epoch [278], Loss: 0.0437, Val Loss: 0.0499
# Epoch [279], Loss: 0.0437, Val Loss: 0.0499
# Epoch [280], Loss: 0.0437, Val Loss: 0.0499
# Epoch [281], Loss: 0.0437, Val Loss: 0.0499
# Epoch [282], Loss: 0.0437, Val Loss: 0.0499
# Epoch [283], Loss: 0.0437, Val Loss: 0.0499
# Epoch [284], Loss: 0.0437, Val Loss: 0.0499
# Epoch [285], Loss: 0.0437, Val Loss: 0.0499
# Epoch [286], Loss: 0.0437, Val Loss: 0.0499
# Epoch [287], Loss: 0.0437, Val Loss: 0.0499
# Epoch [288], Loss: 0.0437, Val Loss: 0.0499
# Epoch [289], Loss: 0.0437, Val Loss: 0.0499
# Epoch [290], Loss: 0.0437, Val Loss: 0.0499
# Epoch [291], Loss: 0.0437, Val Loss: 0.0499
# Epoch [292], Loss: 0.0437, Val Loss: 0.0500
# Epoch [293], Loss: 0.0438, Val Loss: 0.0499
# Epoch [294], Loss: 0.0437, Val Loss: 0.0499
# Epoch [295], Loss: 0.0437, Val Loss: 0.0501
# Epoch [296], Loss: 0.0439, Val Loss: 0.0499
# Epoch [297], Loss: 0.0438, Val Loss: 0.0500
# Epoch [298], Loss: 0.0437, Val Loss: 0.0501
# Epoch [299], Loss: 0.0439, Val Loss: 0.0499
# Epoch [300], Loss: 0.0437, Val Loss: 0.0499
# Epoch [301], Loss: 0.0437, Val Loss: 0.0499
# Epoch [302], Loss: 0.0437, Val Loss: 0.0498
# Epoch [303], Loss: 0.0437, Val Loss: 0.0498
# Epoch [304], Loss: 0.0437, Val Loss: 0.0499
# Epoch [305], Loss: 0.0437, Val Loss: 0.0498
# Epoch [306], Loss: 0.0438, Val Loss: 0.0501
# Epoch [307], Loss: 0.0438, Val Loss: 0.0499
# Epoch [308], Loss: 0.0437, Val Loss: 0.0499
# Epoch [309], Loss: 0.0437, Val Loss: 0.0500
# Epoch [310], Loss: 0.0437, Val Loss: 0.0499
# Epoch [311], Loss: 0.0438, Val Loss: 0.0500
# Epoch [312], Loss: 0.0437, Val Loss: 0.0498
# Epoch [313], Loss: 0.0437, Val Loss: 0.0498
# Epoch [314], Loss: 0.0436, Val Loss: 0.0498
# Epoch [315], Loss: 0.0437, Val Loss: 0.0500
# Epoch [316], Loss: 0.0438, Val Loss: 0.0498
# Epoch [317], Loss: 0.0437, Val Loss: 0.0501
# Epoch [318], Loss: 0.0438, Val Loss: 0.0498
# Epoch [319], Loss: 0.0437, Val Loss: 0.0500
# Epoch [320], Loss: 0.0437, Val Loss: 0.0499
# Epoch [321], Loss: 0.0438, Val Loss: 0.0500
# Epoch [322], Loss: 0.0437, Val Loss: 0.0500
# Epoch [323], Loss: 0.0438, Val Loss: 0.0498
# Epoch [324], Loss: 0.0437, Val Loss: 0.0499
# Epoch [325], Loss: 0.0437, Val Loss: 0.0498
# Epoch [326], Loss: 0.0437, Val Loss: 0.0501
# Epoch [327], Loss: 0.0440, Val Loss: 0.0498
# Epoch [328], Loss: 0.0437, Val Loss: 0.0503
# Epoch [329], Loss: 0.0440, Val Loss: 0.0498
# Epoch [330], Loss: 0.0438, Val Loss: 0.0509
# Epoch [331], Loss: 0.0443, Val Loss: 0.0499
# Epoch [332], Loss: 0.0441, Val Loss: 0.0502
# Epoch [333], Loss: 0.0438, Val Loss: 0.0501
# Epoch [334], Loss: 0.0440, Val Loss: 0.0499
# Epoch [335], Loss: 0.0437, Val Loss: 0.0499
# Epoch [336], Loss: 0.0437, Val Loss: 0.0498
# Epoch [337], Loss: 0.0437, Val Loss: 0.0499
# Epoch [338], Loss: 0.0437, Val Loss: 0.0498
# Epoch [339], Loss: 0.0436, Val Loss: 0.0499
# Epoch [340], Loss: 0.0437, Val Loss: 0.0498
# Epoch [341], Loss: 0.0436, Val Loss: 0.0498
# Epoch [342], Loss: 0.0436, Val Loss: 0.0498
# Epoch [343], Loss: 0.0436, Val Loss: 0.0498
# Epoch [344], Loss: 0.0436, Val Loss: 0.0500
# Epoch [345], Loss: 0.0437, Val Loss: 0.0498
# Epoch [346], Loss: 0.0436, Val Loss: 0.0498
# Epoch [347], Loss: 0.0437, Val Loss: 0.0498
# Epoch [348], Loss: 0.0436, Val Loss: 0.0499
# Epoch [349], Loss: 0.0439, Val Loss: 0.0499
# Epoch [350], Loss: 0.0437, Val Loss: 0.0503
# Epoch [351], Loss: 0.0441, Val Loss: 0.0499
# Epoch [352], Loss: 0.0437, Val Loss: 0.0501
# Epoch [353], Loss: 0.0441, Val Loss: 0.0501
# Epoch [354], Loss: 0.0437, Val Loss: 0.0502
# Epoch [355], Loss: 0.0441, Val Loss: 0.0499
# Early stopping at epoch 356 as validation loss did not improve for 10 epochs.
# Time taken to train JRN: 70.81096768379211
# Best Epoch: 345
# Error in Output:
# tensor([[[-1.6870e-02, -5.9589e+00],
#          [-2.4658e-02, -4.2560e+00],
#          [ 5.1127e-02, -2.5972e+00],
#          ...,
#          [-6.5605e-03, -7.1782e-03],
#          [-1.3919e-02,  6.5440e-02],
#          [-7.5122e-03,  1.4443e-01]],
#
#         [[ 4.2198e-03,  3.0296e-01],
#          [ 1.1347e-02,  2.0786e-01],
#          [ 4.1140e-03,  8.5996e-02],
#          ...,
#          [-1.6201e-02, -3.2348e-02],
#          [ 2.4004e-03,  3.1200e-02],
#          [-1.1570e-02,  3.2707e-02]],
#
#         [[-5.4253e-03, -1.9093e+00],
#          [-1.4018e-02, -1.4240e+00],
#          [ 3.0189e-02, -8.8246e-01],
#          ...,
#          [-6.1195e-03,  2.0260e-01],
#          [-6.7457e-03,  1.6626e-01],
#          [-2.1698e-03,  1.6580e-01]],
#
#         ...,
#
#         [[ 1.0862e-03,  4.8848e+00],
#          [ 3.6899e-02,  3.6075e+00],
#          [-5.0935e-02,  2.1622e+00],
#          ...,
#          [-5.9768e-03,  8.7857e-02],
#          [ 4.4630e-04,  8.3719e-02],
#          [-6.8571e-03,  7.8853e-02]],
#
#         [[ 2.3537e-02,  5.4809e+00],
#          [ 2.2680e-04,  3.8836e+00],
#          [-3.7553e-02,  2.4573e+00],
#          ...,
#          [-6.2124e-03,  1.1066e-01],
#          [ 3.2746e-03,  8.6747e-02],
#          [ 1.0741e-02,  5.4269e-02]],
#
#         [[-1.0091e-02, -4.1457e+00],
#          [-8.5962e-03, -2.9286e+00],
#          [ 2.9878e-02, -1.8053e+00],
#          ...,
#          [-7.8328e-03,  1.9416e-01],
#          [-1.0203e-02,  1.8746e-01],
#          [-8.8448e-03,  1.8113e-01]]], device='cuda:0')
# /tmp/ipykernel_319954/1447195921.py:108: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(os.path.join(checkpoint_dir, 'ckpt.pth'))

# %%
print("time taken to run RNN:")
end=time.time()
print(end-start)
# Output the final weight and bias values
print("Final Weight (Wxh):")
print(model.Wxh)
print("Final Weight (Wyh):")
print(model.Wyh)
print("Final Weight (Why):")
print(model.Why)
#print("Final Bias (bh):")
#print(model.bh)
#print("Final Bias (by):")
#print(model.by)
# Out:
# time taken to run RNN:
# 71.95452928543091
# Final Weight (Wxh):
# Parameter containing:
# tensor([[-0.0796,  0.2962, -0.3330, -0.2290,  0.0915, -0.0985, -0.3414,  0.2850,
#           0.0540, -0.0412, -0.0557,  0.3536,  0.2999,  0.1393,  0.2604,  0.2343,
#           0.0954,  0.2614,  0.0887, -0.1410,  0.0671, -0.1767, -0.2389,  0.0707,
#           0.1937, -0.1186,  0.0551,  0.0053, -0.0951,  0.0861, -0.0044,  0.0448,
#          -0.0883, -0.2469,  0.1720, -0.1313,  0.2254, -0.0775,  0.1859,  0.0679,
#          -0.1968, -0.1056,  0.2635,  0.1706,  0.0529,  0.1782,  0.2674,  0.0965,
#           0.2439,  0.2540]], device='cuda:0', requires_grad=True)
# Final Weight (Wyh):
# Parameter containing:
# tensor([[ 5.0272e-01, -3.3468e-03, -3.1034e-01, -3.5803e-01,  3.5701e-01,
#          -2.6838e-01,  3.4131e-02, -5.4814e-01,  5.3683e-01, -1.9044e-01,
#           3.9152e-01, -3.5184e-01,  3.5006e-01, -6.0238e-01,  2.8158e-01,
#           1.5468e-01,  1.1774e-01,  3.6989e-02, -1.4632e-01,  4.9886e-01,
#           2.8317e-01, -3.5505e-01, -1.7533e-01, -1.8051e-01,  2.8284e-01,
#          -1.3324e-01, -4.4135e-01,  4.2792e-01,  3.0967e-01, -6.2523e-01,
#           4.7687e-01, -3.7136e-01, -3.2247e-01,  2.4293e-02, -6.4890e-01,
#          -3.2777e-01,  1.9355e-01,  6.2982e-01,  4.3236e-01,  3.6855e-01,
#          -2.4665e-01, -2.9107e-01,  2.3513e-01,  9.7408e-02, -1.1387e-02,
#           1.3670e-01,  2.1160e-01, -3.8452e-01, -4.0802e-01,  2.2608e-01],
#         [ 5.6240e-02, -2.0306e-01,  3.2343e-01, -1.9830e-02,  2.4838e-02,
#           8.1456e-02,  1.1814e-01, -9.5265e-02, -9.2835e-02,  2.0250e-01,
#           2.0657e-01, -2.8563e-02, -2.5992e-02,  5.9936e-02, -1.9034e-01,
#          -3.0278e-01, -2.4071e-01, -8.8879e-02, -2.1895e-02, -1.6035e-01,
#          -3.8589e-03, -6.6767e-02,  7.4024e-02, -1.6057e-01, -6.8573e-02,
#          -8.1045e-02,  1.0787e-02, -4.9433e-02,  1.7920e-01, -6.3112e-02,
#          -1.3078e-01,  4.9216e-01,  7.1378e-02, -7.8762e-02, -1.6825e-01,
#           1.9774e-01, -1.5747e-01,  1.1868e-04, -2.5391e-01, -1.0076e-01,
#           5.2046e-02,  7.0690e-03,  5.5321e-02, -1.5089e-01,  1.2106e-02,
#          -1.4025e-01, -7.1398e-02,  9.4860e-02, -3.0878e-02, -7.3783e-02]],
#        device='cuda:0', requires_grad=True)
# Final Weight (Why):
# Parameter containing:
# tensor([[ 0.0298, -0.3989],
#         [ 0.1352, -0.1463],
#         [ 0.1262,  0.1975],
#         [ 0.0103,  0.6011],
#         [-0.0117, -0.3030],
#         [-0.0859,  0.1970],
#         [-0.2855, -0.0459],
#         [ 0.0910,  0.5019],
#         [-0.0347, -0.2901],
#         [-0.2512,  0.1723],
#         [ 0.0050, -0.4283],
#         [ 0.1560,  0.3928],
#         [ 0.0080, -0.5390],
#         [ 0.1829,  0.3036],
#         [ 0.3170, -0.4793],
#         [-0.1957, -0.0940],
#         [ 0.0813, -0.1527],
#         [ 0.3603, -0.2514],
#         [-0.3620, -0.0238],
#         [-0.1529, -0.3282],
#         [ 0.1514, -0.2439],
#         [-0.3941,  0.4470],
#         [-0.3808,  0.4334],
#         [-0.2227,  0.1463],
#         [ 0.1358, -0.5398],
#         [-0.3172,  0.2421],
#         [-0.0148,  0.4636],
#         [-0.1342, -0.4370],
#         [-0.0018, -0.3058],
#         [ 0.2959,  0.6073],
#         [ 0.1619, -0.4109],
#         [ 0.2462,  0.1933],
#         [-0.2192,  0.3284],
#         [-0.3841,  0.0979],
#         [ 0.0855,  0.2861],
#         [ 0.1903,  0.3846],
#         [ 0.1111, -0.1421],
#         [-0.1715, -0.5153],
#         [-0.2719, -0.3671],
#         [ 0.1481, -0.3056],
#         [-0.3168,  0.2128],
#         [ 0.1736,  0.3321],
#         [ 0.1489, -0.3590],
#         [ 0.2526, -0.1501],
#         [ 0.1715,  0.0323],
#         [ 0.0924, -0.3372],
#         [ 0.3685, -0.2812],
#         [-0.0456,  0.4447],
#         [-0.0238,  0.2333],
#         [ 0.2992, -0.5613]], device='cuda:0', requires_grad=True)

# %%
print(np.shape(predicted_output))
predicted_output=predicted_output.cpu()
predicted_output=predicted_output.numpy()
all_outputs=all_outputs.cpu()
all_outputs=all_outputs.detach().numpy()
# Out:
# torch.Size([10, 300, 2])

# %%
# Compute squared error
jrn_squared_error = (predicted_output - X_test) ** 2

# Compute mean squared error over all samples, timesteps, and dimensions
jrn_mse = np.mean(jrn_squared_error)

# Root mean squared error
jrn_rmse = np.sqrt(jrn_mse)

print(f"JRN RMSE: {jrn_rmse}")
# Out:
# JRN RMSE: 0.23325263776062713

# %%
# #plotted all timesteps for a few features of each test sequence

# t=[i for i in range(0,seq_length, 1)] #change timesteps here if needful

# sequences=[i for i in range(0,test_data_size,1)]

# for i in range(0,dim_x,1):
#     for se in sequences:
#         print("for test sequence"+str(se+1))
#         fig=plt.figure()
#         fig.set_figwidth(10)
#         fig.set_figheight(5)
#         plt.plot(t, predicted_output[se,t,i], label= "estimated state")
#         plt.plot(t, X_test[se,t,i], label= "true state")
#         plt.title(f"x{i+1}")
#         plt.legend()
#         plt.show()

# %%
#implementing a KF for connected springs
start_KF=time.time()
X_hat_t_kf=np.zeros((test_data_size, seq_length, dim_x))#array to store estimated state values

def prediction(X_hat_t_1,P_t_1,Q_t,A):
    X_hat_t=X_hat_t_1
    F_t=np.matrix(A)
    X_hat_t=F_t*X_hat_t
    P_t = F_t*P_t_1*F_t.T + Q_t
    return X_hat_t,P_t

def update(X_hat_t,P_t,Y_t,R_t,H):
    H_t=np.matrix(H)
    S = H_t*P_t*H_t.T + R_t
    K = (P_t*H_t.T) *np.linalg.inv(S)
    z = Y_t - (H_t*X_hat_t) 
    X_t = X_hat_t + (K*z)
    P_t = P_t - (K*H_t*P_t)
    return X_t,P_t

for seq in range(0, test_data_size, 1):
    P_t_minus_1=np.matrix(P)
    Q_t=np.matrix(Q)
    R_t=np.matrix(R)
        
    for timestep in range(1, seq_length, 1):

        X_hat_t_step=np.transpose(np.matrix(X_hat_t_kf[seq,timestep-1,:]))
        Y_t_step=np.matrix(Y_test[seq,timestep-1,:]).T

        X_hat_t_step,P_hat_t=prediction(X_hat_t_step,P_t_minus_1,Q_t,A)

        X_t,P_t=update(X_hat_t_step,P_hat_t,Y_t_step,R_t,H)

        X_hat_t_kf[seq,timestep,:]=np.squeeze(np.asarray(X_t))

        P_t_minus_1=P_t     
end_KF=time.time()
print("Time taken to run KF:")
print(end_KF-start_KF)
# Out:
# Time taken to run KF:
# 0.3043811321258545

# %%
# Extract test portion of X_hat_t_ekf
X_hat_test = X_hat_t_kf[:, 1:, :] 

# Compute squared error
kf_squared_error = (X_hat_test - X_test) ** 2

# Compute mean squared error across all samples, timesteps, and dimensions
kf_mse = np.mean(kf_squared_error)

# Root mean squared error
kf_rmse = np.sqrt(kf_mse)

print(f"KF RMSE: {kf_rmse}")
# Out:
# KF RMSE: 0.2225859238036116

# %%
#for plotting absolute error at each timestep averaged over test sequences

test_errors_for_kf=np.zeros((seq_length-1,1))
for k in range(0,seq_length-1,1):
    for i in range(0,test_data_size,1):
        for j in range(0, dim_x, 1):
            test_errors_for_kf[k]+=(X_hat_t_kf[i,k+1,j]-X_test[i,k,j])**2
test_errors_for_kf=test_errors_for_kf/(dim_x*test_data_size)


#for plotting absolute error at each timestep averaged over test sequences

test_errors_for_jrn=np.zeros((seq_length-1,1))
for k in range(0,seq_length-1,1):
    for i in range(0,test_data_size,1):
        for j in range(0, dim_x, 1):
            test_errors_for_jrn[k]+=(predicted_output[i,k,j]-X_test[i,k,j])**2
test_errors_for_jrn=test_errors_for_jrn/(dim_x*test_data_size)

# %%
t2=[i for i in range(0,seq_length-1, 1)] #change timesteps here if needful
matplotlib.rc('xtick', labelsize=15) 
matplotlib.rc('ytick', labelsize=15) 

f1=plt.figure()
f1.set_figwidth(10)
f1.set_figheight(5)
plt.plot(t2,test_errors_for_jrn,label="JRN error",linestyle='dashed')
plt.plot(t2,test_errors_for_kf,label="KF error")
#plt.title(f"x{i+1}")
plt.xlabel("Timesteps", fontsize=15)
plt.ylabel("Error", fontsize=15)
plt.legend(fontsize=15)
plt.show()
f1.savefig("mass_spring_errors.png")
f1.savefig("mass_spring_errors.svg")

# %%
print(f"KF RMSE: {kf_rmse}")
print(f"JRN RMSE: {jrn_rmse}")
print(f"Best Epoch: {best_epoch}")
# Out:
# KF RMSE: 0.2225859238036116
# JRN RMSE: 0.23325263776062713
# Best Epoch: 345

# %%
np.savez("ms_data.npz", X_data=X_data_array[:,:,:], Y_data=Y_data_array[:,:,:])
