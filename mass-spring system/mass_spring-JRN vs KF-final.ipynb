# %%
#mass spring system KF vs RNN comparison
import numpy as np
import tensorflow as tf
from keras.callbacks import EarlyStopping
from numpy import linalg
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import math
import matplotlib.pyplot as plt
from scipy.signal import cont2discrete, lti, dlti, dstep
import scipy.integrate
import time
from mpl_toolkits import mplot3d
import matplotlib
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, LSTM
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset 
import os
# Out:
# 2025-06-28 14:07:39.956997: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751134059.976774  384055 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751134059.982808  384055 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-28 14:07:40.002940: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print(tf.config.list_physical_devices())
start=time.time()

# Simulation variables
seq_length = 301 # Number of time steps in each sequence
num_records = 100 # Number of sequences to generate
dim_y =1 # Degrees of freedom (number of connected masses) # No. of measured states
dim_x= 2*dim_y # Number of states

# Arrays to store results
X_data_array = np.empty((num_records, seq_length, dim_x))
Y_data_array = np.zeros((num_records, seq_length, dim_y))
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU')]

# %%
# Continuous-time model
# Parameters 

# Masses (kg)
m = np.ones(dim_y)
m = 10*m

# Spring constants (N/m)
k = np.ones(dim_y)
k = 800*k

# Damping factors (Ns/m)
d = np.ones(dim_y)
d = 6*d

# State-space
A_c = np.zeros((dim_x,dim_x))

offset = 0
for i in range(dim_x):
    if i % 2 == 0:
        A_c[i,i+1] = 1

    if i % 2 == 1:
        if i != dim_x-1:
            A_c[i,i-1] = -(k[i-1-offset]+k[i-offset])/m[i-1-offset]
            A_c[i,i] = -(d[i-1-offset]+d[i-offset])/m[i-1-offset]
            A_c[i,i+1] = k[i-offset]/m[i-1-offset]
            A_c[i,i+2] = d[i-offset]/m[i-1-offset]
        else:
            A_c[i,i-1] = -k[i-dim_y]/m[i-dim_y]
            A_c[i,i] = -d[i-dim_y]/m[i-dim_y]

        if i != 1:
            A_c[i,i-3] = k[i-1-offset]/m[i-1-offset]
            A_c[i,i-2] = d[i-1-offset]/m[i-1-offset]
        
        offset += 1

B_c = np.zeros((dim_x,dim_y))

H_c = np.zeros((dim_y,dim_x))
offset = 0
for i in range(dim_y):
    H_c[i,i+offset] = 1

    offset += 1

D_c = np.array([[0.]])

# %%
# Discretize LTI system using zero-order hold method
dt = 0.1 # Sampling time (seconds)
d_system = cont2discrete((A_c, B_c, H_c, D_c),dt)
A = d_system[0] # Process matrix
H = d_system[2] # Measurement matrix`
print(np.linalg.eig(A))
print(A)

def is_schur(matrix):
    # Check eigenvalues
    eigenvalues, _ = np.linalg.eig(matrix)
    if np.all(np.abs(eigenvalues) < 1):
        print(np.abs(eigenvalues))
        return True
    else:
        return False
    
if is_schur(A):
    print("The matrix is Schur.")
else:
    print("The matrix is not Schur.")
# Out:
# EigResult(eigenvalues=array([0.60784633+0.75649677j, 0.60784633-0.75649677j]), eigenvectors=array([[-0.00372678-0.11104859j, -0.00372678+0.11104859j],
#        [ 0.99380799+0.j        ,  0.99380799-0.j        ]]))
# [[ 0.63323429  0.08462653]
#  [-6.77012211  0.58245838]]
# [0.97044553 0.97044553]
# The matrix is Schur.

# %%
# Noise parameters
mu_pn = np.zeros(dim_x) #mean of process noise
sigma_p = 0.01 # Standard deviation of process noise
sigma_p_diag = (sigma_p)*np.ones(dim_x)
Q = np.diag(sigma_p_diag)

mu_mn=np.zeros(dim_y) #mean of measurement noise
sigma_m = 0.01 # Standard deviation of measurement noise
sigma_m_diag = (sigma_m)*np.ones(dim_y)
R = np.diag(sigma_m_diag)

sigma_x = 0.01 # Standard deviation of initial state
sigma_x_diag = (sigma_p)*np.ones(dim_x)
P = np.diag(sigma_x_diag)

# %%
# Simulation
for s in range(num_records):
    mu_x0 = np.random.uniform(-1,1,size=dim_x) # Initial true state
    x=np.random.multivariate_normal(mu_x0,P)
    # Store initial values
    X_data_array[s,0,:] = np.squeeze(np.asarray(x))
    
    for t in range(1,seq_length):
        w = np.random.multivariate_normal(mu_pn,Q)         
        v = np.random.multivariate_normal(mu_mn,R)

        x = A.dot(X_data_array[s,t-1,:]) + w #state at time t
        y = H.dot(x.reshape(-1,1)) + v # Measurement at time t
         
        X_data_array[s,t,:] = x.T # Store true state at time t
        Y_data_array[s,t,:] = y.T # Store measurement at time t

# %%
end_t=seq_length*dt
t_span=np.arange(0,end_t,dt)
plt.plot(t_span,X_data_array[0,:,0],'b-',label='x1')
plt.plot(t_span,X_data_array[0,:,1],'r--',label='x2')
plt.ylabel('Plot')
plt.xlabel('Time')
plt.legend(loc='best')
plt.show()

# %%
num_data_pts=seq_length*num_records
print(num_data_pts)
# Out:
# 30100

# %%
num_train_pts=np.floor(0.80*num_records).astype(int)
num_val_pts=np.floor(0.10*num_records).astype(int)
test_data_size=num_records-num_train_pts-num_val_pts

Y_train=Y_data_array[0:num_train_pts,1:,:]
X_train=X_data_array[0:num_train_pts,1:,:]
num_train_plus_val=num_train_pts+num_val_pts

Y_validate=Y_data_array[num_train_pts:num_train_plus_val,1:,:]
X_validate=X_data_array[num_train_pts:num_train_plus_val,1:,:]

Y_test=Y_data_array[num_train_plus_val:num_records,1:,:]
X_test=X_data_array[num_train_plus_val:num_records,1:,:]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
print("Device name:", torch.cuda.get_device_name(0))
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = True

#proposed rnn implementation
start=time.time()
# Convert data to PyTorch tensors
input_data = torch.tensor(Y_train, dtype=torch.float32)
output_data = torch.tensor(X_train, dtype=torch.float32)

# Define validation data
val_input_data = torch.tensor(Y_validate, dtype=torch.float32)
val_output_data = torch.tensor(X_validate, dtype=torch.float32) 

test_input_data=torch.tensor(Y_test, dtype=torch.float32)
test_output_data=torch.tensor(X_test, dtype=torch.float32)

# Initialize variables for early stopping
best_val_loss = float('inf')  # Set initial best validation loss to infinity
patience = 10  # Number of epochs to wait for improvement
counter = 0  # Counter to track the number of epochs with no improvement
best_epoch = 0 

checkpoint_dir = './ms_torch_checkpoints_jrn'
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
    
# Define the model
class JRN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(JRN, self).__init__()
        self.output_size=output_size 
        self.Why = nn.Parameter(torch.empty(hidden_size, output_size))
        nn.init.xavier_uniform_(self.Why)
        self.Wyh = nn.Parameter(torch.empty(output_size, hidden_size))
        self.Wxh = nn.Parameter(torch.empty(input_size, hidden_size))
        nn.init.orthogonal_(self.Wyh)  
        nn.init.orthogonal_(self.Wxh)
        #self.bh = nn.Parameter(torch.zeros(hidden_size))
        #self.by = nn.Parameter(torch.zeros(output_size))

    def forward(self, x):
        batch_size, seq_len, _ = x.size()
        y = torch.zeros(batch_size, self.output_size, device=x.device)
        outputs = []
        for i in range(seq_len):
            h = torch.matmul(x[:, i, :], self.Wxh) + torch.matmul(y, self.Wyh)
            y = torch.matmul(h, self.Why) 
            outputs.append(y.unsqueeze(1))
        return torch.cat(outputs, dim=1)

# Create DataLoader for training data
train_dataset = TensorDataset(input_data, output_data)
train_loader = DataLoader(train_dataset, batch_size=40, shuffle=True)

# Define the model, loss function, and optimizer
hidden_size = 50
model = JRN(dim_y, hidden_size, dim_x).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# Training the model
num_epochs = 600
start_time = time.time()
for epoch in range(num_epochs):
    total_loss = 0.0
    for batch_Y, batch_X in train_loader:
        batch_Y = batch_Y.to(device)
        batch_X = batch_X.to(device)
        # Forward pass
        all_outputs = model(batch_Y)

        # Compute the loss
        loss = criterion(all_outputs, batch_X)
        total_loss += loss.item()

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Validation
    with torch.no_grad():
        val_loss = criterion(model(val_input_data.to(device)), val_output_data.to(device))

    # Print and check for early stopping
    print(f'Epoch [{epoch}], Loss: {total_loss / len(train_loader):.4f}, Val Loss: {val_loss.item():.4f}')

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
        best_epoch = epoch
        torch.save({'model_state_dict': model.state_dict()}, os.path.join(checkpoint_dir, 'ckpt.pth'))
    else:
        counter += 1
        if counter >= patience:
            print(f'Early stopping at epoch {epoch+1} as validation loss did not improve for {patience} epochs.')
            break

end_time = time.time()
print("Time taken to train JRN:", end_time - start_time)

print("Best Epoch:", best_epoch)

# Restore best model
checkpoint = torch.load(os.path.join(checkpoint_dir, 'ckpt.pth'))
model.load_state_dict(checkpoint['model_state_dict'])

# Test the model
with torch.no_grad():
    predicted_output = model(test_input_data.to(device))
    print("Error in Output:")
    print(predicted_output.to(device) - test_output_data.to(device))
# Out:
# Using device: cuda
# Device name: NVIDIA RTX 4500 Ada Generation
# Epoch [0], Loss: 3.4884, Val Loss: 3.1509
# Epoch [1], Loss: 3.2030, Val Loss: 2.6962
# Epoch [2], Loss: 2.6141, Val Loss: 1.7175
# Epoch [3], Loss: 1.5236, Val Loss: 2.3150
# Epoch [4], Loss: 1.6554, Val Loss: 1.1429
# Epoch [5], Loss: 1.3115, Val Loss: 1.4347
# Epoch [6], Loss: 1.5428, Val Loss: 1.5089
# Epoch [7], Loss: 1.5768, Val Loss: 1.4528
# Epoch [8], Loss: 1.4934, Val Loss: 1.3170
# Epoch [9], Loss: 1.3286, Val Loss: 1.1261
# Epoch [10], Loss: 1.1166, Val Loss: 0.8944
# Epoch [11], Loss: 0.8784, Val Loss: 0.6690
# Epoch [12], Loss: 0.6572, Val Loss: 0.5531
# Epoch [13], Loss: 0.5888, Val Loss: 0.6181
# Epoch [14], Loss: 0.6702, Val Loss: 0.6620
# Epoch [15], Loss: 0.6620, Val Loss: 0.5512
# Epoch [16], Loss: 0.5503, Val Loss: 0.4909
# Epoch [17], Loss: 0.5100, Val Loss: 0.5028
# Epoch [18], Loss: 0.5273, Val Loss: 0.5289
# Epoch [19], Loss: 0.5479, Val Loss: 0.5321
# Epoch [20], Loss: 0.5446, Val Loss: 0.5128
# Epoch [21], Loss: 0.5218, Val Loss: 0.4828
# Epoch [22], Loss: 0.4924, Val Loss: 0.4627
# Epoch [23], Loss: 0.4745, Val Loss: 0.4588
# Epoch [24], Loss: 0.4751, Val Loss: 0.4601
# Epoch [25], Loss: 0.4728, Val Loss: 0.4453
# Epoch [26], Loss: 0.4531, Val Loss: 0.4215
# Epoch [27], Loss: 0.4328, Val Loss: 0.4116
# Epoch [28], Loss: 0.4258, Val Loss: 0.4084
# Epoch [29], Loss: 0.4220, Val Loss: 0.3995
# Epoch [30], Loss: 0.4116, Val Loss: 0.3856
# Epoch [31], Loss: 0.3998, Val Loss: 0.3781
# Epoch [32], Loss: 0.3942, Val Loss: 0.3759
# Epoch [33], Loss: 0.3916, Val Loss: 0.3685
# Epoch [34], Loss: 0.3840, Val Loss: 0.3615
# Epoch [35], Loss: 0.3777, Val Loss: 0.3577
# Epoch [36], Loss: 0.3753, Val Loss: 0.3543
# Epoch [37], Loss: 0.3711, Val Loss: 0.3485
# Epoch [38], Loss: 0.3658, Val Loss: 0.3446
# Epoch [39], Loss: 0.3628, Val Loss: 0.3420
# Epoch [40], Loss: 0.3592, Val Loss: 0.3369
# Epoch [41], Loss: 0.3548, Val Loss: 0.3342
# Epoch [42], Loss: 0.3517, Val Loss: 0.3306
# Epoch [43], Loss: 0.3484, Val Loss: 0.3278
# Epoch [44], Loss: 0.3451, Val Loss: 0.3240
# Epoch [45], Loss: 0.3424, Val Loss: 0.3226
# Epoch [46], Loss: 0.3396, Val Loss: 0.3185
# Epoch [47], Loss: 0.3366, Val Loss: 0.3171
# Epoch [48], Loss: 0.3344, Val Loss: 0.3137
# Epoch [49], Loss: 0.3321, Val Loss: 0.3130
# Epoch [50], Loss: 0.3294, Val Loss: 0.3094
# Epoch [51], Loss: 0.3273, Val Loss: 0.3091
# Epoch [52], Loss: 0.3253, Val Loss: 0.3054
# Epoch [53], Loss: 0.3232, Val Loss: 0.3048
# Epoch [54], Loss: 0.3211, Val Loss: 0.3020
# Epoch [55], Loss: 0.3197, Val Loss: 0.3018
# Epoch [56], Loss: 0.3177, Val Loss: 0.2984
# Epoch [57], Loss: 0.3164, Val Loss: 0.2972
# Epoch [58], Loss: 0.3149, Val Loss: 0.2970
# Epoch [59], Loss: 0.3134, Val Loss: 0.2947
# Epoch [60], Loss: 0.3116, Val Loss: 0.2926
# Epoch [61], Loss: 0.3105, Val Loss: 0.2926
# Epoch [62], Loss: 0.3091, Val Loss: 0.2906
# Epoch [63], Loss: 0.3091, Val Loss: 0.2902
# Epoch [64], Loss: 0.3069, Val Loss: 0.2880
# Epoch [65], Loss: 0.3058, Val Loss: 0.2872
# Epoch [66], Loss: 0.3046, Val Loss: 0.2860
# Epoch [67], Loss: 0.3040, Val Loss: 0.2849
# Epoch [68], Loss: 0.3030, Val Loss: 0.2844
# Epoch [69], Loss: 0.3021, Val Loss: 0.2855
# Epoch [70], Loss: 0.3018, Val Loss: 0.2832
# Epoch [71], Loss: 0.3003, Val Loss: 0.2818
# Epoch [72], Loss: 0.3002, Val Loss: 0.2814
# Epoch [73], Loss: 0.2991, Val Loss: 0.2834
# Epoch [74], Loss: 0.2987, Val Loss: 0.2795
# Epoch [75], Loss: 0.2984, Val Loss: 0.2794
# Epoch [76], Loss: 0.2977, Val Loss: 0.2790
# Epoch [77], Loss: 0.2963, Val Loss: 0.2796
# Epoch [78], Loss: 0.2966, Val Loss: 0.2819
# Epoch [79], Loss: 0.2964, Val Loss: 0.2770
# Epoch [80], Loss: 0.2943, Val Loss: 0.2762
# Epoch [81], Loss: 0.2939, Val Loss: 0.2794
# Epoch [82], Loss: 0.3028, Val Loss: 0.3159
# Epoch [83], Loss: 0.3246, Val Loss: 0.2914
# Epoch [84], Loss: 0.2989, Val Loss: 0.2865
# Epoch [85], Loss: 0.3178, Val Loss: 0.2762
# Epoch [86], Loss: 0.2962, Val Loss: 0.2960
# Epoch [87], Loss: 0.3008, Val Loss: 0.2764
# Epoch [88], Loss: 0.3013, Val Loss: 0.2744
# Epoch [89], Loss: 0.2936, Val Loss: 0.2904
# Epoch [90], Loss: 0.2991, Val Loss: 0.2727
# Epoch [91], Loss: 0.2934, Val Loss: 0.2746
# Epoch [92], Loss: 0.2929, Val Loss: 0.2737
# Epoch [93], Loss: 0.2898, Val Loss: 0.2718
# Epoch [94], Loss: 0.2898, Val Loss: 0.2715
# Epoch [95], Loss: 0.2899, Val Loss: 0.2717
# Epoch [96], Loss: 0.2893, Val Loss: 0.2744
# Epoch [97], Loss: 0.2898, Val Loss: 0.2711
# Epoch [98], Loss: 0.2893, Val Loss: 0.2767
# Epoch [99], Loss: 0.3008, Val Loss: 0.2722
# Epoch [100], Loss: 0.2901, Val Loss: 0.2901
# Epoch [101], Loss: 0.3047, Val Loss: 0.2883
# Epoch [102], Loss: 0.2946, Val Loss: 0.2737
# Epoch [103], Loss: 0.3021, Val Loss: 0.2733
# Epoch [104], Loss: 0.2905, Val Loss: 0.2788
# Epoch [105], Loss: 0.2935, Val Loss: 0.2778
# Epoch [106], Loss: 0.2899, Val Loss: 0.2689
# Epoch [107], Loss: 0.2878, Val Loss: 0.2686
# Epoch [108], Loss: 0.2865, Val Loss: 0.2728
# Epoch [109], Loss: 0.2896, Val Loss: 0.2756
# Epoch [110], Loss: 0.2931, Val Loss: 0.2834
# Epoch [111], Loss: 0.2931, Val Loss: 0.2683
# Epoch [112], Loss: 0.2858, Val Loss: 0.2679
# Epoch [113], Loss: 0.2875, Val Loss: 0.2684
# Epoch [114], Loss: 0.2870, Val Loss: 0.2673
# Epoch [115], Loss: 0.2856, Val Loss: 0.2749
# Epoch [116], Loss: 0.2905, Val Loss: 0.2772
# Epoch [117], Loss: 0.2876, Val Loss: 0.2678
# Epoch [118], Loss: 0.2928, Val Loss: 0.2745
# Epoch [119], Loss: 0.2946, Val Loss: 0.2671
# Epoch [120], Loss: 0.2859, Val Loss: 0.2663
# Epoch [121], Loss: 0.2842, Val Loss: 0.2668
# Epoch [122], Loss: 0.2846, Val Loss: 0.2745
# Epoch [123], Loss: 0.2945, Val Loss: 0.3010
# Epoch [124], Loss: 0.3047, Val Loss: 0.2749
# Epoch [125], Loss: 0.2873, Val Loss: 0.2663
# Epoch [126], Loss: 0.2837, Val Loss: 0.2667
# Epoch [127], Loss: 0.2868, Val Loss: 0.2671
# Epoch [128], Loss: 0.2860, Val Loss: 0.2654
# Epoch [129], Loss: 0.2833, Val Loss: 0.2654
# Epoch [130], Loss: 0.2836, Val Loss: 0.2653
# Epoch [131], Loss: 0.2835, Val Loss: 0.2650
# Epoch [132], Loss: 0.2840, Val Loss: 0.2655
# Epoch [133], Loss: 0.2848, Val Loss: 0.2648
# Epoch [134], Loss: 0.2833, Val Loss: 0.2647
# Epoch [135], Loss: 0.2841, Val Loss: 0.2665
# Epoch [136], Loss: 0.2890, Val Loss: 0.2746
# Epoch [137], Loss: 0.3145, Val Loss: 0.2957
# Epoch [138], Loss: 0.3283, Val Loss: 0.2653
# Epoch [139], Loss: 0.3028, Val Loss: 0.4241
# Epoch [140], Loss: 0.3582, Val Loss: 0.3672
# Epoch [141], Loss: 0.5304, Val Loss: 0.3925
# Epoch [142], Loss: 0.6631, Val Loss: 0.6782
# Epoch [143], Loss: 0.9379, Val Loss: 0.4397
# Epoch [144], Loss: 0.8690, Val Loss: 0.5219
# Early stopping at epoch 145 as validation loss did not improve for 10 epochs.
# Time taken to train JRN: 20.377269983291626
# Best Epoch: 134
# Error in Output:
# tensor([[[-1.1308e-01,  2.9123e-01],
#          [-1.2857e-01,  8.3528e-01],
#          [ 6.2232e-02,  1.3996e+00],
#          ...,
#          [ 1.0006e-01, -4.3485e-01],
#          [-1.7243e-01, -3.3820e-01],
#          [-4.5121e-02, -1.3641e-01]],
#
#         [[-8.4272e-02,  2.7707e+00],
#          [-3.4186e-02,  2.2775e+00],
#          [ 1.3506e-02,  1.2141e+00],
#          ...,
#          [ 9.8449e-02,  5.4417e-01],
#          [-2.3623e-02, -5.2898e-02],
#          [-1.2674e-01, -3.1298e-01]],
#
#         [[-1.7020e-02, -7.3799e-01],
#          [ 3.3951e-02, -2.5216e-01],
#          [-1.5463e-02, -3.8616e-01],
#          ...,
#          [ 1.2684e-03,  2.0721e-01],
#          [-2.4306e-01, -4.6607e-01],
#          [ 9.8664e-02,  2.2121e-01]],
#
#         ...,
#
#         [[-9.4141e-02, -1.2109e+00],
#          [-4.4387e-02, -5.0738e-01],
#          [ 1.8277e-02, -2.4421e-01],
#          ...,
#          [-1.2926e-01, -5.2993e-01],
#          [ 2.2062e-01,  1.2431e-03],
#          [ 2.2114e-01, -3.3366e-01]],
#
#         [[ 1.9084e-03, -2.8338e+00],
#          [-8.8134e-02, -2.5246e+00],
#          [ 1.0287e-01, -1.2525e+00],
#          ...,
#          [ 4.1496e-02,  6.3338e-01],
#          [-9.5202e-03, -9.5403e-03],
#          [ 6.7812e-02, -2.2660e-02]],
#
#         [[-1.1374e-01, -2.0940e-01],
#          [ 1.0875e-03,  3.0119e-01],
#          [-5.2061e-02,  2.4196e-01],
#          ...,
#          [ 1.6161e-02,  1.2664e+00],
#          [ 1.2964e-01,  6.1801e-02],
#          [-2.1559e-02, -1.2166e+00]]], device='cuda:0')
# /tmp/ipykernel_384055/136188975.py:108: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(os.path.join(checkpoint_dir, 'ckpt.pth'))

# %%
print("time taken to run RNN:")
end=time.time()
print(end-start)
# Output the final weight and bias values
print("Final Weight (Wxh):")
print(model.Wxh)
print("Final Weight (Wyh):")
print(model.Wyh)
print("Final Weight (Why):")
print(model.Why)
#print("Final Bias (bh):")
#print(model.bh)
#print("Final Bias (by):")
#print(model.by)
# Out:
# time taken to run RNN:
# 21.362848043441772
# Final Weight (Wxh):
# Parameter containing:
# tensor([[-1.1459e-01,  1.2213e-01, -1.8900e-01, -7.2749e-02, -7.8562e-02,
#          -6.1596e-02,  1.5031e-01,  3.1722e-02,  1.8402e-01,  7.9996e-02,
#          -3.8637e-04, -1.4343e-01, -1.6772e-01,  3.8882e-02, -2.1797e-02,
#           5.0651e-02,  3.5556e-02, -4.6485e-02, -1.9002e-01, -4.9677e-02,
#          -2.8778e-02, -1.0972e-01, -2.0909e-01, -1.4177e-01, -7.4432e-02,
#          -2.8616e-02,  2.0610e-01, -2.1039e-01, -7.7475e-02,  1.1569e-01,
#           1.5931e-01,  1.8839e-01, -3.8349e-01,  1.8872e-01,  8.2549e-02,
#          -2.8952e-02,  1.4632e-01,  1.1921e-01,  1.0117e-01,  1.9460e-03,
#           7.1907e-04, -2.2640e-01,  1.6012e-01,  4.2842e-01,  4.9047e-02,
#          -1.6122e-01, -1.1125e-01, -4.0127e-02, -8.1884e-02,  1.7716e-01]],
#        device='cuda:0', requires_grad=True)
# Final Weight (Wyh):
# Parameter containing:
# tensor([[-0.0797,  0.0062, -0.1437, -0.1373,  0.2832, -0.1601, -0.3016,  0.4682,
#          -0.3321,  0.0301,  0.0195, -0.2968, -0.2357, -0.4266,  0.3070, -0.4164,
#           0.1862,  0.3930, -0.0422,  0.2926, -0.0863,  0.3973, -0.2115, -0.2351,
#          -0.2270, -0.3748,  0.1325, -0.1771, -0.3129, -0.5653,  0.1680,  0.0711,
#           0.0021,  0.1843, -0.4675,  0.2028,  0.1929,  0.3691, -0.6064, -0.2222,
#           0.2675, -0.3403,  0.1189, -0.0889, -0.5919, -0.1975,  0.6737,  0.0728,
#          -0.2339, -0.2778],
#         [ 0.0084, -0.1161,  0.1696, -0.2126, -0.1800,  0.4339,  0.2009, -0.0606,
#          -0.0101,  0.0667, -0.1072,  0.0350,  0.3232,  0.0429, -0.1750, -0.1046,
#          -0.1680, -0.2501,  0.0739, -0.0820,  0.1364, -0.1295, -0.1911,  0.0956,
#           0.0734,  0.0718,  0.2096,  0.2281,  0.1206, -0.2263, -0.1740,  0.0925,
#          -0.0809,  0.0315,  0.2817, -0.0303, -0.0443, -0.1277, -0.0721,  0.0528,
#           0.1222, -0.0532, -0.0130,  0.1203, -0.0766,  0.1423,  0.0533, -0.2905,
#           0.0988,  0.0021]], device='cuda:0', requires_grad=True)
# Final Weight (Why):
# Parameter containing:
# tensor([[-0.2167,  0.1489],
#         [-0.1963, -0.0250],
#         [-0.3654,  0.1956],
#         [-0.3245,  0.0568],
#         [ 0.1240, -0.3340],
#         [-0.2610,  0.3232],
#         [ 0.2611,  0.2097],
#         [-0.0637, -0.4590],
#         [ 0.0756,  0.4323],
#         [ 0.0120, -0.1749],
#         [-0.2101,  0.1127],
#         [-0.0947,  0.4469],
#         [ 0.2668,  0.1388],
#         [ 0.2068,  0.4426],
#         [ 0.1630, -0.5283],
#         [ 0.0481,  0.1696],
#         [-0.0550, -0.3026],
#         [-0.1201, -0.2598],
#         [ 0.1100,  0.0449],
#         [-0.2582, -0.3426],
#         [-0.0323,  0.1893],
#         [ 0.1202, -0.1222],
#         [-0.3295,  0.1551],
#         [-0.3379,  0.1748],
#         [-0.2955,  0.3803],
#         [-0.2142,  0.5815],
#         [ 0.2194, -0.0470],
#         [-0.1951,  0.1585],
#         [-0.1087,  0.3099],
#         [ 0.1091,  0.6960],
#         [-0.0020, -0.1212],
#         [ 0.0693, -0.0370],
#         [-0.3691,  0.1506],
#         [ 0.1096, -0.3403],
#         [-0.0976,  0.2310],
#         [ 0.1360, -0.1007],
#         [ 0.2035, -0.4497],
#         [ 0.1123, -0.2622],
#         [ 0.2012,  0.8633],
#         [-0.1327,  0.5667],
#         [ 0.2951, -0.4291],
#         [-0.1394,  0.2188],
#         [ 0.1684, -0.4616],
#         [ 0.2084,  0.1209],
#         [ 0.2838,  1.2804],
#         [-0.1366,  0.4282],
#         [-0.0019, -0.2231],
#         [-0.1119, -0.0866],
#         [-0.1086,  0.2836],
#         [ 0.2437,  0.2566]], device='cuda:0', requires_grad=True)

# %%
print(np.shape(predicted_output))
predicted_output=predicted_output.cpu()
predicted_output=predicted_output.numpy()
all_outputs=all_outputs.cpu()
all_outputs=all_outputs.detach().numpy()
# Out:
# torch.Size([10, 300, 2])

# %%
# Compute squared error
jrn_squared_error = (predicted_output - X_test) ** 2

# Compute mean squared error over all samples, timesteps, and dimensions
jrn_mse = np.mean(jrn_squared_error)

# Root mean squared error
jrn_rmse = np.sqrt(jrn_mse)

print(f"JRN RMSE: {jrn_rmse}")
# Out:
# JRN RMSE: 0.5268930639449464

# %%
# #plotted all timesteps for a few features of each test sequence

# t=[i for i in range(0,seq_length, 1)] #change timesteps here if needful

# sequences=[i for i in range(0,test_data_size,1)]

# for i in range(0,dim_x,1):
#     for se in sequences:
#         print("for test sequence"+str(se+1))
#         fig=plt.figure()
#         fig.set_figwidth(10)
#         fig.set_figheight(5)
#         plt.plot(t, predicted_output[se,t,i], label= "estimated state")
#         plt.plot(t, X_test[se,t,i], label= "true state")
#         plt.title(f"x{i+1}")
#         plt.legend()
#         plt.show()

# %%
#implementing a KF for connected springs
start_KF=time.time()
X_hat_t_kf=np.zeros((test_data_size, seq_length, dim_x))#array to store estimated state values

def prediction(X_hat_t_1,P_t_1,Q_t,A):
    X_hat_t=X_hat_t_1
    F_t=np.matrix(A)
    X_hat_t=F_t*X_hat_t
    P_t = F_t*P_t_1*F_t.T + Q_t
    return X_hat_t,P_t

def update(X_hat_t,P_t,Y_t,R_t,H):
    H_t=np.matrix(H)
    S = H_t*P_t*H_t.T + R_t
    K = (P_t*H_t.T) *np.linalg.inv(S)
    z = Y_t - (H_t*X_hat_t) 
    X_t = X_hat_t + (K*z)
    P_t = P_t - (K*H_t*P_t)
    return X_t,P_t

for seq in range(0, test_data_size, 1):
    P_t_minus_1=np.matrix(P)
    Q_t=np.matrix(Q)
    R_t=np.matrix(R)
        
    for timestep in range(1, seq_length, 1):

        X_hat_t_step=np.transpose(np.matrix(X_hat_t_kf[seq,timestep-1,:]))
        Y_t_step=np.matrix(Y_test[seq,timestep-1,:]).T

        X_hat_t_step,P_hat_t=prediction(X_hat_t_step,P_t_minus_1,Q_t,A)

        X_t,P_t=update(X_hat_t_step,P_hat_t,Y_t_step,R_t,H)

        X_hat_t_kf[seq,timestep,:]=np.squeeze(np.asarray(X_t))

        P_t_minus_1=P_t     
end_KF=time.time()
print("Time taken to run KF:")
print(end_KF-start_KF)
# Out:
# Time taken to run KF:
# 0.20111584663391113

# %%
# Extract test portion of X_hat_t_ekf
X_hat_test = X_hat_t_kf[:, 1:, :] 

# Compute squared error
kf_squared_error = (X_hat_test - X_test) ** 2

# Compute mean squared error across all samples, timesteps, and dimensions
kf_mse = np.mean(kf_squared_error)

# Root mean squared error
kf_rmse = np.sqrt(kf_mse)

print(f"KF RMSE: {kf_rmse}")
# Out:
# KF RMSE: 0.5132679000665745

# %%
#for plotting absolute error at each timestep averaged over test sequences

test_errors_for_kf=np.zeros((seq_length-1,1))
for k in range(0,seq_length-1,1):
    for i in range(0,test_data_size,1):
        for j in range(0, dim_x, 1):
            test_errors_for_kf[k]+=(X_hat_t_kf[i,k+1,j]-X_test[i,k,j])**2
test_errors_for_kf=test_errors_for_kf/(dim_x*test_data_size)


#for plotting absolute error at each timestep averaged over test sequences

test_errors_for_jrn=np.zeros((seq_length-1,1))
for k in range(0,seq_length-1,1):
    for i in range(0,test_data_size,1):
        for j in range(0, dim_x, 1):
            test_errors_for_jrn[k]+=(predicted_output[i,k,j]-X_test[i,k,j])**2
test_errors_for_jrn=test_errors_for_jrn/(dim_x*test_data_size)

# %%
t2=[i for i in range(0,seq_length-1, 1)] #change timesteps here if needful
matplotlib.rc('xtick', labelsize=15) 
matplotlib.rc('ytick', labelsize=15) 

f1=plt.figure()
f1.set_figwidth(10)
f1.set_figheight(5)
plt.plot(t2,test_errors_for_jrn,label="JRN error",linestyle='dashed')
plt.plot(t2,test_errors_for_kf,label="KF error")
#plt.title(f"x{i+1}")
plt.xlabel("Time-steps", fontsize=15)
plt.ylabel("Error", fontsize=15)
plt.legend(fontsize=15)
plt.show()
f1.savefig("mass_spring_errors.png")
f1.savefig("mass_spring_errors.svg")

# %%
print(f"KF RMSE: {kf_rmse}")
print(f"JRN RMSE: {jrn_rmse}")
print(f"Best Epoch: {best_epoch}")
# Out:
# KF RMSE: 0.5132679000665745
# JRN RMSE: 0.5268930639449464
# Best Epoch: 134

# %%
np.savez("ms_data.npz", X_data=X_data_array[:,:,:], Y_data=Y_data_array[:,:,:])
